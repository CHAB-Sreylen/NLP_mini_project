# %%
import re 

def clean_headers_footers(text,footer_pattern,header_parttern):
    clean_text = []
    for line in text.splitlines():
        if not re.search(footer_pattern,line) and not re.search(header_parttern, line):
            clean_text.append(line)
        return '\n'.join(clean_text)
    
text = open('data/raw.txt','r',encoding='utf-8').read()
cleaned_text = clean_headers_footers(
    text,
    footer_pattern=r'Page \d+',
    header_parttern=r'Chapter \d+'
)
with open('cleaned_text.txt', 'w', encoding='utf-8') as file:
    file.write(cleaned_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       7             clean_text.append(line)
#       8         return '\n'.join(clean_text)
# ---> 10 text = open('data/raw.txt','r',encoding='utf-8').read()
#      11 cleaned_text = clean_headers_footers(
#      12     text,
#      13     footer_pattern=r'Page \d+',
#      14     header_parttern=r'Chapter \d+'
#      15 )
#      16 with open('cleaned_text.txt', 'w', encoding='utf-8') as file:
#
# File c:\Users\Sreylen\miniconda3\envs\lenenv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
# ...

# %%
import random 

with open('data/corpus.txt','r') as file:
    corpus = file.read().lower()
sentences = corpus.split('.')
random.shuffle(sentences)

train_split = int(0.7 * len(sentences))
val_split = int(0.8 * len(sentences))

train_set = sentences[:train_split]
val_set = sentences[train_split:val_split]
test_set = sentences[val_split:]
print(train_set)
# Out:
# ['\n\nthis vestibule is just as long as the palace; it opens upon a kind of\ncourt similar to the courts of our hotels', ' he at last succeeded in breaking\naway one of the lamps altogether, with a bit of the marble of the\nabacus; the whole falling in ruin to the pavement, and causing much\nconsultation and clamour among a tribe of beggars who were assisting\nthe sacristan with their wisdom respecting the festal arrangements', '9', ' but its chief interest centres in the sculptures\nexecuted by giovanni and andrea, sons and pupils of nicola pisano', '\nbefore it was that, it was a town of hindu temples and palaces', ' clinging like a limpet to the east angle of the keep is a\nsmaller tower twenty-eight feet square and about seventy-five feet\nhigh', ' you must work according to orders, and be\nobedient', ' when you come out into the sun and the cleaner dirt of the\ntown, you draw long breaths', ' this wall was fronted for the most\npart by houses in the street just mentioned, some o
# ...

# %%
from collections import Counter
import nltk
from nltk.tokenize import word_tokenize

tokens = word_tokenize(''.join(train_set))
vocab_size = 5000
token_counts = Counter(tokens)
vocab = {word for word, _ in token_counts.most_common(vocab_size)}

def replace_with_unk(data):
    return [
        [
            word if word in vocab else '<UNK>' for word in word_tokenize(sentence)]
            for sentence in data
    ]

train_tokens = replace_with_unk(train_set)
val_tokens = replace_with_unk(val_set)
test_tokens = replace_with_unk(test_set)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[25], line 5
#       2 import nltk
#       3 from nltk.tokenize import word_tokenize
# ----> 5 tokens = word_tokenize(''.join(train_set))
#       6 vocab_size = 5000
#       7 token_counts = Counter(tokens)
#
# File c:\Users\Sreylen\miniconda3\envs\lenenv\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
# ...
