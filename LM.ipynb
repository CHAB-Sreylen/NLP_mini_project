# %% [markdown]
# ### 1. Download dataset from wiki

# %%
import wikipediaapi

# Set up the Wikipedia API with a valid user-agent
wiki = wikipediaapi.Wikipedia(
    language="en", 
    user_agent="YourAppName/1.0 (your-email@example.com)"
)
# Fetch the article
topic = "Cambodia"
article = wiki.page(topic)

if article.exists():
    with open(f"./data/wiki_dataset.txt", "w", encoding="utf-8") as file:
        file.write(article.text)
    
else:
    print(f"The article '{topic}' does not exist.")

# %% [markdown]
# ### 2. Clean dataset

# %%
import re

def clean_wikipedia_text(text):
    # Remove citations like [1], [2][3], [citation needed]
    text = re.sub(r'\[[^\]]+\]', '', text)
    
    # Remove URLs
    text = re.sub(r'http[s]?://\S+', '', text)
    
    # Remove parenthetical information
    text = re.sub(r'\([^)]*\)', '', text)
    
    # Remove special formatting (e.g., ''italic'' or '''bold''')
    text = re.sub(r"''+|\<.*?\>", '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove lines starting with special characters (-, *, digits)
    text = '\n'.join(line for line in text.split('\n') if not line.strip().startswith(('-', '*', '1.')))
    
    return text

# Load text and clean
with open('data/wiki_dataset.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

cleaned_text = clean_wikipedia_text(raw_text)

# Save cleaned text
with open('data/cleaned_wiki_text.txt', 'w', encoding='utf-8') as file:
    file.write(cleaned_text)

# %% [markdown]
# ### 3. Spit data into 3 subset for training, testing and validation

# %%
import random
import re
from nltk.tokenize import word_tokenize, sent_tokenize

# Load and preprocess corpus
with open('data/cleaned_wiki_text.txt', 'r', encoding='utf-8') as file:
    # Convert to lowercase
    corpus = file.read()

# Clean up text: remove extra newlines and leading/trailing spaces
corpus = re.sub(r'\n+', ' ', corpus).strip()  
corpus = re.sub(r'\s+', ' ', corpus) 

# Split into sentences
sentences = sent_tokenize(corpus)

# Remove empty sentences
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

# Shuffle sentences
random.shuffle(sentences)

# Split into training, validation, and testing sets
train_split = int(0.7 * len(sentences))
val_split = int(0.8 * len(sentences))

train_set = sentences[:train_split]
val_set = sentences[train_split:val_split]
test_set = sentences[val_split:]

# Verify results
print(f"Total sentences: {len(sentences)}")
print(f"Training set: {len(train_set)} sentences")
print(f"Validation set: {len(val_set)} sentences")
print(f"Testing set: {len(test_set)} sentences")

# Optional: Save the sets to files for further use
with open('data/wiki_article/train_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(train_set) + '.')

with open('data/wiki_article/val_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(val_set) + '.')

with open('data/wiki_article/test_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(test_set) + '.')
# Out:
# Total sentences: 535
# Training set: 374 sentences
# Validation set: 54 sentences
# Testing set: 107 sentences

# %% [markdown]
# ### 4. Limit vocabulary size and replace with unknown

# %%
import re
from collections import Counter

# Tokenize
tokens = word_tokenize(' '.join(train_set))
vocab_size = 10000
token_counts = Counter(tokens)
vocab = {word for word, _ in token_counts.most_common(vocab_size)}

# Clean up unwanted characters
def clean_tokens(tokens):
    cleaned = []
    for sentence in tokens:
        cleaned_sentence = [re.sub(r'[^\w.]', '', word) for word in sentence]  # Keep only words and periods
        cleaned_sentence = [word for word in cleaned_sentence if word]  # Remove empty tokens
        cleaned.append(cleaned_sentence)
    return cleaned

# Replace words not in vocab with <UNK> and clean
def replace_with_unk(data):
    return [
        [word if word in vocab else '<UNK>' for word in word_tokenize(sentence)]
        for sentence in data
    ]

train_tokens = replace_with_unk(train_set)
val_tokens = replace_with_unk(val_set)
test_tokens = replace_with_unk(test_set)

# Clean the tokenized data
train_tokens = clean_tokens(train_tokens)
val_tokens = clean_tokens(val_tokens)
test_tokens = clean_tokens(test_tokens)

# Check results
print(train_tokens[:10])  # Show first 10 sentences from train_tokens
print(val_tokens[:10])    # Show first 10 sentences from val_tokens
print(test_tokens[:10])   # Show first 10 sentences from test_tokens
print(len(train_tokens))
# Out:
# [['Although', 'the', 'Vietnamese', 'language', 'has', 'been', 'determined', 'to', 'be', 'a', 'MonKhmer', 'language', 'there', 'are', 'very', 'few', 'cultural', 'connections', 'between', 'the', 'two', 'peoples', 'because', 'the', 'early', 'Khmers', 'were', 'influenced', 'by', 'the', 'Indian', 'cultural', 'sphere', 'while', 'the', 'Vietnamese', 'are', 'part', 'of', 'the', 'Chinese', 'cultural', 'sphere', '.'], ['The', 'rate', 'of', 'deforestation', 'in', 'Cambodia', 'is', 'one', 'of', 'the', 'highest', 'in', 'the', 'world', 'and', 'it', 'is', 'often', 'perceived', 'as', 'the', 'most', 'destructive', 'singular', 'environmental', 'issue', 'in', 'the', 'country', '.'], ['The', 'United', 'Nations', 'designates', 'Cambodia', 'as', 'a', 'least', 'developed', 'country', '.'], ['Around', 'the', '13th', 'century', 'Theravada', 'missionaries', 'from', 'Sri', 'Lanka', 'reintroduced', 'Theravada', 'Buddhism', 'to', 'Southeast', 'Asia', 'having', 'sent', 'missionaries', 'previously', 'in', 'the', '1190s', '.'], ['Most', 'of', 'the', 'victims', 'of', 'the', 'Khmer', 'Rouge', 'regime', 'were', 'not', 'ethnic', 'minorities', 'but', 'ethnic', 'Khmer', '.'], ['More', 'rural', 'forms', 'of', 'music', 'include', 'Chapei', 'and', 'Ayai', '.'], ['Known', 'formally', 'as', 'Robam', 'Preah', 'Reach', 'Troap', 'it', 'is', 'set', 'to', 'the', 'music', 'of', 'a', 'pinpeat', 'ensemble', 'accompanied', 'by', 'a', 'vocal', 'chorus', '.'], ['Western', 'sports', 'such', 'as', 'basketball', 'volleyball', 'bodybuilding', 'field', 'hockey', 'rugby', 'union', 'golf', 'and', 'baseball', 'are', 'gaining', 'popularity', '.'], ['Between', '1874', 'and', '1962', 'the', 'total', 'population', 'increased', 'from', 'about', '946000', 'to', '5.7', 'million', '.'], ['The', 'Khmer', 'Empire', 'was', 'Southeast', 'Asia', 's', 'largest', 'empire', 'during', 'the', '12th', 'century', '.']]
K', '.'], ['UNK', 'International', 'currently', 'recognises', 'one', 'UNK', 'of', 'UNK', 'in', 'the', 'country', 'UNK', 'land', 'rights', 'UNK', 'UNK', 'UNK', '.'], ['UNK', 'dances', 'are', 'those', 'performed', 'by', 'UNK', 'at', 'UNK', 'parties', 'or', 'other', 'UNK', 'social', 'UNK', '.'], ['UNK', 'UNK', 'organisations', 'UNK', 'that', 'UNK', 'people', 'have', 'been', 'UNK', 'affected', 'by', 'land', 'UNK', 'covering', 'at', 'least', 'UNK', 'million', 'hectares', 'of', 'land', 'that', 'have', 'been', 'confiscated', 'says', 'UNK', 'International', 'UNK', 'for', 'Human', 'Rights', '.']]
# 374

# %%
import pandas as pd 
from collections import Counter 
from nltk.tokenize import word_tokenize
from itertools import chain

flattened_tokens = list(chain.from_iterable(train_tokens))
word_counts = Counter(flattened_tokens)
tokens = word_tokenize(corpus.lower()) 
df = pd.DataFrame(word_counts.items(),columns=['word','Frequency'])
df = df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)

# Display the DataFrame
print(df)
for word, count in word_counts.items():
    print(f'{word}: {count}')
print(len(tokens))
# Out:
#                 word  Frequency
# 0                the        560
# 1                  .        374
# 2                 of        309
# 3                and        293
# 4                 in        211
# ...              ...        ...
# 2738      challenges          1
# 2739       continues          1
# 2740          marred          1
# 2741  reconstruction          1
# 2742      leadership          1
#
# [2743 rows x 2 columns]
# Although: 2
# the: 560
# Vietnamese: 18
# language: 8
# has: 41
# been: 18
# determined: 2
# to: 171
# be: 14
# a: 137
# MonKhmer: 2
# there: 8
# are: 57
# very: 2
# few: 2
# cultural: 3
# connections: 1
# between: 11
# two: 8
# peoples: 1
# because: 5
# early: 6
# Khmers: 3
# were: 21
# influenced: 3
# by: 75
# Indian: 4
# sphere: 2
# while: 7
# part: 7
# of: 309
# Chinese: 7
# .: 374
# The: 90
# rate: 6
# deforestation: 3
# in: 211
# Cambodia: 138
# is: 105
# one: 7
# highest: 2
# world: 14
# and: 293
# it: 12
# often: 7
# perceived: 1
# as: 66
# most: 16
# destructive: 1
# singular: 1
# environmental: 2
# issue: 1
# country: 39
# United: 8
# Nations: 7
# designates: 2
# least: 3
# developed: 3
# Around: 1
# 13th: 1
# century: 3
# Theravada: 5
# missionaries: 2
# from: 60
# Sri: 1
# Lanka: 1
# reintroduced: 2
# Buddhism: 8
# Southeast: 13
# Asia: 9
# having: 2
# sent: 1
# previously: 1
# 1190s: 1
# Most: 7
# victims: 2
# Khmer: 45
# Rouge: 16
# regime: 5
# not: 10
# ethnic: 7
# minorities: 1
# but: 9
# More: 1
# rural: 4
# forms: 2
# music: 10
# include: 11
# Chapei: 1
# Ayai: 1
# Known: 1
# formally: 1
# Robam: 1
# Preah: 4
# Reach: 1
# Troap: 1
# set: 3
# pinpeat: 1
# ensemble: 1
# accompanied: 1
# vocal: 1
# chorus: 1
# Western: 2
# sports: 4
# such: 9
# basketball: 1
# volleyball: 1
# bodybuilding: 1
# field: 2
# hockey: 1
# rugby: 1
# union: 1
# golf: 1
# baseball: 1
# gaining: 1
# popularity: 2
# Between: 1
# 1874: 1
# Canada: 1
# European: 1
# Japan: 1
# Russia: 1
# Planning: 1
# 2014: 1
# culmination: 1
# twoyear: 1
# supported: 1
# Korea: 1
# 2001: 1
# partnership: 1
# Labour: 1
# Organization: 1
# Finance: 1
# Corporation: 1
# Group: 1
# revised: 1
# prelude: 1
# reorganisation: 1
# 28: 1
# conference: 1
# held: 1
# appealed: 1
# I: 2
# appeal: 1
# you: 1
# publicise: 1
# abroad: 1
# stand: 1
# Cambodiathat: 1
# oppose: 1
# bombings: 1
# whatever: 1
# pretext: 1
# Court: 1
# Rescue: 2
# paving: 1
# return: 1
# yet: 1
# fatalities: 1
# 10000: 1
# vehicles: 1
# times: 1
# higher: 1
# doubled: 1
# preceding: 1
# 70th: 1
# peaceful: 1
# powersharing: 1
# agreement: 1
# agreed: 1
# Ministers: 1
# threatened: 1
# secede: 1
# transferred: 1
# wars: 1
# kingdoms: 1
# sacked: 1
# Ayutthaya: 1
# abandoned: 1
# 1432: 1
# ecological: 1
# failure: 1
# breakdown: 1
# interviews: 1
# prostitution: 1
# interviewees: 1
# prostitute: 1
# norm: 1
# felt: 1
# shameful: 1
# 2019: 1
# 88.5: 1
# literate: 1
# Women: 1
# 2.2: 1
# 3.3: 1
# landscape: 1
# characterised: 1
# lowlying: 1
# surrounded: 1
# uplands: 1
# low: 1
# reaches: 1
# delta: 1
# airports: 1
# An: 1
# prehistory: 1
# penetration: 1
# Extending: 1
# outward: 1
# transitional: 1
# plains: 1
# thinly: 1
# forested: 1
# rising: 1
# elevations: 1
# 650: 1
# feet: 1
# above: 1
# sea: 1
# Among: 1
# 65: 1
# 1.61: 1
# refusal: 1
# withdraw: 1
# sanctions: 1
# Institute: 1
# 750: 1
# seed: 1
# bank: 1
# temperatures: 1
# 40: 1
# Techo: 1
# intended: 1
# replace: 1
# Science: 2
# technology: 1
# Technology: 1
# representing: 1
# 11: 1
# centre: 1
# capitals: 1
# constructed: 1
# zenith: 1
# networks: 1
# separated: 1
# space: 1
# indicate: 1
# 2nd4th: 1
# AD: 1
# probably: 1
# changes: 1
# sociopolitical: 1
# allegations: 1
# voter: 1
# widespread: 1
# antigovernment: 1
# Fish: 1
# Tonlé: 1
# rivers: 1
# diet: 1
# original: 1
# 5: 1
# 2006: 1
# Southwest: 1
# blow: 1
# bringing: 1
# moistureladen: 1
# winds: 1
# Ocean: 1
# Killing: 1
# Fields: 1
# Tuol: 1
# Sleng: 1
# history: 1
# mass: 1
# killing: 1
# researchers: 1
# satellite: 1
# photographs: 1
# techniques: 1
# concluded: 1
# preindustrial: 1
# sprawl: 1
# 2980: 1
# leadership: 1
# 12753

# %% [markdown]
# ### 5. Create two language model

# %%
from collections import defaultdict
def build_ngram_model(data, n):
    model = defaultdict(lambda: defaultdict(int))
    for sentence in data:
        for i in range(len(sentence) - n + 1):
            ngram = tuple(sentence[i:i+n])
            prefix, token = ngram[:-1], ngram[-1]
            model[prefix][token] += 1
    return model

# Build the LM1 Backoff mothod
def backoff_prob(model, ngram):
    prefix, token = ngram[:-1], ngram[-1]
    if prefix in model and sum(model[prefix].values()) > 0:
        if token in model[prefix]:
            return model[prefix][token] / sum(model[prefix].values())
    elif len(prefix) > 1:
        return backoff_prob(model, prefix[1:] + (token,))
    return 0  # Default probability if no valid prefix or tokens

ngram_model = build_ngram_model(train_tokens, 4)

# Build the LM2 interpolated method
def interpolated_prob(model, ngram, lambdas, k):
    n = len(ngram)
    prob = 0
    for i in range(1, n+1):
        prefix, token = ngram[:i-1], ngram[i-1]
        count = model[prefix][token] + k
        total_count = sum(model[prefix].values()) + k * vocab_size
        prob += lambdas[i-1] * (count / total_count)
    return prob

lambdas = [0.1, 0.2, 0.3, 0.4]  # Example weights
k = 0.001  # Example smoothing parameter

# %% [markdown]
# ### 6. Evaluation with perplexity on both model

# %%
import math
import numpy as np

def perplexity(model, tokens, prob_func):
    log_prob_sum = 0
    total_tokens = 0
    
    for sentence in tokens:
        for i in range(3, len(sentence)):
            # Create n-gram
            ngram = tuple(sentence[i-3:i+1])
            
            try:
                # Calculate probability
                prob = prob_func(model, ngram)
                
                # Handle zero or negative probabilities
                if prob <= 0:
                    prob = 1e-10  # Small positive value
                
                # Sum log probabilities
                log_prob = math.log2(prob)
                log_prob_sum += log_prob
                total_tokens += 1
            
            except Exception as e:
                print(f"Error processing n-gram {ngram}: {e}")
                continue
    
    # Avoid division by zero
    if total_tokens == 0:
        return float('inf')
    
    # Calculate perplexity
    perplexity_score = 2 ** (-log_prob_sum / total_tokens)
    
    return perplexity_score

pp_lm1 = perplexity(model=ngram_model, tokens=test_tokens, prob_func=backoff_prob)
pp_lm2 = perplexity(ngram_model, test_tokens, lambda m, n: interpolated_prob(m, n, lambdas, k))

print(f"pp_lm1: {pp_lm1}")
print(f"pp_lm2: {pp_lm2}")
# Out:
# pp_lm1: 6265007384.971368
# pp_lm2: 8831.92108133984

# %% [markdown]
# ### 7. Generating text using both model

# %%
import random

def generate_text(model, start, length, prob_func):
    text = list(start)
    for _ in range(length - len(start)):
        prefix = tuple(text[-3:])
        if prefix not in model or not model[prefix] or sum(model[prefix].values()) == 0:
            next_words = random.choice(train_tokens)[:3]
            for next_word in next_words:
                text.append(next_word)
        else:
            next_word = max(model[prefix], key=lambda x: prob_func(model, prefix + (x,)))
            text.append(next_word)
    return ' '.join(text)


start_tokens = list(random.choice(train_tokens)[:3])
backoff_text = generate_text(ngram_model, start_tokens, 50, backoff_prob)
# start_tokens = list(random.choice(train_tokens)[:3])
interpolation_text = generate_text(ngram_model, start_tokens, 50, lambda m, n: interpolated_prob(m, n, lambdas, k))
print(f"Backoff Model: {backoff_text}")
print(f"Interpolation Model: {interpolation_text}")
# Out:
# Backoff Model: Known formally as Robam Preah Reach Troap it is set to the music of a pinpeat ensemble accompanied by a vocal chorus . Archived from the original on 5 October 2006 . It was fully beholden to the occupying Vietnamese army and under the direction of the Vietnamese ambassador to Phnom Penh . The English Cambodia
# Interpolation Model: Known formally as Robam Preah Reach Troap it is set to the music of a pinpeat ensemble accompanied by a vocal chorus . The Worldwide Fund for Nature recognises six distinct terrestrial ecoregions in Cambodia the Cardamom Mountains rain forests Central Indochina dry forest Southeast Indochina dry evergreen forest Southern Annamite Range
