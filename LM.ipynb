# %% [markdown]
# 1. Clean data

# %%
import re

def clean_wikipedia_text(text):
    # Remove citations like [1], [2][3], [citation needed]
    text = re.sub(r'\[[^\]]+\]', '', text)
    
    # Remove URLs
    text = re.sub(r'http[s]?://\S+', '', text)
    
    # Remove parenthetical information
    text = re.sub(r'\([^)]*\)', '', text)
    
    # Remove special formatting (e.g., ''italic'' or '''bold''')
    text = re.sub(r"''+|\<.*?\>", '', text)
    
    
    
    # Remove lines starting with special characters (-, *, digits)
    text = '\n'.join(line for line in text.split('\n') if not line.strip().startswith(('-', '*', '1.')))
    
    return text

# Load text and clean
with open('data/wiki_dataset.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

cleaned_text = clean_wikipedia_text(raw_text)

# Save cleaned text
with open('data/cleaned_wiki_text.txt', 'w', encoding='utf-8') as file:
    file.write(cleaned_text)

# %%
import nltk
nltk.download('punkt')
nltk.data.path.append('C:/Users/Sreylen/AppData/Roaming/nltk_data')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sreylen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Sreylen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# 2. Spit data into 3 subset for training, testing and validation

# %%
import random
import re

# Load and preprocess corpus
with open('data/cleaned_wiki_text.txt', 'r') as file:
    # Convert to lowercase
    corpus = file.read()

# Clean up text: remove extra newlines and leading/trailing spaces
# corpus = re.sub(r'\n+', ' ', corpus).strip()  # Replace multiple newlines with a space
# corpus = re.sub(r'\s+', ' ', corpus) 
 # Replace multiple spaces with a single space

# Split into sentences
sentences = corpus.split('.')

# Remove empty sentences
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

# Shuffle sentences
random.shuffle(sentences)

# Split into training, validation, and testing sets
train_split = int(0.7 * len(sentences))
val_split = int(0.8 * len(sentences))
# val_split = int(0.1 * len(sentences))


train_set = sentences[:train_split]
val_set = sentences[train_split:val_split]
test_set = sentences[val_split:]

# Verify results
print(f"Total sentences: {len(sentences)}")
print(f"Training set: {len(train_set)} sentences")
print(f"Validation set: {len(val_set)} sentences")
print(f"Testing set: {len(test_set)} sentences")

# Optional: Save the sets to files for further use
with open('data/wiki_article/train_set.txt', 'w') as file:
    file.write('. '.join(train_set) + '.')

with open('data/wiki_article/val_set.txt', 'w') as file:
    file.write('. '.join(val_set) + '.')

with open('data/wiki_article/test_set.txt', 'w') as file:
    file.write('. '.join(test_set) + '.')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 7
#       4 # Load and preprocess corpus
#       5 with open('data/cleaned_wiki_text.txt', 'r') as file:
#       6     # Convert to lowercase
# ----> 7     corpus = file.read()
#       9 # Clean up text: remove extra newlines and leading/trailing spaces
#      10 # corpus = re.sub(r'\n+', ' ', corpus).strip()  # Replace multiple newlines with a space
#      11 # corpus = re.sub(r'\s+', ' ', corpus)
#      12  # Replace multiple spaces with a single space
#      13
#      14 # Split into sentences
#      15 sentences = corpus.split('.')
#
# File c:\Users\Sreylen\miniconda3\envs\lenenv\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 2808: character maps to <undefined>

# %%
import re
from nltk.tokenize import word_tokenize
from collections import Counter

# Tokenize
tokens = word_tokenize(' '.join(train_set))
vocab_size = 20000 # Limit vocabulary size
token_counts = Counter(tokens)
vocab = {word for word, _ in token_counts.most_common(vocab_size)}

# Clean up unwanted characters
def clean_tokens(tokens):
    cleaned = []
    for sentence in tokens:
        cleaned_sentence = [re.sub(r'[^\w.]', '', word) for word in sentence]  # Keep only words and periods
        cleaned_sentence = [word for word in cleaned_sentence if word]  # Remove empty tokens
        cleaned.append(cleaned_sentence)
    return cleaned

# Replace words not in vocab with <UNK> and clean
def replace_with_unk(data):
    return [
        [word if word in vocab else '<UNK>' for word in word_tokenize(sentence)]
        for sentence in data
    ]

train_tokens = replace_with_unk(train_set)
val_tokens = replace_with_unk(val_set)
test_tokens = replace_with_unk(test_set)

# Clean the tokenized data
train_tokens = clean_tokens(train_tokens)
val_tokens = clean_tokens(val_tokens)
test_tokens = clean_tokens(test_tokens)
length_tokens=len(tokens)
# Check results
print(train_tokens[:10])  # Show first 10 sentences from train_tokens
print(length_tokens)
print(val_tokens[:10])    # Show first 10 sentences from val_tokens
print(test_tokens[:10])   # Show first 10 sentences from test_tokens
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 from collections import Counter
#       5 # Tokenize
# ----> 6 tokens = word_tokenize(' '.join(train_set))
#       7 vocab_size = 20000 # Limit vocabulary size
#       8 token_counts = Counter(tokens)
#
# NameError: name 'train_set' is not defined

# %%
import pandas as pd 
from collections import Counter 
from nltk.tokenize import word_tokenize
from itertools import chain
# for i in train_tokens:
#     train_corpus = train_tokens[i]+1
# print(train_corpus)
flattened_tokens = list(chain.from_iterable(train_tokens))
word_counts = Counter(flattened_tokens)
tokens = word_tokenize(corpus.lower()) 
df = pd.DataFrame(word_counts.items(),columns=['word','Frequency'])
df = df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)

# Display the DataFrame
print(df)
for word, count in word_counts.items():
    print(f'{word}: {count}')
# Out:
#               word  Frequency
# 0              the        636
# 1               of        331
# 2              and        294
# 3               in        256
# 4               to        159
# ...            ...        ...
# 2594       decided          1
# 2595      withdrew          1
# 2596  francophonie          1
# 2597            la          1
# 2598         added          1
#
# [2599 rows x 2 columns]
# siem: 11
# reapangkor: 1
# international: 25
# airport: 8
# is: 93
# the: 636
# second: 5
# busiest: 2
# and: 294
# serves: 2
# most: 20
# flights: 1
# in: 256
# out: 3
# of: 331
# cambodia: 151
# shortages: 1
# clean: 1
# water: 4
# extreme: 1
# flooding: 1
# mudslides: 1
# higher: 2
# sea: 3
# levels: 4
# potentially: 1
# destructive: 2
# storms: 1
# are: 52
# particular: 4
# concern: 1
# according: 5
# to: 159
# climate: 9
# change: 6
# alliance: 1
# simultaneous: 1
# attacks: 3
# around: 9
# perimeter: 1
# phnom: 25
# penh: 21
# pinned: 1
# down: 2
# republican: 1
# forces: 7
# while: 11
# other: 16
# cpk: 1
# units: 2
# overran: 2
# fire: 1
# bases: 1
# controlling: 1
# vital: 1
# lower: 3
# mekong: 13
# resupply: 1
# route: 1
# legal: 4
# profession: 2
# cambodian: 49
# was: 61
# established: 5
# 1932: 1
# 2012: 3
# credit: 1
# bureau: 1
# with: 53
# direct: 2
# regulatory: 3
# oversight: 2
# by: 78
# national: 25
# bank: 8
# cham: 7
# descended: 2
# from: 50
# austronesian: 2
# people: 21
# champa: 1
# a: 149
# former: 5
# kingdom: 13
# on: 39
# coast: 1
# central: 5
# southern: 5
# presentday: 1
# vietnam: 12
# rival: 1
# khmer: 53
# empire: 9
# has: 34
# two: 11
# major: 7
# ports: 1
# sihanoukville: 5
# five: 3
# minor: 2
# ones: 1
# 1997: 4
# fearing: 1
# growing: 3
# power: 14
# his: 17
# coprime: 3
# minister: 14
# prince: 1
# norodom: 9
# ranariddh: 5
# hun: 19
# launched: 4
# coup: 5
# using: 3
# army: 4
# purge: 1
# supporters: 1
# judges: 1
# lawyers: 3
# were: 30
# executed: 1
# after: 13
# being: 5
# deemed: 1
# class: 1
# enemies: 2
# only: 4
# 612: 1
# professionals: 2
# actually: 1
# survived: 1
# remained: 1
# country: 35
# among: 4
# population: 21
# aged: 1
# over: 12
# 65: 2
# female: 4
# male: 4
# ratio: 3
# 1: 11
# scholar: 1
# george: 1
# coedes: 2
# refers: 1
# 10thcentury: 1
# inscription: 1
# dynastic: 1
# legend: 2
# which: 28
# hermit: 1
# kambu: 2
# swayambhuva: 2
# celestial: 1
# nymph: 1
# mera: 1
# unite: 1
# establish: 1
# solar: 3
# royal: 5
# dynasty: 2
# that: 35
# begins: 2
# chenla: 2
# ruler: 2
# srutavarman: 1
# son: 4
# sreshthavarman: 1
# modern: 5
# western: 5
# popular: 13
# dances: 7
# including: 8
# chacha: 1
# bolero: 1
# madison: 1
# have: 21
# also: 17
# influenced: 3
# social: 6
# dance: 13
# culture: 4
# as: 66
# developed: 4
# spread: 4
# distinctive: 1
# styles: 3
# architecture: 3
# sculpture: 1
# been: 20
# exchanged: 1
# neighbouring: 2
# laos: 6
# thailand: 13
# throughout: 3
# history: 2
# s: 67
# extensive: 3
# inland: 1
# waterways: 1
# important: 6
# historically: 1
# trade: 3
# older: 2
# generation: 1
# often: 8
# solo: 1
# performance: 3
# man: 1
# plucking: 1
# guitar: 1
# between: 15
# cappella: 1
# verses: 1
# tra: 2
# leaf: 1
# books: 2
# record: 2
# legends: 1
# ramayana: 2
# origin: 2
# buddhism: 8
# prayer: 1
# public: 6
# sihanouk: 18
# refuted: 1
# right: 2
# u: 1
# under: 14
# reign: 2
# king: 14
# gained: 4
# independence: 2
# france: 2
# 9: 3
# november: 5
# 1953: 3
# party: 14
# sole: 2
# dominantparty: 1
# centre: 1
# angkor: 10
# where: 5
# series: 4
# capitals: 1
# constructed: 1
# during: 18
# zenith: 1
# exact: 1
# origins: 2
# classical: 5
# disputed: 4
# islam: 1
# followed: 3
# about: 9
# 2: 12
# comes: 2
# three: 5
# varieties: 3
# practised: 3
# third: 2
# descendants: 1
# malays: 1
# resident: 1
# for: 53
# generations: 1
# respect: 2
# academic: 1
# primary: 7
# school: 1
# children: 9
# research: 6
# showed: 2
# parental: 1
# attitudes: 1
# beliefs: 2
# played: 1
# significant: 6
# role: 3
# arrivals: 2
# 2018: 6
# chinese: 6
# these: 2
# had: 7
# collected: 1
# 1960s: 3
# consistently: 1
# listed: 1
# one: 12
# corrupt: 2
# governments: 1
# world: 14
# examples: 2
# areas: 7
# cambodians: 10
# encounter: 1
# practices: 4
# their: 14
# everyday: 1
# lives: 2
# include: 9
# obtaining: 2
# medical: 1
# services: 4
# dealing: 1
# alleged: 1
# traffic: 2
# violations: 1
# pursuing: 1
# fair: 1
# court: 4
# verdicts: 1
# december: 2
# 2021: 2
# sen: 15
# announced: 3
# support: 4
# manet: 4
# succeed: 1
# him: 4
# next: 1
# general: 7
# election: 13
# 2023: 6
# 2010: 4
# number: 5
# regulated: 1
# banks: 1
# microfinance: 1
# institutions: 4
# increased: 4
# 31: 1
# covered: 3
# entities: 2
# 70: 2
# individual: 1
# underlining: 1
# growth: 5
# within: 4
# banking: 2
# finance: 3
# sector: 8
# year: 9
# 2015: 3
# 100: 1
# forest: 9
# area: 9
# reported: 5
# be: 17
# ownership: 1
# main: 24
# article: 14
# tourism: 7
# every: 2
# nearly: 2
# open: 1
# doors: 1
# new: 9
# investment: 6
# yielded: 1
# access: 2
# coterie: 1
# cronies: 1
# wife: 1
# bun: 1
# rany: 1
# megha: 1
# bahree: 1
# writer: 1
# forbes: 1
# form: 4
# stylised: 1
# art: 1
# courts: 2
# exhibited: 1
# both: 3
# entertainment: 1
# ceremonial: 1
# purposes: 2
# peace: 6
# efforts: 2
# began: 5
# paris: 4
# 1989: 1
# state: 11
# culminating: 1
# years: 10
# later: 3
# october: 2
# 1991: 3
# comprehensive: 1
# settlement: 1
# stability: 2
# following: 3
# conflict: 1
# shaken: 1
# détat: 2
# led: 5
# who: 3
# ousted: 1
# parties: 2
# represented: 2
# government: 18
# consolidated: 2
# cpp: 5
# 1874: 1
# 1962: 4
# total: 2
# 946000: 1
# 5: 7
# lon: 1
# nol: 1
# surrendered: 1
# 17: 3
# april: 4
# 1975: 3
# days: 2
# us: 12
# mission: 2
# evacuated: 1
# te: 2
# krolap: 1
# strong: 1
# tea: 7
# made: 3
# putting: 1
# mass: 3
# leaves: 2
# into: 10
# small: 1
# glass: 2
# placing: 1
# saucer: 1
# top: 3
# turning: 1
# whole: 1
# thing: 1
# upside: 1
# brew: 1
# currently: 4
# commands: 1
# 120: 1
# 125: 1
# seats: 3
# assembly: 5
# 55: 1
# 62: 1
# senate: 5
# 88: 2
# 2019: 4
# 15552211: 1
# 0: 6
# 2024: 2
# became: 5
# president: 6
# gives: 1
# sign: 2
# off: 3
# laws: 1
# absence: 1
# fear: 1
# renewed: 1
# political: 12
# instability: 2
# corruption: 4
# discourage: 1
# foreign: 11
# delay: 1
# aid: 2
# although: 6
# there: 12
# bilateral: 1
# multilateral: 1
# donors: 1
# east: 2
# transitional: 2
# plains: 1
# gradually: 1
# merge: 1
# eastern: 2
# highlands: 3
# region: 7
# forested: 1
# mountains: 6
# high: 4
# plateaus: 1
# extend: 1
# 4: 7
# billion: 4
# accounting: 2
# almost: 2
# ten: 3
# per: 9
# cent: 4
# gross: 1
# product: 1
# 14: 4
# 2004: 4
# sihamoni: 2
# selected: 1
# special: 2
# ninemember: 1
# throne: 1
# council: 1
# part: 10
# selection: 1
# process: 2
# quickly: 1
# put: 2
# place: 3
# abdication: 1
# week: 2
# prior: 1
# officially: 1
# multiparty: 3
# democracy: 4
# reality: 1
# remain: 4
# oneparty: 2
# dominated: 3
# prime: 10
# recast: 1
# rouge: 20
# official: 8
# since: 9
# 1985: 3
# constitutionally: 1
# dominates: 1
# system: 10
# dissolved: 2
# its: 16
# opposition: 9
# 2017: 3
# making: 2
# it: 27
# de: 2
# facto: 2
# 3: 9
# largest: 5
# ethnic: 11
# group: 3
# khmers: 3
# indigenous: 1
# lowland: 3
# subregion: 3
# they: 8
# inhabit: 1
# typically: 1
# fasterpaced: 1
# than: 8
# folk: 6
# display: 1
# themes: 1
# common: 1
# person: 1
# such: 8
# love: 1
# comedy: 1
# or: 16
# warding: 1
# evil: 1
# spirits: 4
# seven: 2
# reporters: 1
# sustained: 2
# injuries: 2
# at: 16
# least: 5
# protesters: 2
# hit: 1
# slingshot: 1
# projectiles: 1
# hospitalized: 1
# performed: 4
# mahori: 1
# music: 10
# celebrates: 1
# various: 4
# cultural: 4
# groups: 7
# close: 1
# interrelationship: 1
# community: 1
# efficacy: 1
# apotropaic: 1
# luckattracting: 1
# actions: 2
# charms: 1
# possibility: 1
# manipulating: 1
# life: 2
# through: 6
# contact: 1
# spiritual: 1
# baromey: 1
# originates: 1
# native: 4
# religion: 7
# rural: 4
# wear: 1
# krama: 1
# scarf: 1
# unique: 3
# aspect: 1
# clothing: 1
# food: 4
# stands: 2
# reap: 10
# oil: 2
# natural: 2
# gas: 1
# deposits: 1
# found: 4
# beneath: 2
# territorial: 2
# waters: 1
# 2005: 1
# yield: 1
# great: 1
# potential: 3
# but: 12
# mostly: 2
# untapped: 1
# due: 6
# disputes: 2
# this: 14
# section: 1
# needs: 2
# updated: 1
# mao: 1
# zedong: 1
# 1956: 2
# 1955: 1
# abdicated: 1
# favour: 1
# father: 2
# participate: 1
# politics: 4
# elected: 3
# municipalities: 2
# districts: 2
# secondlevel: 1
# administrative: 1
# divisions: 1
# control: 2
# territory: 3
# vietnamese: 17
# communists: 3
# imposed: 1
# infrastructure: 4
# eventually: 2
# now: 5
# referred: 2
# newly: 1
# created: 3
# governmentinexile: 1
# coalition: 2
# democratic: 3
# kampuchea: 6
# formed: 2
# 1981: 1
# factions: 1
# french: 10
# remnant: 1
# colonial: 1
# past: 2
# dialect: 1
# sometimes: 1
# used: 1
# particularly: 4
# religious: 5
# targeted: 2
# kampot: 4
# pepper: 2
# reputed: 1
# best: 1
# accompanies: 1
# crab: 2
# kep: 2
# shacks: 1
# squid: 1
# restaurants: 1
# ou: 1
# trojak: 1
# jet: 1
# river: 6
# köppen: 1
# classification: 1
# map: 5
# like: 3
# rest: 2
# southeast: 11
# asia: 5
# monsoons: 2
# known: 7
# tropical: 3
# wet: 2
# dry: 5
# because: 4
# distinctly: 1
# marked: 1
# seasonal: 1
# differences: 1
# archaeological: 3
# records: 1
# period: 8
# holocene: 2
# iron: 3
# age: 5
# equally: 1
# limited: 1
# 212: 1
# mammal: 1
# species: 6
# 536: 1
# bird: 1
# 240: 1
# reptile: 1
# 850: 1
# freshwater: 1
# fish: 7
# 435: 1
# marine: 1
# recorded: 2
# science: 3
# 2013: 5
# results: 2
# leading: 3
# demonstrations: 1
# capital: 3
# saw: 1
# defence: 2
# ministry: 4
# subordinate: 1
# departments: 1
# responsible: 6
# logistics: 2
# materials: 1
# technical: 1
# command: 3
# headquarters: 1
# based: 3
# economist: 1
# imf: 1
# annual: 4
# average: 5
# gdp: 4
# 20012010: 1
# 7: 5
# documents: 1
# uncovered: 1
# soviet: 1
# archives: 1
# reveal: 1
# north: 6
# attempt: 1
# overrun: 1
# 1970: 4
# explicit: 1
# request: 1
# negotiated: 1
# pol: 2
# pot: 2
# then: 3
# nuon: 2
# chea: 2
# lemon: 3
# kdau: 1
# kroch: 1
# chhma: 1
# reddust: 1
# juice: 1
# refreshing: 1
# hot: 1
# iced: 1
# generally: 2
# served: 1
# hefty: 1
# dose: 1
# sugar: 2
# agriculture: 8
# further: 5
# information: 5
# mainstay: 1
# economy: 1
# remains: 2
# continued: 2
# leadership: 1
# anticorruption: 1
# law: 3
# provided: 2
# no: 3
# protection: 2
# whistleblowers: 2
# can: 7
# jailed: 1
# up: 5
# 6: 7
# months: 1
# if: 3
# report: 3
# not: 10
# proven: 1
# scholars: 1
# trace: 2
# forms: 1
# back: 3
# time: 3
# seeing: 1
# similarities: 1
# temple: 2
# engravings: 1
# others: 4
# hold: 1
# learned: 1
# siamese: 2
# dancers: 3
# 1800s: 1
# textiles: 2
# garment: 4
# industry: 6
# represents: 1
# portion: 1
# manufacturing: 1
# 80: 3
# exports: 5
# crooner: 1
# sinn: 3
# sisamouth: 3
# ros: 2
# sereysothea: 1
# pen: 1
# ran: 1
# 1970s: 3
# considered: 4
# classic: 3
# pop: 3
# prostitution: 1
# illegal: 2
# yet: 2
# appears: 1
# prevalent: 2
# determined: 2
# keep: 1
# disenfranchise: 1
# any: 2
# threats: 1
# thus: 2
# violent: 2
# aggressive: 1
# against: 4
# sports: 8
# basketball: 1
# volleyball: 2
# bodybuilding: 1
# field: 3
# hockey: 1
# rugby: 1
# union: 3
# golf: 1
# baseball: 1
# gaining: 1
# popularity: 1
# language: 8
# monkhmer: 3
# very: 2
# few: 2
# connections: 1
# peoples: 1
# early: 5
# indian: 2
# sphere: 2
# human: 8
# rights: 11
# deputy: 2
# leader: 2
# kem: 1
# sokha: 1
# arrested: 1
# september: 2
# sam: 1
# rainsy: 1
# lived: 1
# exile: 1
# coastal: 3
# city: 5
# won: 2
# funcinpec: 2
# hung: 1
# parliament: 3
# ministries: 1
# 33: 2
# universities: 3
# majority: 5
# come: 4
# umbrella: 1
# education: 16
# youth: 4
# toasted: 2
# baguette: 2
# pieces: 1
# dipped: 1
# curry: 3
# eaten: 1
# victims: 3
# regime: 7
# minorities: 1
# some: 13
# delicacies: 1
# num: 2
# banhchok: 2
# amok: 1
# aping: 1
# etymology: 1
# names: 1
# english: 5
# name: 3
# an: 19
# event: 2
# prehistory: 1
# penetration: 1
# first: 8
# rice: 11
# farmers: 2
# millennium: 2
# bc: 4
# increasing: 4
# economic: 6
# activity: 1
# increase: 2
# automobile: 1
# use: 3
# though: 2
# motorcycles: 1
# still: 3
# predominate: 1
# institute: 3
# reintroduced: 2
# more: 10
# 750: 1
# traditional: 8
# seed: 1
# philippines: 2
# lowest: 1
# women: 4
# contributing: 1
# overall: 1
# b: 1
# bokor: 1
# hill: 3
# station: 1
# interest: 1
# visitors: 1
# wine: 1
# alcoholic: 1
# drink: 2
# july: 3
# ruling: 1
# easily: 1
# landslide: 1
# flawed: 1
# disqualification: 1
# candlelight: 1
# did: 1
# reappear: 1
# until: 5
# 1995: 1
# when: 9
# bar: 1
# association: 1
# households: 1
# depend: 1
# related: 1
# subsectors: 1
# highly: 2
# vulnerable: 2
# negative: 1
# effects: 2
# advised: 1
# focuses: 1
# developing: 2
# renewable: 5
# energy: 7
# mitigation: 1
# measures: 1
# plans: 2
# quality: 3
# healthcare: 1
# raising: 1
# awareness: 1
# hivaids: 1
# malaria: 1
# diseases: 1
# 2000: 3
# what: 2
# become: 1
# absorbed: 1
# influences: 1
# india: 3
# passing: 1
# them: 2
# asian: 8
# civilisations: 1
# war: 10
# extended: 1
# 1965: 1
# via: 3
# ho: 2
# chi: 2
# minh: 2
# trails: 1
# constitution: 2
# promulgates: 1
# free: 2
# compulsory: 1
# nine: 2
# guaranteeing: 1
# universal: 1
# basic: 2
# isolated: 2
# loeu: 2
# indianized: 1
# cousins: 1
# consequently: 1
# culturally: 2
# distant: 1
# each: 2
# observing: 1
# many: 8
# preindiancontact: 1
# customs: 1
# sampeah: 1
# greeting: 1
# way: 2
# showing: 1
# employs: 2
# 335400: 1
# workers: 4
# 91: 1
# 95: 2
# buddhist: 1
# temples: 4
# destroyed: 2
# road: 4
# fatalities: 1
# 10000: 1
# vehicles: 1
# times: 1
# deaths: 2
# doubled: 1
# preceding: 1
# famous: 1
# singer: 2
# dates: 2
# far: 2
# progressed: 2
# adopted: 1
# policy: 5
# neutrality: 1
# cold: 1
# viet: 1
# cong: 1
# desperate: 1
# retain: 1
# sanctuaries: 3
# supply: 3
# lines: 2
# armed: 3
# challenges: 2
# facing: 1
# fact: 1
# lacks: 1
# countryside: 1
# suffers: 1
# lack: 3
# issued: 1
# 150: 2
# licenses: 2
# before: 4
# same: 3
# message: 1
# conveyed: 1
# johnson: 1
# emissary: 1
# chester: 1
# bowles: 1
# january: 1
# 1968: 1
# spans: 1
# 181035: 2
# square: 2
# kilometres: 5
# million: 12
# 79: 1
# 1994: 1
# 9900000: 1
# fertility: 1
# highest: 3
# mondol: 1
# kiri: 2
# rattanak: 1
# provinces: 5
# 56: 1
# colloquially: 2
# refer: 1
# either: 2
# srok: 1
# slightly: 1
# formal: 1
# បរទសកមពជ: 1
# literate: 1
# pchum: 2
# ben: 2
# ancestors: 2
# day: 2
# festival: 3
# celebrated: 1
# buddhists: 1
# geography: 2
# geographic: 1
# regional: 1
# lies: 1
# entirely: 1
# tropics: 1
# latitudes: 1
# 10: 4
# 15n: 1
# longitudes: 1
# 102: 1
# 108e: 1
# accords: 1
# formally: 2
# ended: 1
# governed: 1
# united: 6
# nations: 6
# recent: 2
# artistic: 1
# figures: 1
# singers: 3
# serey: 2
# sothea: 1
# introduced: 1
# musical: 1
# wat: 4
# bestpreserved: 1
# example: 1
# angkorian: 2
# era: 3
# along: 3
# hundreds: 2
# discovered: 3
# sport: 2
# football: 2
# professional: 1
# organised: 3
# countries: 6
# conditions: 1
# un: 6
# designates: 2
# cuisine: 4
# contains: 1
# fruits: 3
# soups: 1
# noodles: 1
# vast: 2
# speakers: 3
# response: 2
# invasion: 1
# richard: 1
# nixon: 1
# south: 4
# ground: 1
# entered: 1
# campaign: 1
# aimed: 1
# destroying: 1
# nva: 2
# base: 1
# influencing: 1
# business: 2
# factory: 1
# data: 1
# highlight: 1
# improvement: 1
# core: 1
# risk: 2
# management: 2
# strategies: 1
# brandsbuyers: 1
# paddy: 1
# province: 11
# provides: 1
# jobs: 1
# key: 4
# ingredients: 1
# kaffir: 1
# lime: 1
# grass: 1
# garlic: 1
# sauce: 3
# soy: 1
# tamarind: 1
# ginger: 1
# oyster: 1
# coconut: 1
# milk: 2
# black: 1
# networks: 2
# separated: 1
# space: 1
# indicate: 1
# shift: 1
# network: 1
# 2nd4th: 1
# century: 3
# ad: 2
# probably: 1
# changes: 1
# sociopolitical: 1
# powers: 2
# die: 1
# muslim: 1
# signed: 1
# treaty: 1
# prohibition: 1
# nuclear: 1
# weapons: 1
# heavily: 2
# decentralised: 1
# provincial: 1
# district: 1
# prehistoric: 1
# evidence: 4
# circular: 2
# earthworks: 2
# red: 3
# soils: 1
# near: 1
# memot: 1
# adjacent: 3
# latter: 1
# 1950s: 1
# ensuring: 1
# receive: 1
# correct: 1
# wages: 1
# benefits: 1
# d: 1
# dominant: 1
# construction: 3
# garments: 2
# 15day: 1
# offer: 1
# prayers: 1
# dead: 1
# relatives: 1
# member: 5
# la: 1
# francophonie: 1
# withdrew: 1
# 1993: 4
# decided: 1
# 90: 2
# registered: 1
# voters: 1
# followers: 2
# instituted: 1
# cult: 1
# godking: 1
# conquests: 1
# flourished: 1
# 9th: 1
# 15th: 2
# centuries: 1
# tourists: 4
# visit: 2
# compared: 2
# continues: 1
# face: 2
# improvements: 1
# especially: 2
# terms: 3
# net: 1
# enrolment: 1
# gains: 1
# introduction: 2
# program: 1
# basedbudgeting: 1
# development: 9
# framework: 3
# helps: 1
# disadvantaged: 1
# gain: 2
# 20102015: 1
# rate: 4
# deforestation: 4
# tonle: 8
# sap: 10
# numerous: 3
# tributaries: 1
# avenues: 1
# considerable: 1
# length: 1
# 3700: 1
# navigable: 2
# all: 6
# craft: 2
# drawing: 2
# expected: 2
# land: 10
# mines: 2
# 2025: 1
# legacy: 2
# orphans: 1
# 290: 1
# amputee: 1
# affect: 1
# settlements: 1
# baksei: 1
# chamkrong: 1
# site: 6
# lovea: 1
# northwest: 3
# consisted: 1
# royalist: 1
# faction: 1
# liberation: 1
# front: 1
# boat: 4
# racing: 3
# buffalo: 1
# pradal: 1
# wrestling: 1
# bokator: 1
# indochina: 1
# 1760: 1
# tribe: 1
# hunted: 1
# incessantly: 1
# carried: 2
# slaves: 1
# annamites: 1
# military: 3
# spending: 1
# urban: 2
# dwellers: 1
# engaged: 1
# primarily: 1
# commerce: 1
# estimated: 4
# 100000: 2
# sex: 2
# pagodas: 1
# across: 3
# mark: 1
# worked: 1
# 500: 1
# supporting: 2
# coming: 1
# khorat: 1
# plateau: 1
# regular: 1
# rail: 2
# cities: 4
# restarted: 1
# recently: 2
# offering: 1
# safer: 1
# option: 1
# travellers: 1
# woman: 2
# vowed: 1
# rule: 3
# he: 3
# turned: 1
# 74: 1
# 1980s: 2
# commodity: 2
# sources: 1
# exchange: 2
# metres: 1
# another: 4
# 282: 1
# secondlargest: 1
# minority: 2
# 16000: 1
# living: 1
# concentrated: 1
# delta: 3
# unbacked: 1
# crimes: 3
# tribunal: 3
# sought: 1
# investigate: 2
# committed: 2
# prosecute: 1
# leaders: 3
# kinds: 1
# beads: 1
# recovered: 1
# sites: 1
# phum: 1
# snay: 1
# prohear: 1
# suggest: 1
# trading: 1
# densely: 1
# populated: 2
# plain: 4
# devoted: 1
# cultivation: 1
# heartland: 1
# cyclo: 1
# cycle: 1
# rickshaws: 2
# 1990s: 2
# increasingly: 1
# replaced: 1
# remorques: 1
# imported: 3
# approved: 1
# diplomatic: 2
# relations: 5
# reports: 1
# twenty: 1
# embassies: 1
# neighbours: 1
# those: 2
# players: 1
# negotiations: 1
# australia: 1
# canada: 1
# china: 4
# european: 1
# japan: 1
# russia: 1
# nevertheless: 1
# pleas: 1
# ignored: 1
# bombing: 2
# traditionally: 2
# offered: 1
# wats: 1
# providing: 2
# exclusively: 1
# head: 3
# occupation: 2
# transition: 2
# articles: 3
# republic: 3
# cambodianvietnamese: 1
# 1978: 2
# troops: 4
# invaded: 1
# border: 2
# raids: 1
# conquered: 1
# suggests: 1
# version: 2
# kanchi: 1
# pallava: 1
# creation: 1
# myth: 1
# communist: 3
# offensive: 1
# 117: 1
# collapse: 1
# warning: 1
# june: 2
# 2022: 3
# lawsuit: 1
# filed: 1
# committee: 2
# chhay: 1
# accusing: 1
# defamation: 1
# speaking: 1
# electoral: 2
# fraud: 3
# demographics: 3
# historical: 2
# grew: 1
# varies: 1
# widely: 2
# infused: 1
# medicinal: 1
# herbs: 1
# held: 3
# end: 1
# rainy: 1
# season: 3
# sink: 1
# normal: 1
# allowing: 1
# reverse: 1
# flow: 2
# approximately: 4
# attends: 1
# play: 1
# games: 5
# give: 1
# thanks: 1
# moon: 1
# watch: 3
# fireworks: 1
# dine: 1
# attend: 1
# race: 1
# carnivaltype: 1
# atmosphere: 1
# humble: 1
# farming: 1
# background: 1
# just: 2
# took: 2
# longruling: 1
# dictator: 1
# positions: 1
# expanded: 1
# communication: 1
# attack: 1
# overseas: 1
# press: 3
# club: 1
# rick: 1
# valenzuela: 1
# captured: 1
# video: 1
# civil: 6
# duties: 1
# security: 3
# prevent: 1
# crime: 1
# terrorism: 1
# protect: 1
# private: 1
# property: 1
# help: 2
# assist: 1
# civilians: 1
# emergency: 2
# case: 2
# disaster: 1
# unrest: 1
# conflicts: 2
# 1967: 1
# washington: 1
# post: 1
# journalist: 1
# stanley: 1
# karnow: 1
# told: 1
# wanted: 1
# bomb: 1
# would: 2
# object: 1
# unless: 1
# killed: 4
# forced: 1
# evictions: 1
# senior: 1
# officials: 2
# governmentconnected: 1
# commonplace: 2
# regarding: 1
# coffee: 2
# beans: 2
# domestically: 1
# produced: 3
# ratanakiri: 3
# mondulkiri: 2
# places: 2
# amnesty: 1
# recognises: 1
# prisoner: 1
# conscience: 1
# 33yearold: 1
# activist: 1
# yorm: 1
# bopha: 1
# jayavarman: 2
# viii: 1
# attacked: 2
# mongol: 1
# kublai: 1
# khan: 1
# able: 1
# buy: 1
# wars: 1
# kingdoms: 1
# sacked: 1
# ayutthaya: 1
# abandoned: 1
# 1432: 1
# ecological: 1
# failure: 1
# breakdown: 1
# original: 1
# master: 2
# tapes: 1
# lost: 1
# cover: 1
# fell: 1
# 1969: 1
# 1987: 1
# passenger: 2
# train: 2
# operated: 2
# battambang: 7
# 141: 1
# project: 3
# funded: 1
# started: 1
# revitalise: 1
# languishing: 1
# will: 2
# industrial: 3
# centers: 1
# bangkok: 1
# techo: 1
# intended: 1
# replace: 1
# existing: 2
# census: 6
# conducted: 1
# lead: 1
# 36yearlong: 1
# gap: 1
# could: 3
# 1998: 2
# calendar: 1
# theravada: 4
# holiday: 1
# takes: 1
# protectorate: 3
# lasted: 1
# brief: 1
# interruption: 1
# occupied: 1
# japanese: 2
# 1941: 1
# 1945: 2
# simultaneously: 2
# puppet: 1
# deeply: 1
# hinduism: 4
# animism: 1
# constitutional: 2
# monarchy: 3
# parliamentary: 1
# representative: 1
# receipts: 1
# exceeded: 1
# indianised: 1
# facilitated: 1
# undertook: 1
# infrastructural: 1
# projects: 2
# soccer: 2
# brought: 1
# locals: 1
# tens: 1
# thousands: 5
# 1973: 1
# includes: 4
# 20: 2
# distinct: 2
# tribes: 1
# term: 4
# coined: 1
# encourage: 1
# unity: 1
# highlanders: 1
# lowlanders: 1
# cyclos: 1
# cyclist: 1
# sits: 1
# behind: 1
# seat: 1
# adjoining: 1
# gulf: 4
# narrow: 1
# strip: 1
# wooded: 1
# sparsely: 1
# southwestern: 2
# credible: 1
# nongovernmental: 1
# organisations: 2
# estimate: 1
# 770000: 1
# adversely: 1
# affected: 3
# grabbing: 1
# covering: 2
# four: 1
# hectares: 3
# confiscated: 2
# says: 2
# parisbased: 1
# federation: 1
# members: 2
# 123seat: 1
# proportional: 1
# representation: 1
# serve: 2
# maximum: 1
# 61: 2
# appointed: 2
# commune: 2
# councillors: 1
# 24: 1
# entire: 1
# eradicated: 1
# upper: 3
# layers: 2
# gave: 2
# neolithic: 2
# containing: 1
# earliest: 1
# dated: 1
# earthenware: 1
# ceramics: 1
# function: 1
# debated: 1
# possibly: 1
# date: 1
# classified: 1
# combines: 1
# westernstyle: 1
# rock: 2
# technology: 2
# plan: 2
# 20142020: 1
# asean: 3
# joined: 1
# wto: 1
# cliff: 1
# marks: 1
# limit: 1
# dângrêk: 1
# restored: 1
# reinstated: 1
# postwar: 1
# coordinated: 1
# untac: 1
# 443kilometre: 1
# coastline: 2
# half: 3
# worth: 1
# makes: 2
# provision: 1
# establishing: 2
# foundation: 1
# promote: 1
# innovation: 2
# focus: 1
# icts: 1
# 2007: 3
# thenprime: 1
# meets: 1
# joe: 1
# biden: 1
# summit: 1
# 12: 2
# bon: 2
# om: 2
# touk: 2
# rowing: 1
# contest: 1
# attended: 1
# lake: 4
# unusual: 1
# disappears: 1
# expands: 1
# massively: 1
# backs: 1
# rains: 1
# impact: 2
# ecology: 1
# productivity: 1
# tonlé: 2
# affecting: 1
# large: 3
# proportion: 1
# elements: 1
# veneration: 1
# heroes: 1
# confucianism: 1
# taoism: 1
# mix: 1
# timber: 1
# rubber: 3
# see: 2
# list: 2
# vte: 1
# towns: 1
# rank: 1
# handled: 1
# passengers: 1
# disagreements: 1
# offshore: 1
# islands: 1
# sections: 1
# boundary: 1
# undefined: 1
# maritime: 1
# boundaries: 1
# muslims: 2
# underwent: 1
# purges: 1
# much: 6
# exterminated: 1
# august: 3
# 2014: 1
# sentenced: 1
# khieu: 1
# samphan: 1
# 83yearold: 1
# 88yearold: 1
# chief: 1
# ideologue: 1
# prison: 2
# charges: 1
# terror: 1
# less: 1
# 3220: 1
# km2: 1
# result: 2
# future: 1
# sustainability: 1
# reserves: 1
# severe: 2
# threat: 1
# creating: 1
# level: 1
# playing: 1
# labour: 4
# g: 1
# populations: 1
# 4392: 1
# monastery: 1
# 5728771: 1
# 1980: 1
# 6600000: 1
# replacing: 1
# displaced: 1
# mahayana: 1
# 1295: 1
# indravarman: 1
# iii: 1
# accounted: 1
# employed: 1
# workforce: 2
# senators: 1
# sixyear: 1
# decade: 1
# purpose: 1
# selfenrichment: 1
# maintaining: 1
# interests: 1
# suffered: 1
# setbacks: 1
# supported: 1
# kicking: 1
# sey: 1
# similar: 1
# footbag: 1
# chess: 1
# habitats: 2
# evergreen: 1
# dipterocarp: 1
# forests: 1
# mondolkiri: 1
# protected: 1
# keo: 2
# seima: 1
# wildlife: 6
# sanctuary: 5
# prich: 1
# srepok: 1
# well: 5
# cardamom: 1
# ecosystem: 1
# preah: 5
# monivong: 1
# park: 3
# botumsakor: 1
# aural: 1
# samkos: 1
# comprised: 1
# 102000: 1
# active: 1
# personnel: 1
# instead: 1
# maternal: 1
# grandson: 1
# sisowath: 1
# enthroned: 1
# shuttle: 1
# accident: 1
# standards: 1
# clear: 3
# distinction: 1
# executive: 3
# branch: 1
# deep: 1
# politicisation: 1
# judicial: 1
# estimates: 2
# unexploded: 1
# 60000: 1
# civilian: 1
# maimed: 1
# injured: 2
# worst: 2
# health: 2
# indicators: 1
# 22: 3
# biosphere: 3
# reserve: 3
# surrounding: 2
# 2281951: 1
# 11: 1
# chbar: 1
# mon: 1
# kampong: 8
# speu: 1
# 50359: 1
# sisophon: 3
# 245494: 1
# bavet: 1
# svay: 3
# rieng: 3
# 43783: 1
# 119251: 1
# 13: 1
# doun: 1
# kaev: 1
# takéo: 1
# 43402: 1
# banteay: 3
# meanchey: 5
# 99019: 1
# 41424: 1
# poipet: 1
# 98934: 1
# 15: 1
# chhnang: 3
# 41080: 1
# ta: 1
# khmau: 1
# kandal: 1
# 75629: 1
# 16: 1
# 38365: 1
# 73036: 1
# pailin: 3
# 37393: 1
# 8: 2
# samraong: 1
# oddar: 2
# 70944: 1
# 18: 2
# prey: 3
# veng: 2
# 36254: 1
# pursat: 3
# 58355: 1
# 19: 1
# suong: 1
# tboung: 1
# khmum: 1
# 35054: 1
# stueng: 1
# saen: 1
# thom: 2
# 53118: 1
# 32053: 1
# languages: 3
# subfamily: 1
# austroasiatic: 1
# clockwise: 1
# left: 3
# saraman: 1
# prahok: 2
# ktis: 1
# samlor: 1
# kako: 1
# staple: 1
# grain: 1
# formerly: 1
# controlled: 1
# 1698: 1
# chey: 1
# chettha: 1
# ii: 2
# granting: 1
# permission: 1
# settle: 1
# decades: 1
# longer: 1
# storage: 1
# reasons: 1
# range: 3
# opportunistic: 1
# loggings: 1
# scale: 2
# clearings: 1
# big: 1
# agricultural: 1
# activities: 1
# secondary: 1
# crops: 1
# maize: 1
# cassava: 1
# sweet: 1
# potatoes: 1
# groundnuts: 1
# soybeans: 1
# sesame: 1
# seeds: 1
# better: 2
# factories: 3
# 2001: 1
# partnership: 1
# organization: 2
# corporation: 1
# anglicisation: 1
# cambodge: 1
# turn: 2
# transliteration: 1
# កមពជ: 1
# choeung: 1
# ek: 1
# grave: 1
# genocide: 2
# how: 2
# cited: 1
# figure: 1
# apsara: 2
# divided: 2
# categories: 1
# landmines: 1
# exploded: 1
# ordnance: 1
# alone: 1
# caused: 1
# 44630: 1
# 1979: 1
# mineuxo: 1
# victim: 1
# fully: 2
# beholden: 1
# occupying: 1
# direction: 1
# ambassador: 1
# travel: 1
# restrictions: 2
# attract: 1
# improve: 2
# governance: 1
# adopt: 1
# targets: 1
# develop: 1
# effective: 1
# bankability: 1
# facilitate: 1
# market: 1
# entry: 1
# investors: 2
# 28: 1
# march: 2
# conference: 1
# appealed: 1
# media: 2
# i: 2
# appeal: 1
# you: 1
# publicise: 1
# abroad: 1
# stand: 1
# cambodiathat: 1
# oppose: 1
# bombings: 1
# whatever: 1
# pretext: 1
# companies: 1
# deal: 2
# tape: 1
# permits: 2
# constructionrelated: 1
# demand: 1
# bribes: 2
# lyrical: 1
# poetry: 1
# full: 1
# double: 1
# entendres: 1
# scripted: 1
# completely: 1
# impromptu: 1
# adlibbed: 1
# literacy: 1
# 89: 2
# 86: 1
# females: 1
# trains: 1
# again: 1
# running: 1
# destinations: 1
# involves: 1
# local: 1
# businesses: 1
# authorities: 1
# transnational: 1
# corporations: 1
# prepared: 1
# macerated: 1
# spices: 1
# sombai: 1
# liqueur: 1
# called: 1
# sra: 1
# tram: 1
# succeeded: 1
# shows: 1
# communities: 1
# huntergatherers: 1
# inhabited: 1
# ancient: 1
# discovery: 1
# cave: 1
# laang: 1
# spean: 1
# belongs: 2
# hoabinhian: 1
# supreme: 1
# rescue: 1
# paving: 1
# return: 1
# authoritarian: 2
# chams: 1
# powersharing: 1
# agreement: 1
# agreed: 1
# ministers: 1
# threatened: 2
# secede: 1
# transferred: 1
# 04: 1
# femalebiased: 1
# greater: 2
# department: 1
# frequent: 1
# largescale: 1
# abuses: 2
# extrajudicial: 1
# killings: 1
# torture: 1
# impunity: 1
# analogous: 1
# frenchlanguage: 1
# newspaper: 1
# tv: 1
# channels: 1
# available: 1
# 2020: 3
# naturally: 2
# regenerating: 2
# 7464400: 1
# planted: 1
# 603970: 1
# rise: 2
# killing: 2
# fields: 1
# tuol: 2
# sleng: 2
# ranked: 2
# 103rd: 1
# global: 2
# index: 2
# vote: 1
# tampering: 1
# elections: 1
# addition: 1
# oppression: 1
# accused: 2
# sale: 1
# resulting: 1
# eviction: 1
# villagers: 3
# taking: 1
# grants: 1
# exploit: 1
# wealth: 1
# mineral: 1
# resources: 3
# legislative: 1
# shared: 1
# bicameral: 1
# consists: 1
# house: 2
# 96: 1
# 11437656: 1
# intricately: 1
# costumed: 1
# trained: 1
# men: 2
# occasions: 1
# tribute: 1
# invocation: 1
# enact: 1
# stories: 1
# epic: 1
# poems: 1
# reamker: 1
# principal: 2
# encompasses: 1
# vihear: 2
# lyrics: 1
# usually: 1
# moral: 1
# theme: 1
# improving: 1
# bfc: 2
# programme: 3
# family: 1
# c: 3
# antigovernment: 1
# protests: 1
# cnrp: 1
# center: 1
# alongside: 1
# move: 1
# step: 1
# towards: 1
# approach: 1
# university: 2
# application: 1
# quantity: 1
# souvenirs: 1
# sufficient: 1
# products: 1
# sold: 1
# markets: 1
# plenty: 2
# grown: 1
# kirirom: 1
# p: 2
# 802: 1
# declared: 1
# himself: 1
# uniting: 1
# warring: 1
# princes: 1
# kambuja: 1
# office: 2
# lao: 1
# pdr: 1
# noted: 1
# several: 4
# concerns: 3
# gaps: 1
# migrations: 1
# insular: 1
# 2011: 1
# ministerial: 1
# appointees: 1
# exercise: 1
# communes: 1
# quarters: 1
# landscape: 1
# characterised: 1
# lowlying: 1
# surrounded: 1
# uplands: 1
# low: 1
# reaches: 1
# borders: 1
# southwest: 1
# given: 1
# mandate: 1
# enforce: 1
# ceasefire: 1
# refugees: 1
# disarmament: 1
# authority: 1
# 26: 1
# translates: 1
# roughly: 1
# monetary: 1
# fund: 1
# dengue: 1
# fever: 1
# roll: 1
# band: 2
# features: 1
# backup: 1
# california: 1
# opposed: 1
# trials: 1
# investigations: 1
# urged: 1
# overthrowing: 1
# hastening: 1
# onset: 1
# take: 1
# nation: 1
# invaluable: 1
# beijing: 1
# effort: 1
# claim: 1
# team: 1
# managed: 1
# fourth: 1
# 1972: 1
# cup: 2
# slowed: 1
# demonstrators: 1
# 20000: 1
# gathered: 1
# clashing: 2
# riot: 1
# police: 2
# designated: 1
# rabbit: 1
# island: 1
# koh: 1
# tonsay: 1
# condudcted: 1
# 1921: 1
# charitable: 1
# assisted: 1
# rivers: 1
# diet: 1
# once: 1
# completed: 1
# demanded: 1
# leave: 1
# states: 1
# journalists: 1
# protest: 1
# say: 1
# deliberately: 1
# clothes: 1
# slingshots: 1
# stun: 1
# guns: 1
# little: 1
# beyond: 1
# magical: 1
# tantricism: 1
# host: 1
# hindu: 1
# gods: 1
# assimilated: 1
# spirit: 1
# may: 1
# advisory: 1
# ilo: 1
# met: 1
# provide: 1
# input: 1
# draft: 1
# conclusions: 1
# recommendations: 1
# independent: 1
# midterm: 1
# evaluation: 1
# discuss: 1
# options: 1
# strengthen: 1
# transparent: 1
# reporting: 1
# initiative: 1
# acclaimed: 1
# biodiversity: 1
# contained: 1
# environmental: 2
# degradation: 1
# parks: 1
# endangered: 1
# endemic: 1
# extinction: 1
# loss: 1
# breweries: 1
# located: 1
# mainly: 1
# violence: 1
# came: 1
# amid: 1
# tensions: 1
# boycotted: 1
# opening: 1
# assumed: 1
# 39: 1
# ago: 1
# longestserving: 1
# surath: 1
# remaking: 1
# songs: 1
# thought: 1
# young: 1
# easy: 1
# style: 1
# instruments: 2
# mixture: 1
# even: 1
# attracted: 1
# model: 1
# learn: 1
# conducting: 1
# auctions: 1
# installed: 1
# usaligned: 1
# overthrown: 1
# temperature: 1
# 21: 1
# 35: 1
# experiences: 1
# revolution: 1
# murdered: 1
# starved: 1
# death: 2
# overwork: 1
# advice: 1
# approval: 1
# robam: 1
# reach: 1
# troap: 1
# set: 1
# pinpeat: 1
# ensemble: 1
# accompanied: 1
# vocal: 1
# chorus: 1
# 13th: 1
# missionaries: 2
# sri: 1
# lanka: 1
# having: 1
# sent: 1
# previously: 1
# 1190s: 1
# late: 1
# 2000s: 1
# reconstruction: 1
# marred: 1
# combination: 1
# disrespecting: 1
# thai: 1
# upbuild: 1
# situation: 2
# unsettled: 1
# kaplan: 1
# eyeglasses: 1
# deadly: 1
# yellow: 1
# star: 1
# seen: 1
# intellectualism: 1
# circle: 1
# romvong: 1
# romkbach: 1
# saravan: 1
# lam: 1
# leav: 1
# hosted: 1
# ganefo: 1
# 1966: 1
# 2008: 1
# 13395682: 1
# microbreweries: 1
# 94: 1
# statistics: 1
# chapter: 1
# flowing: 1
# regions: 1
# taught: 1
# street: 1
# signs: 1
# bilingual: 1
# waterfall: 1
# kulen: 1
# lang: 1
# perceived: 1
# singular: 1
# issue: 1
# commercial: 1
# crop: 1
# operation: 1
# eagle: 1
# pull: 1
# rebels: 1
# influence: 1
# bread: 1
# upland: 1
# blocks: 1
# krâvanh: 1
# dâmrei: 1
# highland: 1
# covers: 1
# hydroelectric: 1
# pose: 1
# real: 1
# danger: 1
# doctors: 1
# teachers: 1
# already: 1
# europe: 1
# 1524: 1
# antonio: 1
# pigafetta: 1
# cites: 1
# work: 1
# relazione: 1
# del: 1
# primo: 1
# viaggio: 1
# intorno: 1
# al: 1
# mondo: 1
# camogia: 1
# despite: 1
# minimising: 1
# disease: 1
# strain: 1
# outbreak: 1
# prompted: 1
# lockdowns: 1
# originated: 1
# villages: 1
# regularly: 1
# ignoring: 1
# suppressing: 1
# dissent: 1
# beaches: 1
# casinos: 1
# attractions: 1
# participated: 1
# olympics: 1
# summer: 1
# olympic: 1
# sending: 1
# equestrian: 1
# riders: 1
# revised: 1
# structure: 1
# prelude: 1
# reorganisation: 1
# lasts: 1
# temperatures: 1
# 40: 1
# expert: 1
# expressed: 1
# serious: 1
# freedom: 1
# expression: 1
# participation: 1
# ahead: 1
# policies: 1
# guidelines: 1
# sworn: 1
# excavations: 1
# radiocarbon: 1
# 6000: 1
# defense: 1
# banh: 1
# rooms: 1
# museum: 1
# contain: 1
# photos: 1
# taken: 1
# harvesting: 1
# confederation: 1
# landing: 1
# category: 1
# guarantee: 1
# fastestgrowing: 1
# 219000: 1
# decline: 1
# 1863: 1
# inflation: 1
# immediately: 1
# deterioration: 1
# described: 1
# director: 1
# david: 1
# roberts: 1
# relatively: 1
# superficial: 1
# dark: 1
# enough: 1
# decanted: 1
# added: 1

# %%
from collections import defaultdict

def build_ngram_model(data, n):
    model = defaultdict(lambda: defaultdict(int))
    for sentence in data:
        for i in range(len(sentence) - n + 1):
            ngram = tuple(sentence[i:i+n])
            prefix, token = ngram[:-1], ngram[-1]
            model[prefix][token] += 1
    return model

def backoff_prob(model, ngram):
    prefix, token = ngram[:-1], ngram[-1]
    if prefix in model and sum(model[prefix].values()) > 0:
        if token in model[prefix]:
            return model[prefix][token] / sum(model[prefix].values())
    elif len(prefix) > 1:
        return backoff_prob(model, prefix[1:] + (token,))
    return 0  # Default probability if no valid prefix or tokens


lm1 = build_ngram_model(train_tokens, 4)

# %%
# Build the LM2 interpolated method 
def interpolated_prob(model, ngram, lambdas, k):
    n = len(ngram)
    prob = 0
    for i in range(1, n+1):
        prefix, token = ngram[:i-1], ngram[i-1]
        count = model[prefix][token] + k
        total_count = sum(model[prefix].values()) + k * vocab_size
        prob += lambdas[i-1] * (count / total_count)
    return prob

lambdas = [0.1, 0.2, 0.3, 0.4]  # Example weights
k = 1  # Example smoothing parameter

# %%
import math
def perplexity(model, tokens, prob_func):
    log_prob = 0
    word_count = 0
    for sentence in tokens:
        for i in range(3, len(sentence)):
            ngram = tuple(sentence[i-3:i+1])
            prob = prob_func(model, ngram)
            # Ensure probability is a small positive value
            if prob <= 0:
                prob = 1e-10  # Assign a small positive probability
            log_prob += math.log2(prob)
            word_count += 1
    return 2 ** (-log_prob / word_count)


pp_lm1 = perplexity(lm1, test_tokens, backoff_prob)
pp_lm2 = perplexity(lm1, test_tokens, lambda m, n: interpolated_prob(m, n, lambdas, k))

print(f"pp_lm1: {pp_lm1}")
print(f"pp_lm2: {pp_lm2}")
# Out:
# pp_lm1: 5937574397.718667
# pp_lm2: 19811.206507987925

# %%
def generate_text(model, start, length, prob_func):
    text = list(start)
    for _ in range(length - len(start)):
        prefix = tuple(text[-3:])
        if prefix not in model or not model[prefix] or sum(model[prefix].values()) == 0:
            print(f"Prefix not found or has zero probability: {prefix}. Stopping generation.")
            break  # Stop generation if prefix is invalid
        else:
            next_word = max(model[prefix], key=lambda x: prob_func(model, prefix + (x,)))
            text.append(next_word)
    return ' '.join(text)
# Ensure start tokens match the model's keys
start = list(random.choice(list(lm1.keys())))
print('LM1:', generate_text(lm1, start, 50, backoff_prob))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#      11     return ' '.join(text)
#      12 # Ensure start tokens match the model's keys
# ---> 13 start = list(random.choice(list(lm1.keys())))
#      14 print('LM1:', generate_text(lm1, start, 50, backoff_prob))
#
# NameError: name 'random' is not defined
