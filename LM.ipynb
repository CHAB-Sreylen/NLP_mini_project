# %% [markdown]
# 1. Clean data

# %%
import re

def clean_wikipedia_text(text):
    # Remove citations like [1], [2][3], [citation needed]
    text = re.sub(r'\[[^\]]+\]', '', text)
    
    # Remove URLs
    text = re.sub(r'http[s]?://\S+', '', text)
    
    # Remove parenthetical information
    text = re.sub(r'\([^)]*\)', '', text)
    
    # Remove special formatting (e.g., ''italic'' or '''bold''')
    text = re.sub(r"''+|\<.*?\>", '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove lines starting with special characters (-, *, digits)
    text = '\n'.join(line for line in text.split('\n') if not line.strip().startswith(('-', '*', '1.')))
    
    return text

# Load text and clean
with open('data/wiki_dataset.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

cleaned_text = clean_wikipedia_text(raw_text)

# Save cleaned text
with open('data/cleaned_wiki_text.txt', 'w', encoding='utf-8') as file:
    file.write(cleaned_text)

# %% [markdown]
# 2. Spit data into 3 subset for training, testing and validation

# %%
import random
import re
from nltk.tokenize import word_tokenize, sent_tokenize

# Load and preprocess corpus
with open('data/cleaned_wiki_text.txt', 'r', encoding='utf-8') as file:
    # Convert to lowercase
    corpus = file.read().lower()

# Clean up text: remove extra newlines and leading/trailing spaces
corpus = re.sub(r'\n+', ' ', corpus).strip()  # Replace multiple newlines with a space
corpus = re.sub(r'\s+', ' ', corpus) 
 # Replace multiple spaces with a single space

# Split into sentences
# sentences = corpus.split('.')
sentences = sent_tokenize(corpus)

# Remove empty sentences
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

# Shuffle sentences
random.shuffle(sentences)

# Split into training, validation, and testing sets
train_split = int(0.7 * len(sentences))
val_split = int(0.8 * len(sentences))

train_set = sentences[:train_split]
val_set = sentences[train_split:val_split]
test_set = sentences[val_split:]

# Verify results
print(f"Total sentences: {len(sentences)}")
print(f"Training set: {len(train_set)} sentences")
print(f"Validation set: {len(val_set)} sentences")
print(f"Testing set: {len(test_set)} sentences")

# Optional: Save the sets to files for further use
with open('data/wiki_article/train_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(train_set) + '.')

with open('data/wiki_article/val_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(val_set) + '.')

with open('data/wiki_article/test_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(test_set) + '.')
# Out:
# Total sentences: 507
# Training set: 354 sentences
# Validation set: 51 sentences
# Testing set: 102 sentences

# %%
import re
from collections import Counter

# Tokenize
tokens = word_tokenize(' '.join(train_set))
vocab_size = 20000 # Limit vocabulary size
token_counts = Counter(tokens)
vocab = {word for word, _ in token_counts.most_common(vocab_size)}

# Clean up unwanted characters
def clean_tokens(tokens):
    cleaned = []
    for sentence in tokens:
        cleaned_sentence = [re.sub(r'[^\w.]', '', word) for word in sentence]  # Keep only words and periods
        cleaned_sentence = [word for word in cleaned_sentence if word]  # Remove empty tokens
        cleaned.append(cleaned_sentence)
    return cleaned

# Replace words not in vocab with <UNK> and clean
def replace_with_unk(data):
    return [
        [word if word in vocab else '<UNK>' for word in word_tokenize(sentence)]
        for sentence in data
    ]

train_tokens = replace_with_unk(train_set)
val_tokens = replace_with_unk(val_set)
test_tokens = replace_with_unk(test_set)

# Clean the tokenized data
train_tokens = clean_tokens(train_tokens)
val_tokens = clean_tokens(val_tokens)
test_tokens = clean_tokens(test_tokens)

# Check results
print(train_tokens[:10])  # Show first 10 sentences from train_tokens
print(val_tokens[:10])    # Show first 10 sentences from val_tokens
print(test_tokens[:10])   # Show first 10 sentences from test_tokens
# Out:
# [['demonstrators', 'were', 'injured', 'and', 'killed', 'in', 'phnom', 'penh', 'where', 'a', 'reported', '20000', 'protesters', 'gathered', 'with', 'some', 'clashing', 'with', 'riot', 'police', '.'], ['in', '2012', 'the', 'exports', 'grew', 'to', '4.61', 'billion', 'up', '8', 'over', '2011.', 'in', 'the', 'first', 'half', 'of', '2013', 'the', 'garment', 'industry', 'reported', 'exports', 'worth', '1.56', 'billion', '.'], ['hun', 'sen', 'remains', 'the', 'de', 'facto', 'ruler', 'of', 'cambodia', 'through', 'his', 'continued', 'leadership', 'of', 'the', 'cambodian', 'people', 's', 'party', '.'], ['that', 'same', 'year', 'it', 'was', 'estimated', 'that', 'there', 'were', 'about', '100000', 'sex', 'workers', 'in', 'cambodia', '.'], ['in', '2018', 'they', 'handled', 'a', 'record', 'of', '10', 'million', 'passengers', '.'], ['they', 'are', 'taken', 'care', 'of', 'by', 'wrapping', 'in', 'cloth', 'to', 'protect', 'from', 'moisture', 'and', 'the', 'climate', '.'], ['the', 'australian', 'hip', 'hop', 'group', 'astronomy', 'class', 'has', 'recorded', 'with', 'kak', 'channthy', 'a', 'nativeborn', 'cambodian', 'female', 'singer', '.'], ['khmer', 'classical', 'dance', 'is', 'the', 'form', 'of', 'stylised', 'performance', 'art', 'established', 'in', 'the', 'royal', 'courts', 'of', 'cambodia', 'exhibited', 'for', 'both', 'entertainment', 'and', 'ceremonial', 'purposes', '.'], ['the', 'toasted', 'baguette', 'pieces', 'are', 'dipped', 'in', 'the', 'curry', 'and', 'eaten', '.'], ['rural', 'cambodians', 'wear', 'a', 'krama', 'scarf', 'which', 'is', 'a', 'unique', 'aspect', 'of', 'cambodian', 'clothing', '.']]
# [['cambodian', 'buddhism', 'is', 'UNK', 'influenced', 'by', 'hinduism', 'and', 'native', 'UNK', '.'], ['UNK', 'flooding', 'UNK', 'in', '2001', 'and', 'again', 'in', '2002', 'with', 'some', 'UNK', 'of', 'flooding', 'almost', 'every', 'year', '.'], ['UNK', 'covering', 'a', 'UNK', 'over', 'disputed', 'election', 'UNK', 'in', 'phnom', 'penh', 'on', '22', 'september', '2013', 'UNK', 'they', 'were', 'UNK', 'attacked', 'by', 'police', 'and', 'men', 'in', 'plain', 'UNK', 'with', 'UNK', 'and', 'UNK', 'UNK', '.'], ['farmers', 'UNK', 'rice', 'in', 'battambang', 'province', 'cambodia', 'UNK', 'among', 'the', 'worst', 'UNK', 'in', 'the', 'world', 'for', 'UNK', 'labour', 'in', 'the', '2015', 'international', 'trade', 'union', 'UNK', 'global', 'rights', 'index', 'UNK', 'in', 'the', 'UNK', 'of', 'countries', 'with', 'no', 'UNK', 'of', 'rights', '.'], ['cambodia', 'has', 'several', 'UNK', 'UNK', 'UNK', 'UNK', 'in', 'sihanoukville', 'province', 'and', 'phnom', 'penh', '.'], ['cambodia', 'and', 'thailand', 'also', 'have', 'border', 'disputes', 'with', 'troops', 'clashing', 'over', 'land', 'immediately', 'UNK', 'to', 'the', 'preah', 'vihear', 'temple', 'in', 'particular', 'leading', 'to', 'a', 'UNK', 'in', 'relations', '.'], ['cambodia', 'was', 'once', 'one', 'of', 'the', 'most', 'UNK', 'countries', 'in', 'the', 'world', '.'], ['to', 'UNK', 'more', 'investment', 'in', 'renewable', 'energy', 'the', 'government', 'could', 'improve', 'renewable', 'energy', 'UNK', 'UNK', 'clear', 'UNK', 'UNK', 'an', 'UNK', 'regulatory', 'framework', 'improve', 'project', 'UNK', 'and', 'UNK', 'UNK', 'entry', 'for', 'international', 'investors', '.'], ['UNK', 'UNK', 'the', 'beans', 'are', 'generally', 'UNK', 'from', 'laos', 'and', 'vietnam', 'although', 'UNK', 'produced', 'UNK', 'from', 'ratanakiri', 'province', 'and', 'mondulkiri', 'province', 'can', 'be', 'found', 'in', 'some', 'UNK', '.'], ['phnom', 'penh', 'at', 'the', 'UNK', 'of', 'the', 'UNK', 'the', 'mekong', 'and', 'the', 'tonle', 'sap', 'rivers', 'is', 'the', 'only', 'river', 'UNK', 'UNK', 'of', 'UNK', 'UNK', 'UNK', 'during', 'the', 'wet', 'season', 'and', 'UNK', 'UNK', 'during', 'the', 'dry', 'season', '.']]
# [['major', 'UNK', 'UNK', 'include', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'UNK', 'dry', 'beans', 'and', 'rubber', '.'], ['the', 'most', 'distinctive', 'UNK', 'UNK', 'is', 'the', 'UNK', 'of', 'the', 'tonle', 'sap', 'UNK', 'about', 'UNK', 'square', 'kilometres', 'during', 'the', 'dry', 'season', 'and', 'UNK', 'to', 'about', 'UNK', 'square', 'kilometres', 'during', 'the', 'rainy', 'season', '.'], ['a', 'july', '2023', 'human', 'rights', 'watch', 'report', 'UNK', 'numerous', 'and', 'significant', 'election', 'fraud', 'and', 'UNK', 'UNK', 'in', 'the', 'UNK', 'UNK', 'commune', 'UNK', '.'], ['in', '2017', 'cambodia', 's', 'supreme', 'court', 'dissolved', 'the', 'main', 'opposition', 'party', 'cambodia', 'national', 'rescue', 'party', 'UNK', 'the', 'way', 'for', 'a', 'UNK', 'to', 'a', 'yet', 'more', 'authoritarian', 'political', 'system', '.'], ['its', 'civil', 'UNK', 'include', 'UNK', 'security', 'and', 'public', 'peace', 'to', 'UNK', 'and', 'UNK', 'UNK', 'crime', 'UNK', 'and', 'other', 'violent', 'groups', 'to', 'protect', 'state', 'and', 'UNK', 'UNK', 'to', 'help', 'and', 'UNK', 'UNK', 'and', 'other', 'UNK', 'forces', 'in', 'a', 'case', 'of', 'UNK', 'natural', 'UNK', 'civil', 'unrest', 'and', 'armed', 'conflicts', '.'], ['and', 'many', 'UNK', 'UNK', 'UNK', 'from', 'the', 'period', 'were', 'UNK', 'or', 'UNK', '.'], ['cambodia', 'has', 'two', 'distinct', 'UNK', '.'], ['from', '1970', 'until', '1972', 'the', 'cambodian', 'conflict', 'was', 'largely', 'between', 'the', 'government', 'and', 'army', 'of', 'cambodia', 'and', 'the', 'armed', 'forces', 'of', 'north', 'vietnam', '.'], ['the', 'vietnamese', 'are', 'the', 'UNK', 'ethnic', 'minority', 'in', 'cambodia', 'with', 'an', 'estimated', 'UNK', 'UNK', 'in', 'provinces', 'UNK', 'in', 'the', 'southeast', 'of', 'the', 'country', 'UNK', 'to', 'the', 'mekong', 'delta', '.'], ['a', 'UNK', 'war', 'crimes', 'tribunal', 'the', 'khmer', 'rouge', 'tribunal', 'UNK', 'out', 'to', 'UNK', 'crimes', 'committed', 'during', 'the', 'democratic', 'kampuchea', 'period', 'and', 'UNK', 'its', 'leaders', '.']]

# %%
import pandas as pd 
from collections import Counter 
from nltk.tokenize import word_tokenize
from itertools import chain

flattened_tokens = list(chain.from_iterable(train_tokens))
word_counts = Counter(flattened_tokens)
tokens = word_tokenize(corpus.lower()) 
df = pd.DataFrame(word_counts.items(),columns=['word','Frequency'])
df = df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)

# Display the DataFrame
print(df)
for word, count in word_counts.items():
    print(f'{word}: {count}')
# Out:
#             word  Frequency
# 0            the        636
# 1              .        354
# 2             of        342
# 3            and        302
# 4             in        258
# ...          ...        ...
# 2705       2011.          1
# 2706       worth          1
# 2707        1.56          1
# 2708      option          1
# 2709  travellers          1
#
# [2710 rows x 2 columns]
# demonstrators: 1
# were: 23
# injured: 2
# and: 302
# killed: 3
# in: 258
# phnom: 26
# penh: 24
# where: 6
# a: 145
# reported: 6
# 20000: 1
# protesters: 2
# gathered: 1
# with: 49
# some: 14
# clashing: 1
# riot: 1
# police: 1
# .: 354
# 2012: 2
# the: 636
# exports: 3
# grew: 3
# to: 167
# 4.61: 1
# billion: 3
# up: 6
# 8: 3
# over: 10
# 2011.: 1
# first: 8
# half: 4
# of: 342
# 2013: 5
# garment: 6
# industry: 6
# worth: 1
# 1.56: 1
# hun: 19
# sen: 16
# remains: 2
# de: 5
# facto: 5
# ruler: 1
# cambodia: 168
# through: 5
# his: 15
# continued: 1
# leadership: 1
# cambodian: 56
# people: 22
# s: 75
# party: 12
# that: 33
# same: 3
# year: 4
# it: 27
# was: 58
# estimated: 3
# there: 12
# about: 11
# 100000: 2
# sex: 2
# workers: 5
# 2018: 6
# they: 7
# handled: 2
# record: 2
# 10: 5
# million: 11
# passengers: 1
# are: 57
# taken: 2
# care: 1
# by: 71
# wrapping: 1
# cloth: 1
# protect: 1
# from: 56
# moisture: 1
# climate: 9
# australian: 1
# hip: 1
# hop: 1
# group: 4
# astronomy: 1
# class: 2
# has: 41
# recorded: 4
# kak: 1
# channthy: 1
# nativeborn: 1
# female: 4
# singer: 3
# khmer: 55
# classical: 4
# dance: 12
# is: 102
# form: 5
# stylised: 2
# performance: 2
# art: 1
# established: 6
# royal: 13
# courts: 2
# exhibited: 1
# for: 55
# both: 8
# entertainment: 2
# ceremonial: 2
# purposes: 2
# toasted: 1
# baguette: 1
# pieces: 1
# dipped: 1
# curry: 3
# eaten: 2
# rural: 5
# cambodians: 7
# wear: 1
# krama: 1
# scarf: 1
# which: 28
# unique: 3
# aspect: 1
# clothing: 2
# p.a: 1
# sihamoni: 3
# selection: 2
# endorsed: 1
# prime: 17
# minister: 21
# national: 22
# assembly: 7
# speaker: 1
# prince: 4
# norodom: 14
# ranariddh: 6
# members: 4
# throne: 4
# council: 2
# more: 11
# than: 9
# 2000: 3
# years: 10
# what: 2
# become: 1
# absorbed: 1
# influences: 1
# india: 1
# passing: 1
# them: 2
# on: 44
# other: 22
# southeast: 12
# asian: 7
# civilisations: 1
# later: 3
# became: 6
# thailand: 14
# laos: 7
# peace: 6
# efforts: 2
# began: 6
# paris: 5
# 1989: 1
# under: 15
# state: 11
# culminating: 1
# 2: 7
# october: 5
# 1991: 3
# comprehensive: 1
# settlement: 1
# upon: 1
# father: 3
# death: 5
# 1960: 1
# sihanouk: 20
# again: 2
# head: 4
# taking: 2
# title: 1
# concerns: 4
# new: 10
# law: 5
# shared: 2
# not: 5
# only: 6
# labour: 7
# rights: 9
# groups: 10
# but: 9
# international: 22
# organisations: 3
# generally: 3
# senate: 2
# 61: 1
# seats: 1
# two: 11
# appointed: 2
# king: 15
# others: 3
# rest: 2
# elected: 3
# commune: 1
# councillors: 1
# 24: 3
# provinces: 8
# please: 1
# help: 2
# update: 1
# this: 13
# article: 19
# reflect: 1
# recent: 2
# events: 1
# or: 18
# newly: 1
# available: 2
# information: 7
# southern: 4
# coastal: 3
# region: 5
# adjoining: 1
# gulf: 4
# narrow: 1
# lowland: 2
# strip: 1
# heavily: 1
# wooded: 1
# sparsely: 1
# populated: 2
# isolated: 2
# central: 3
# plain: 4
# southwestern: 2
# highlands: 3
# spans: 1
# an: 18
# area: 10
# 181035: 2
# square: 2
# kilometres: 4
# population: 18
# 17: 5
# 1970: 4
# coup: 6
# installed: 1
# usaligned: 1
# republic: 5
# overthrown: 1
# rouge: 20
# 1975.: 1
# ruled: 1
# country: 38
# carried: 2
# out: 4
# genocide: 3
# 1975: 2
# until: 5
# 1979: 2
# when: 9
# ousted: 4
# cambodianvietnamese: 2
# war: 13
# vacant: 1
# 1941: 3
# monivong: 2
# sisowath: 4
# son: 3
# france: 6
# passed: 2
# monireth: 1
# feeling: 1
# he: 6
# too: 1
# independently: 1
# minded: 1
# due: 7
# shift: 2
# mostly: 2
# english: 6
# now: 8
# used: 4
# relationships: 1
# replaced: 1
# french: 12
# stamps: 1
# since: 11
# 2002: 1
# currency: 2
# worldwide: 1
# fund: 2
# nature: 2
# recognises: 2
# six: 2
# distinct: 4
# terrestrial: 1
# ecoregions: 1
# cardamom: 1
# mountains: 6
# rain: 1
# forests: 2
# indochina: 5
# dry: 5
# forest: 12
# evergreen: 1
# annamite: 1
# range: 4
# tropical: 5
# tonle: 7
# sap: 7
# freshwater: 3
# swamp: 2
# sapmekong: 1
# peat: 1
# consistently: 1
# listed: 1
# as: 66
# one: 10
# most: 20
# corrupt: 1
# governments: 2
# world: 18
# 2017: 5
# crackdowns: 1
# political: 11
# dissent: 2
# free: 3
# press: 4
# been: 22
# described: 2
# oneparty: 4
# regime: 8
# main: 29
# articles: 3
# democratic: 1
# kampuchea: 7
# rooms: 1
# tuol: 2
# sleng: 2
# museum: 1
# contain: 1
# thousands: 5
# photos: 1
# their: 16
# victims: 2
# united: 6
# nations: 6
# designates: 1
# least: 4
# developed: 3
# north: 7
# abuts: 1
# sandstone: 1
# escarpment: 1
# forms: 3
# southwardfacing: 1
# cliff: 2
# stretching: 1
# 200: 1
# miles: 1
# west: 2
# east: 5
# rising: 1
# abruptly: 1
# above: 1
# heights: 1
# 600: 1
# 1800: 1
# feet: 2
# etymology: 1
# names: 1
# kingdom: 12
# official: 7
# name: 5
# music: 11
# composed: 1
# particular: 3
# styles: 4
# social: 9
# dances: 6
# administrative: 4
# divisions: 4
# autonomous: 2
# municipality: 2
# firstlevel: 1
# history: 5
# prehistory: 2
# early: 7
# glazed: 1
# stoneware: 1
# dating: 1
# back: 4
# 12th: 2
# century: 5
# exists: 1
# evidence: 3
# pleistocene: 1
# human: 8
# occupation: 3
# includes: 3
# quartz: 1
# quartzite: 1
# pebble: 1
# tools: 1
# found: 5
# terraces: 1
# along: 4
# mekong: 12
# river: 8
# stung: 4
# treng: 3
# kratié: 3
# kampot: 7
# province: 10
# iron: 1
# age: 3
# settlements: 1
# beneath: 2
# baksei: 1
# chamkrong: 1
# angkorian: 3
# temples: 2
# while: 16
# circular: 1
# earthworks: 1
# discovered: 2
# at: 17
# site: 4
# lovea: 1
# northwest: 4
# angkor: 9
# wat: 4
# bestpreserved: 1
# example: 1
# architecture: 2
# era: 3
# hundreds: 2
# have: 22
# around: 6
# rich: 1
# fisheries: 2
# largest: 5
# lake: 4
# asia: 6
# largely: 3
# supply: 6
# impoverished: 1
# protein: 1
# colonisation: 1
# coronation: 1
# 1863: 2
# signed: 3
# treaty: 2
# protection: 3
# densely: 1
# devoted: 1
# wet: 2
# rice: 12
# cultivation: 1
# heartland: 1
# principal: 1
# commercial: 1
# crop: 1
# rubber: 2
# legal: 4
# profession: 2
# 1932.: 1
# 1978: 2
# entire: 1
# system: 9
# eradicated: 1
# ministry: 7
# culture: 10
# fine: 1
# arts: 1
# responsible: 5
# promoting: 1
# developing: 2
# favouritism: 1
# government: 19
# officials: 2
# impunity: 2
# commonplace: 3
# divided: 3
# into: 11
# 25: 2
# including: 8
# 123seat: 1
# proportional: 1
# representation: 1
# serve: 2
# maximum: 1
# term: 5
# five: 4
# rainy: 2
# season: 5
# runs: 1
# may: 2
# can: 9
# see: 4
# temperatures: 2
# drop: 2
# 22: 4
# c: 3
# accompanied: 1
# high: 4
# humidity: 1
# fled: 2
# opponents: 1
# arrested: 3
# tortured: 1
# summarily: 1
# executed: 2
# muslim: 1
# be: 17
# 80: 2
# ethnic: 10
# cham: 9
# challenges: 2
# facing: 1
# still: 4
# fact: 1
# older: 3
# often: 11
# lacks: 1
# education: 14
# particularly: 4
# countryside: 1
# suffers: 1
# lack: 2
# basic: 2
# infrastructure: 5
# attack: 1
# against: 3
# president: 3
# overseas: 1
# club: 1
# rick: 1
# valenzuela: 1
# captured: 1
# video: 1
# 14: 5
# 2004: 3
# selected: 1
# special: 2
# ninemember: 1
# part: 9
# process: 2
# quickly: 1
# put: 2
# place: 2
# after: 10
# abdication: 1
# week: 1
# prior: 1
# marks: 1
# limit: 1
# dângrêk: 1
# hinduism: 2
# left: 2
# little: 1
# trace: 2
# beyond: 1
# magical: 1
# practices: 3
# tantricism: 1
# host: 1
# hindu: 1
# gods: 1
# assimilated: 1
# spirit: 1
# trains: 1
# running: 1
# capital: 5
# popular: 6
# destinations: 2
# south: 4
# its: 21
# populous: 1
# city: 5
# documents: 1
# uncovered: 1
# soviet: 2
# archives: 1
# reveal: 1
# vietnamese: 17
# attempt: 1
# overrun: 1
# launched: 3
# explicit: 1
# request: 1
# negotiated: 1
# pol: 2
# pot: 2
# then: 2
# second: 4
# command: 4
# nuon: 2
# chea: 2
# antigovernment: 1
# protests: 1
# supporting: 1
# opposition: 6
# cnrp: 1
# followed: 2
# general: 7
# election: 5
# according: 8
# robert: 1
# d.: 2
# kaplan: 1
# eyeglasses: 1
# deadly: 1
# yellow: 1
# star: 1
# seen: 2
# sign: 1
# intellectualism: 1
# besides: 2
# phom: 1
# tourist: 1
# include: 7
# sihanoukville: 7
# southwest: 2
# several: 6
# beaches: 2
# battambang: 8
# stops: 1
# backpackers: 1
# who: 7
# make: 1
# significant: 4
# portion: 1
# visitors: 2
# reign: 2
# gained: 4
# independence: 3
# 9: 3
# november: 5
# 1953.: 2
# mao: 1
# zedong: 1
# 1956: 2
# 1955: 1
# abdicated: 1
# favour: 1
# participate: 1
# politics: 1
# pepper: 1
# reputed: 1
# best: 1
# accompanies: 1
# crab: 2
# kep: 4
# shacks: 1
# squid: 1
# restaurants: 1
# ou: 1
# trojak: 1
# jet: 1
# among: 3
# vulnerable: 3
# countries: 7
# change: 5
# cpp: 3
# won: 2
# every: 1
# seat: 2
# without: 1
# major: 6
# effectively: 3
# solidifying: 1
# rule: 4
# following: 2
# accords: 1
# formally: 1
# ended: 2
# vietnam: 13
# governed: 1
# mission: 2
# remnant: 1
# colonial: 1
# past: 2
# dialect: 1
# sometimes: 2
# court: 2
# islam: 1
# comes: 1
# three: 4
# varieties: 3
# practised: 2
# third: 2
# descendants: 2
# malays: 1
# resident: 1
# generations: 1
# 2010: 7
# youth: 2
# sports: 4
# approved: 1
# policy: 4
# research: 5
# development: 10
# sector: 8
# violence: 1
# came: 3
# amid: 1
# tensions: 2
# boycotted: 1
# opening: 1
# parliament: 3
# electoral: 1
# fraud: 1
# land: 9
# confiscated: 2
# decade: 1
# purpose: 2
# selfenrichment: 1
# maintaining: 1
# power: 9
# various: 8
# interests: 1
# also: 22
# significantly: 1
# invested: 1
# vocational: 1
# especially: 3
# areas: 7
# tackle: 1
# poverty: 1
# unemployment: 1
# folk: 4
# performed: 4
# mahori: 1
# celebrates: 1
# cultural: 4
# july: 2
# kang: 1
# kek: 1
# iew: 1
# member: 6
# guilty: 1
# crimes: 3
# humanity: 1
# role: 2
# former: 4
# commandant: 1
# s21: 1
# extermination: 1
# camp: 1
# sentenced: 2
# life: 3
# prison: 3
# prehistoric: 1
# sites: 1
# somewhat: 1
# uncertain: 1
# date: 2
# samrong: 1
# investigations: 1
# 1875: 1
# phum: 1
# snay: 1
# northern: 1
# banteay: 5
# meanchey: 8
# instead: 1
# maternal: 1
# grandson: 1
# enthroned: 2
# april: 5
# 2016: 2
# adopted: 2
# trade: 5
# unions: 1
# majesty: 1
# supreme: 1
# commander: 1
# armed: 6
# forces: 9
# holds: 1
# position: 1
# commanderinchief: 1
# prostitution: 1
# illegal: 2
# yet: 1
# appears: 1
# prevalent: 1
# saw: 1
# defence: 3
# subordinate: 1
# departments: 1
# logistics: 1
# finance: 4
# materials: 1
# technical: 1
# services: 3
# headquarters: 1
# held: 3
# end: 1
# begins: 1
# sink: 1
# normal: 1
# levels: 2
# allowing: 1
# reverse: 1
# flow: 2
# approximately: 3
# attends: 1
# event: 2
# each: 3
# play: 1
# games: 4
# give: 1
# thanks: 1
# moon: 1
# watch: 2
# fireworks: 1
# dine: 1
# attend: 1
# boat: 2
# race: 1
# carnivaltype: 1
# atmosphere: 1
# time: 5
# remember: 1
# relatives: 2
# died: 1
# during: 21
# 19751979: 1
# crooner: 1
# sinn: 3
# sisamouth: 3
# ros: 2
# sereysothea: 1
# pen: 1
# ran: 1
# 1960s: 3
# 1970s: 4
# considered: 3
# classic: 2
# pop: 3
# 29: 1
# 2004.: 2
# officially: 2
# multiparty: 3
# democracy: 3
# reality: 1
# remain: 3
# dominated: 3
# recast: 1
# 1985.: 1
# open: 1
# doors: 1
# investment: 5
# yielded: 1
# access: 3
# coterie: 1
# cronies: 1
# wife: 1
# bun: 1
# rany: 1
# megha: 1
# bahree: 1
# writer: 1
# forbes: 1
# 2015: 1
# 100: 1
# public: 3
# ownership: 1
# amnesty: 1
# currently: 4
# prisoner: 1
# conscience: 1
# 33yearold: 1
# activist: 1
# yorm: 1
# bopha: 1
# assumed: 1
# office: 2
# 39: 1
# ago: 1
# longestserving: 1
# leaders: 2
# transition: 2
# troops: 1
# invaded: 1
# response: 1
# border: 2
# raids: 1
# conquered: 1
# vowed: 1
# turned: 1
# 74.: 1
# regularly: 1
# accused: 2
# ignoring: 1
# suppressing: 1
# diplomatic: 2
# support: 4
# invaluable: 1
# beijing: 2
# effort: 1
# claim: 1
# disputed: 2
# china: 3
# sea: 3
# simultaneous: 1
# attacks: 4
# perimeter: 1
# pinned: 1
# down: 2
# republican: 1
# cpk: 1
# units: 2
# overran: 2
# fire: 1
# bases: 1
# controlling: 1
# vital: 1
# lower: 4
# resupply: 1
# route: 2
# 443kilometre: 1
# coastline: 2
# establishing: 1
# policies: 1
# guidelines: 1
# biodiversity: 2
# conservation: 1
# wildlife: 2
# list: 2
# protected: 1
# macaques: 1
# pros: 1
# kampong: 15
# founded: 1
# seasonal: 2
# containing: 2
# 180: 1
# tree: 1
# species: 7
# riparian: 1
# ecosystems: 1
# once: 2
# language: 10
# spoken: 1
# many: 8
# instruction: 1
# schools: 1
# universities: 3
# funded: 1
# fish: 9
# tonlé: 1
# rivers: 1
# important: 5
# diet: 1
# protectorate: 4
# period: 7
# lasted: 1
# 1953: 1
# brief: 1
# interruption: 1
# occupied: 1
# japanese: 3
# empire: 11
# 1945: 1
# simultaneously: 1
# existing: 2
# puppet: 1
# 1945.: 1
# between: 16
# 1874: 1
# 1962: 3
# total: 4
# increased: 5
# 946000: 1
# 5.7: 1
# religion: 3
# pchum: 1
# ben: 1
# known: 6
# ancestors: 2
# day: 2
# religious: 4
# festival: 2
# celebrated: 1
# buddhists: 1
# köppen: 1
# classification: 1
# map: 5
# like: 2
# monsoons: 2
# because: 3
# distinctly: 1
# marked: 1
# differences: 1
# 1980s: 2
# primary: 5
# commodity: 1
# few: 2
# sources: 1
# foreign: 11
# exchange: 2
# rank: 2
# pac: 1
# concurred: 1
# findings: 1
# evaluation: 2
# related: 1
# impact: 2
# programme: 5
# had: 8
# a.: 1
# contributing: 1
# sustained: 2
# overall: 2
# growth: 5
# b.: 1
# improving: 1
# lives: 1
# factories: 4
# bfc: 2
# family: 1
# c.: 1
# ensuring: 1
# receive: 1
# correct: 1
# wages: 1
# benefits: 1
# virtually: 1
# eliminating: 1
# child: 2
# e.: 1
# making: 3
# safer: 2
# f.: 1
# creating: 1
# level: 2
# playing: 1
# field: 3
# across: 2
# g.: 1
# influencing: 1
# business: 2
# using: 3
# factory: 1
# data: 1
# highlight: 1
# improvement: 2
# being: 6
# core: 1
# risk: 2
# management: 1
# strategies: 1
# brandsbuyers: 1
# excavations: 1
# layers: 2
# produced: 1
# series: 4
# radiocarbon: 1
# dates: 2
# 6000: 1
# bc: 3
# temperature: 1
# 21: 2
# 35: 1
# experiences: 2
# manet: 4
# succeeded: 1
# august: 4
# 2023.: 2
# sole: 2
# dominantparty: 1
# majority: 3
# 20: 5
# culturally: 2
# hill: 4
# tribes: 2
# colloquially: 1
# loeu: 3
# coined: 1
# encourage: 1
# unity: 1
# highlanders: 1
# lowlanders: 1
# based: 3
# economist: 1
# imf: 1
# annual: 3
# average: 5
# gdp: 4
# 20012010: 1
# 7.7: 1
# top: 3
# ten: 3
# highest: 4
# networks: 1
# separated: 1
# space: 1
# indicate: 1
# network: 2
# 2nd4th: 1
# ad: 1
# probably: 1
# changes: 1
# sociopolitical: 1
# powers: 2
# western: 2
# such: 8
# basketball: 1
# volleyball: 1
# bodybuilding: 1
# hockey: 1
# rugby: 1
# union: 3
# golf: 1
# baseball: 1
# gaining: 1
# popularity: 1
# geography: 2
# geographic: 1
# regional: 1
# lies: 1
# entirely: 1
# within: 2
# tropics: 1
# latitudes: 1
# 15n: 1
# longitudes: 1
# 102: 1
# 108e: 1
# lon: 2
# nol: 2
# surrendered: 1
# 5: 3
# days: 1
# us: 7
# evacuated: 1
# military: 4
# spending: 1
# stands: 2
# 3: 4
# cyclos: 1
# cyclist: 1
# sits: 1
# behind: 1
# passenger: 1
# could: 2
# supported: 1
# 1: 4
# number: 7
# regulated: 1
# banks: 1
# microfinance: 1
# institutions: 3
# 31: 1
# covered: 1
# entities: 2
# 70: 2
# individual: 1
# underlining: 1
# banking: 2
# cuisine: 4
# clockwise: 1
# saraman: 1
# prahok: 2
# ktis: 1
# num: 2
# banhchok: 2
# samlor: 1
# kako: 1
# staple: 1
# grain: 1
# constitution: 1
# promulgates: 1
# compulsory: 1
# nine: 2
# guaranteeing: 1
# universal: 1
# right: 2
# quality: 3
# much: 6
# controversy: 1
# urban: 2
# dwellers: 1
# engaged: 1
# primarily: 1
# commerce: 2
# maintain: 1
# separate: 1
# villages: 1
# modern: 5
# 1993: 2
# monarchy: 2
# restored: 1
# reinstated: 1
# postwar: 1
# coordinated: 1
# untac: 1
# transitional: 1
# plains: 1
# gradually: 1
# merge: 1
# eastern: 2
# forested: 1
# plateaus: 1
# extend: 1
# 28: 1
# march: 3
# conference: 1
# appealed: 1
# media: 3
# i: 2
# appeal: 1
# you: 1
# publicise: 1
# abroad: 1
# very: 2
# clear: 2
# stand: 1
# cambodiathat: 1
# will: 1
# any: 1
# case: 1
# oppose: 1
# all: 5
# bombings: 1
# territory: 2
# whatever: 1
# pretext: 1
# control: 1
# communists: 4
# imposed: 1
# eventually: 1
# referred: 1
# engages: 1
# employers: 1
# improve: 1
# working: 1
# conditions: 1
# boost: 1
# competitiveness: 1
# result: 2
# relations: 5
# charitable: 1
# assisted: 1
# economic: 5
# civil: 7
# needs: 1
# delicacies: 1
# amok: 1
# aping: 1
# choeung: 1
# ek: 1
# mass: 4
# grave: 1
# estimates: 2
# how: 2
# cited: 1
# figure: 1
# move: 1
# represented: 2
# step: 1
# towards: 1
# approach: 1
# university: 3
# application: 1
# allowed: 2
# use: 5
# sanctuary: 1
# arms: 2
# aid: 2
# fighting: 1
# sung: 1
# duo: 1
# man: 3
# women: 5
# take: 1
# turns: 1
# answering: 1
# verse: 1
# posing: 1
# riddles: 1
# solve: 1
# short: 1
# instrumental: 1
# breaks: 1
# verses: 2
# cities: 4
# vte: 1
# towns: 1
# 2019: 6
# census: 6
# un: 3
# expert: 1
# situation: 1
# expressed: 1
# serious: 2
# restrictions: 2
# freedom: 1
# expression: 1
# participation: 1
# ahead: 2
# lasts: 1
# rise: 2
# 40: 1
# constitutionally: 1
# dominates: 1
# dissolved: 2
# historical: 1
# park: 1
# siem: 11
# reap: 11
# 150: 2
# casinos: 1
# attractions: 1
# tourists: 2
# corruption: 7
# further: 6
# exceeds: 1
# indochinese: 1
# peninsula: 1
# tourism: 6
# employs: 1
# 26: 3
# workforce: 2
# translates: 1
# roughly: 1
# 2.5: 2
# jobs: 1
# te: 2
# krolap: 1
# strong: 1
# tea: 6
# made: 3
# putting: 1
# water: 3
# leaves: 2
# small: 1
# glass: 1
# placing: 1
# saucer: 1
# turning: 1
# whole: 1
# thing: 1
# upside: 1
# brew: 1
# usfunded: 1
# airlift: 1
# ammunition: 1
# congress: 1
# refused: 1
# additional: 1
# bokor: 1
# station: 1
# interest: 1
# even: 1
# though: 2
# attracted: 1
# renewable: 2
# energy: 2
# 2020: 3
# serves: 1
# model: 1
# learn: 1
# asean: 3
# terms: 3
# conducting: 1
# solar: 2
# auctions: 1
# army: 6
# officers: 1
# marching: 1
# navy: 1
# air: 2
# force: 1
# gendarmerie: 2
# collectively: 2
# presided: 1
# native: 3
# scholars: 1
# seeing: 1
# similarities: 1
# temple: 1
# engravings: 1
# hold: 1
# learned: 1
# siamese: 2
# dancers: 4
# 1800s: 1
# legislative: 1
# executive: 3
# bicameral: 1
# consists: 1
# house: 2
# upper: 2
# 2023: 2
# sworn: 1
# indianized: 1
# cousins: 1
# consequently: 1
# distant: 1
# khmers: 3
# observing: 1
# preindiancontact: 1
# customs: 1
# beliefs: 1
# ministerial: 1
# appointees: 1
# exercise: 1
# 18: 5
# project: 1
# advisory: 1
# committee: 1
# ilo: 1
# better: 2
# met: 1
# provide: 1
# input: 1
# draft: 1
# conclusions: 1
# recommendations: 1
# independent: 1
# midterm: 1
# well: 4
# discuss: 1
# options: 1
# strengthen: 1
# transparent: 1
# reporting: 1
# initiative: 2
# urged: 1
# followers: 2
# overthrowing: 1
# hastening: 1
# onset: 1
# environmental: 3
# degradation: 1
# parks: 1
# sanctuaries: 2
# large: 2
# scale: 2
# endangered: 1
# endemic: 1
# threatened: 1
# extinction: 1
# loss: 1
# habitats: 1
# serei: 1
# saophoan: 1
# 6679: 1
# 861883: 1
# 11702: 1
# 997169: 1
# 4549: 1
# 899791: 1
# 4: 4
# chhnang: 5
# 5521: 1
# 527027: 1
# speu: 2
# chbar: 2
# mon: 2
# 7017: 1
# 877523: 1
# 6: 4
# thom: 3
# saen: 2
# 13814: 1
# 681549: 1
# 7: 2
# 4873: 1
# 593829: 1
# kandal: 2
# ta: 3
# khmau: 2
# 3179: 1
# 1201581: 1
# 336: 1
# 42665: 1
# koh: 3
# kong: 2
# khemarak: 1
# phoumin: 1
# 10090: 1
# 125902: 1
# 11: 2
# 11094: 1
# 374755: 1
# 12: 4
# mondulkiri: 2
# senmonorom: 1
# 14288: 1
# 92213: 1
# 13: 2
# oddar: 3
# samraong: 2
# 6158: 1
# 276038: 1
# pailin: 5
# 803: 1
# 75112: 1
# 15: 2
# 679: 1
# 2281951: 2
# 16: 2
# preah: 8
# 1938: 1
# 310072: 1
# vihear: 3
# 13788: 1
# 254827: 1
# pursat: 5
# 12692: 1
# 419952: 1
# 19: 2
# prey: 5
# veng: 4
# 4883: 1
# 1057720: 1
# ratanakiri: 2
# banlung: 1
# 10782: 1
# 217453: 1
# 10299: 1
# 1014234: 1
# 11092: 1
# 165713: 1
# 23: 1
# svay: 5
# rieng: 5
# 2966: 1
# 525497: 1
# takéo: 2
# doun: 2
# kaev: 2
# 3563: 1
# 900914: 1
# tboung: 2
# khmom: 1
# suong: 2
# 5250: 1
# 776841: 1
# economy: 4
# real: 2
# gpd: 1
# per: 14
# capita: 3
# income: 1
# 4022: 1
# ppp: 1
# 1309: 1
# nominal: 1
# bribes: 3
# demanded: 2
# companies: 2
# operating: 2
# obtaining: 2
# licences: 1
# permits: 4
# constructionrelated: 2
# continues: 1
# face: 1
# improvements: 1
# net: 1
# enrolment: 1
# gains: 1
# introduction: 2
# program: 1
# basedbudgeting: 1
# framework: 1
# helps: 1
# disadvantaged: 1
# children: 9
# gain: 2
# completed: 1
# leave: 1
# states: 1
# participated: 1
# olympics: 1
# summer: 1
# olympic: 1
# sending: 1
# equestrian: 1
# riders: 1
# airport: 5
# acclaimed: 1
# although: 2
# determined: 1
# monkhmer: 2
# connections: 1
# peoples: 1
# influenced: 1
# indian: 3
# sphere: 2
# chinese: 6
# expected: 2
# mines: 2
# 2025: 1
# legacy: 1
# orphans: 1
# 290: 1
# amputee: 1
# affect: 1
# come: 3
# exact: 1
# origins: 1
# chapei: 1
# ayai: 1
# generation: 1
# solo: 2
# plucking: 1
# guitar: 1
# cappella: 1
# comprised: 1
# 102000: 1
# active: 1
# personnel: 2
# 212: 1
# mammal: 1
# 536: 1
# bird: 1
# 240: 1
# reptile: 1
# 850: 1
# 435: 1
# marine: 1
# science: 1
# landmines: 1
# exploded: 1
# ordnance: 1
# alone: 1
# caused: 1
# 44630: 1
# injuries: 2
# mineuxo: 1
# victim: 1
# tens: 1
# bombing: 1
# 1973.: 1
# operation: 1
# eagle: 1
# pull: 1
# rebels: 1
# him: 1
# drink: 2
# plenty: 1
# grown: 1
# kirirom: 1
# longer: 1
# storage: 1
# increasing: 2
# activity: 1
# increase: 3
# automobile: 1
# motorcycles: 1
# predominate: 1
# vietnameseoccupied: 1
# traced: 1
# postangkor: 2
# nascent: 1
# attempted: 1
# vassalise: 1
# weakened: 1
# dominate: 1
# widely: 3
# shuttle: 1
# train: 1
# road: 8
# traffic: 2
# accident: 1
# rate: 7
# standards: 2
# red: 2
# vermicelli: 1
# noodles: 2
# classified: 1
# combines: 1
# westernstyle: 1
# rock: 2
# close: 1
# interrelationship: 1
# spirits: 3
# community: 1
# efficacy: 1
# apotropaic: 1
# luckattracting: 1
# actions: 1
# charms: 1
# possibility: 1
# manipulating: 1
# contact: 1
# spiritual: 1
# baromey: 1
# originates: 1
# seven: 1
# reporters: 1
# minor: 2
# hit: 1
# slingshot: 1
# projectiles: 1
# hospitalized: 1
# tra: 2
# leaf: 1
# books: 2
# legends: 1
# ramayana: 2
# origin: 2
# buddhism: 5
# prayer: 1
# highly: 2
# negative: 2
# effects: 2
# advised: 1
# focuses: 1
# mitigation: 1
# measures: 1
# remnants: 1
# chenla: 1
# becoming: 1
# firmly: 1
# 802: 1
# jayavarman: 2
# ii: 2
# declared: 1
# java: 1
# proclaimed: 1
# themselves: 1
# devaraja: 1
# suffered: 2
# setbacks: 2
# 70th: 1
# peaceful: 1
# 2024: 1
# global: 3
# index: 2
# la: 1
# francophonie: 1
# vast: 2
# speakers: 1
# examples: 2
# circle: 1
# romvong: 1
# romkbach: 1
# saravan: 1
# lam: 1
# leav: 1
# institute: 3
# reintroduced: 1
# 750: 1
# traditional: 9
# seed: 1
# bank: 6
# philippines: 2
# historically: 1
# lived: 2
# near: 1
# contiguous: 1
# diagonal: 1
# arc: 1
# modernday: 2
# meet: 1
# way: 2
# mouth: 1
# southeastern: 1
# fully: 1
# beholden: 1
# occupying: 1
# direction: 1
# ambassador: 1
# subdivided: 1
# 159: 1
# districts: 3
# municipalities: 3
# sampeah: 1
# greeting: 1
# showing: 1
# respect: 1
# 2014: 1
# tribunal: 1
# khieu: 1
# samphan: 1
# 83yearold: 1
# 88yearold: 1
# chief: 1
# ideologue: 1
# charges: 1
# terror: 1
# growing: 3
# microbreweries: 2
# racing: 2
# buffalo: 1
# pradal: 1
# serey: 2
# wrestling: 1
# bokator: 1
# issued: 1
# licenses: 5
# before: 4
# announced: 1
# director: 1
# david: 1
# roberts: 1
# relatively: 2
# authoritarian: 1
# coalition: 1
# via: 2
# superficial: 1
# paddy: 1
# provides: 1
# regulatory: 1
# oversight: 1
# direct: 1
# funcinpec: 1
# led: 6
# hung: 1
# replacing: 1
# languages: 3
# 88.5: 1
# literate: 1
# 50359: 1
# sisophon: 3
# 245494: 1
# bavet: 1
# 43783: 1
# 119251: 1
# 43402: 1
# 99019: 1
# 41424: 1
# poipet: 1
# 98934: 1
# 41080: 1
# 75629: 1
# 38365: 1
# 73036: 1
# 37393: 1
# 70944: 1
# 36254: 1
# 58355: 1
# khmum: 1
# 35054: 1
# stueng: 1
# 53118: 1
# 32053: 1
# demographics: 1
# subfamily: 1
# austroasiatic: 1
# brewpubs: 1
# addition: 1
# oppression: 1
# sale: 1
# investors: 1
# resulting: 1
# eviction: 1
# villagers: 1
# grants: 1
# exploit: 1
# oil: 2
# wealth: 1
# mineral: 1
# resources: 1
# 1.04: 1
# male: 2
# ratio: 3
# femalebiased: 1
# greater: 2
# subregion: 2
# rabbit: 1
# island: 1
# tonsay: 1
# designated: 1
# biosphere: 2
# reserve: 3
# script: 2
# derived: 1
# pallava: 1
# those: 5
# so: 1
# livelihoods: 1
# economically: 1
# nutritionally: 1
# said: 2
# gordon: 1
# holtgrieve: 1
# professor: 1
# washington: 1
# points: 1
# none: 1
# dams: 1
# either: 2
# built: 2
# pointing: 1
# good: 1
# outcomes: 2
# traditionally: 2
# encompasses: 1
# disproportionately: 1
# targeted: 3
# minority: 2
# lyrical: 1
# poetry: 1
# full: 1
# double: 1
# entendres: 1
# scripted: 1
# completely: 1
# impromptu: 1
# adlibbed: 1
# late: 2
# 1990s: 1
# 2000s: 2
# reconstruction: 1
# progressed: 2
# stability: 2
# constitutional: 1
# marred: 1
# abuses: 2
# forced: 1
# evictions: 1
# senior: 1
# security: 1
# governmentconnected: 1
# rail: 2
# lines: 4
# totalling: 1
# 612: 2
# single: 1
# onemetre: 1
# gauge: 1
# track: 1
# center: 1
# alongside: 1
# deal: 1
# extensive: 1
# tape: 1
# demand: 1
# intricately: 1
# costumed: 1
# trained: 1
# men: 2
# occasions: 1
# tribute: 1
# invocation: 1
# enact: 1
# stories: 1
# epic: 1
# poems: 1
# reamker: 1
# version: 1
# secondgreatest: 1
# source: 1
# hard: 1
# textile: 1
# advice: 1
# approval: 1
# agriculture: 5
# mainstay: 1
# 1904: 1
# manipulated: 1
# choice: 1
# brother: 1
# placed: 1
# viet: 1
# cong: 1
# desperate: 1
# retain: 1
# 15day: 1
# offer: 1
# prayers: 1
# food: 5
# dead: 1
# revised: 1
# structure: 2
# key: 2
# prelude: 1
# reorganisation: 1
# study: 1
# kim: 1
# reports: 2
# employed: 2
# enrolled: 1
# school: 2
# employment: 1
# associated: 1
# entry: 1
# impacts: 1
# learning: 1
# rates: 1
# 1997: 3
# détat: 2
# consolidated: 2
# formerly: 1
# delta: 1
# controlled: 1
# 1698: 1
# chey: 1
# chettha: 1
# granting: 1
# permission: 1
# settle: 1
# decades: 1
# visitor: 1
# arrivals: 1
# topped: 1
# tenfold: 1
# beginning: 1
# 21st: 1
# deforestation: 4
# involves: 1
# local: 2
# businesses: 1
# authorities: 1
# transnational: 1
# corporations: 1
# despite: 2
# adopting: 1
# anticorruption: 2
# prevails: 1
# throughout: 2
# provided: 1
# no: 1
# whistleblowers: 2
# jailed: 1
# months: 1
# if: 1
# report: 2
# proven: 1
# borders: 2
# aged: 2
# 65: 1
# 1.61.: 1
# fertility: 3
# woman: 3
# 2018.: 2
# 4.0: 1
# 2000.: 1
# 2.2: 1
# compared: 2
# 3.3: 1
# revolution: 1
# singers: 2
# murdered: 1
# starved: 1
# overwork: 1
# 5728771: 1
# 1980: 1
# 6600000: 1
# 0.79: 1
# 1994: 1
# 9900000: 1
# 2.94: 1
# 1996: 1
# 10700000: 1
# 3.96: 1
# 1998: 2
# 11437656: 1
# 3.39: 1
# 12800000: 1
# 1.89: 1
# 2008: 1
# 13395682: 1
# 1.14: 1
# 14700000: 1
# 1.88: 1
# 15552211: 1
# 0.94: 1
# statistics: 1
# chapter: 1
# p.: 1
# condudcted: 1
# 1921.: 1
# 60: 1
# counted: 1
# collection: 1
# taxes: 1
# extended: 1
# 1965: 1
# ho: 1
# chi: 1
# minh: 1
# trails: 1
# beans: 1
# roasted: 1
# butter: 1
# sugar: 2
# plus: 1
# ingredients: 1
# might: 1
# anything: 1
# rum: 1
# pork: 1
# fat: 1
# giving: 1
# beverage: 1
# strange: 1
# faintly: 1
# chocolatey: 1
# aroma: 1
# upland: 1
# blocks: 1
# krâvanh: 1
# dâmrei: 1
# another: 2
# highland: 2
# covers: 1
# run: 1
# coast: 1
# viii: 1
# attacked: 1
# mongol: 1
# kublai: 1
# khan: 1
# able: 1
# buy: 1
# 7000: 1
# fumio: 1
# kishida: 1
# december: 1
# violent: 1
# ruptures: 1
# disputes: 2
# neighbours: 3
# persist: 1
# guests: 1
# banquets: 1
# parties: 2
# informal: 1
# gatherings: 1
# descended: 1
# 19th20thcentury: 1
# settlers: 1
# search: 1
# opportunities: 1
# pleng: 1
# kaah: 1
# set: 1
# songs: 1
# played: 1
# accompaniment: 1
# parts: 1
# dayslong: 1
# wedding: 1
# cover: 1
# fell: 1
# 1969: 1
# just: 1
# 3.1: 1
# 2007.: 1
# 2007: 1
# less: 2
# 3220: 1
# km2: 1
# future: 1
# sustainability: 1
# reserves: 1
# severe: 3
# threat: 1
# artistic: 1
# figures: 1
# sothea: 1
# introduced: 1
# musical: 1
# ports: 1
# ones: 1
# chams: 2
# credible: 1
# nongovernmental: 1
# estimate: 1
# 770000: 1
# adversely: 1
# affected: 3
# grabbing: 1
# covering: 1
# four: 1
# hectares: 1
# says: 2
# parisbased: 1
# federation: 1
# timber: 1
# garments: 2
# unusual: 1
# disappears: 1
# expands: 1
# massively: 1
# backs: 1
# rains: 1
# gave: 2
# killing: 2
# fields: 1
# created: 2
# 2001: 1
# partnership: 1
# organization: 3
# corporation: 1
# remote: 1
# uninhabited: 1
# aural: 1
# peak: 1
# rises: 1
# elevation: 1
# 5949: 1
# naturally: 1
# regenerating: 1
# populations: 1
# credentials: 1
# recognised: 1
# conflict: 1
# shaken: 1
# coprime: 2
# dengue: 1
# fever: 1
# roll: 1
# band: 2
# features: 1
# backup: 1
# california: 1
# infant: 1
# mortality: 1
# decreased: 2
# 86: 1
# 1000: 1
# live: 1
# births: 1
# worst: 1
# health: 2
# indicators: 1
# 22.9: 1
# die: 1
# instituted: 1
# cult: 1
# godking: 1
# conquests: 1
# formed: 1
# flourished: 1
# 9th: 1
# 15th: 2
# centuries: 1
# lao: 1
# pdr: 1
# noted: 1
# gaps: 1
# plans: 2
# healthcare: 1
# raising: 1
# awareness: 1
# hivaids: 1
# malaria: 1
# diseases: 1
# prosoviet: 1
# kampuchean: 1
# revolutionary: 1
# 1951: 1
# avoid: 1
# purged: 1
# mok: 1
# northeast: 1
# varies: 1
# infused: 1
# fruits: 2
# medicinal: 1
# herbs: 1
# calendar: 1
# theravada: 2
# holiday: 1
# takes: 1
# football: 1
# team: 1
# managed: 1
# fourth: 1
# 1972: 1
# cup: 1
# slowed: 1
# indigenous: 1
# montagnards: 1
# meaning: 1
# fatalities: 1
# 10000: 1
# vehicles: 1
# times: 1
# higher: 2
# deaths: 2
# doubled: 1
# preceding: 1
# deputy: 1
# leader: 2
# kem: 1
# sokha: 1
# september: 2
# sam: 1
# rainsy: 1
# exile: 1
# 2015.: 1
# department: 1
# committed: 2
# frequent: 1
# largescale: 1
# extrajudicial: 1
# killings: 1
# torture: 1
# message: 1
# conveyed: 1
# johnson: 1
# emissary: 1
# chester: 1
# bowles: 1
# january: 2
# 1968.: 1
# refuted: 1
# u.s.: 1
# strikes: 1
# these: 2
# criminal: 1
# must: 1
# immediately: 1
# definitively: 1
# stop: 1
# assistance: 1
# upgrading: 1
# highways: 1
# vastly: 1
# improved: 1
# 2006.: 1
# roads: 1
# paved: 1
# taught: 1
# street: 2
# signs: 1
# bilingual: 1
# critics: 1
# allegedly: 1
# spreading: 1
# fake: 1
# news: 1
# covid19: 2
# pandemic: 2
# surrounding: 1
# slavery: 1
# 256800: 1
# enslaved: 1
# 1.65: 1
# 1760: 1
# tribe: 1
# hunted: 1
# incessantly: 1
# off: 1
# slaves: 1
# annamites: 1
# 2010s: 2
# educational: 1
# involvement: 1
# cooperation: 1
# collected: 1
# reasons: 1
# opportunistic: 1
# loggings: 1
# clearings: 1
# big: 1
# construction: 3
# projects: 1
# agricultural: 1
# activities: 1
# receipts: 1
# exceeded: 1
# 4.4: 1
# accounting: 1
# almost: 1
# cent: 3
# gross: 1
# product: 1
# monetary: 1
# conducted: 1
# conflicts: 1
# instability: 1
# lead: 1
# 36yearlong: 1
# gap: 1
# 1998.: 1
# younger: 1
# old: 1
# unexploded: 1
# 60000: 1
# civilian: 1
# maimed: 1
# 1970.: 1
# landmine: 1
# casualties: 1
# sharply: 1
# 800: 1
# 2005: 3
# 111: 1
# penetration: 1
# farmers: 2
# millennium: 2
# senators: 1
# sixyear: 1
# elements: 1
# veneration: 1
# heroes: 1
# confucianism: 1
# taoism: 1
# mix: 1
# centre: 1
# capitals: 1
# constructed: 1
# zenith: 1
# hosted: 1
# ganefo: 1
# 1966: 1
# recently: 2
# apsara: 2
# categories: 1
# yai: 1
# comedic: 1
# ko: 1
# keo: 1
# 19thcentury: 1
# illustration: 1
# tale: 1
# vorvong: 1
# sorvong: 1
# factors: 1
# contribute: 1
# colonialism: 1
# globalization: 1
# secondlevel: 1
# techo: 1
# intended: 1
# replace: 1
# frenchlanguage: 1
# newspaper: 1
# tv: 1
# channels: 1
# reputation: 1
# safe: 1
# destination: 1
# hindered: 1
# unrest: 1
# highprofile: 1
# crime: 3
# visiting: 2
# fearing: 1
# purge: 1
# supporters: 1
# neutrality: 1
# cold: 1
# analogous: 1
# spread: 3
# distinctive: 1
# sculpture: 1
# exchanged: 1
# neighbouring: 3
# travel: 1
# kâmpŭchéa: 1
# shortened: 1
# alternative: 1
# ពររជណចករកមពជ: 1
# कमबज: 1
# referring: 1
# kambu: 1
# waterfall: 1
# kulen: 1
# lang: 1
# perceived: 1
# destructive: 2
# singular: 1
# issue: 1
# thenprime: 1
# meets: 1
# joe: 1
# biden: 1
# summit: 2
# 2022.: 1
# affairs: 1
# prak: 1
# sokhon: 1
# rapidly: 1
# received: 1
# considerable: 1
# belt: 1
# burials: 1
# testify: 1
# availability: 1
# existence: 1
# professionals: 2
# doctors: 1
# lawyers: 2
# teachers: 1
# lyrics: 1
# usually: 1
# moral: 1
# theme: 1
# homicide: 1
# 2.4: 1
# anglicisation: 1
# cambodge: 1
# turn: 2
# transliteration: 1
# កមពជ: 1
# joined: 1
# wto: 1
# attended: 1
# inaugural: 1
# malaysia: 1
# prohibition: 1
# nuclear: 1
# weapons: 1
# wars: 1
# kingdoms: 1
# sacked: 1
# ayutthaya: 1
# abandoned: 1
# 1432: 1
# ecological: 1
# failure: 1
# breakdown: 1
# interprovincial: 1
# artery: 1
# connecting: 1
# resurfacing: 1
# dirt: 1
# concreteasphalt: 1
# bridging: 1
# crossings: 1
# permanently: 1
# connected: 1
# hence: 1
# uninterrupted: 1
# judges: 1
# deemed: 1
# enemies: 1
# actually: 1
# survived: 1
# remained: 1
# transport: 3
# highway: 1
# neglect: 1
# severely: 1
# damaged: 1
# numerous: 1
# twenty: 1
# embassies: 1
# players: 1
# negotiations: 1
# australia: 1
# canada: 1
# european: 1
# japan: 1
# russia: 1
# nva: 1
# positions: 1
# communist: 1
# expanded: 1
# communication: 1
# unknown: 1
# archaeological: 2
# shows: 1
# communities: 1
# huntergatherers: 1
# inhabited: 1
# holocene: 1
# ancient: 1
# discovery: 1
# cave: 1
# laang: 1
# spean: 1
# belongs: 1
# hoabinhian: 1
# rescue: 1
# ruling: 1
# enacted: 1
# tighter: 1
# curbs: 1
# decline: 1
# muslims: 1
# underwent: 1
# purges: 1
# exterminated: 1
# directive: 1
# banning: 1
# issuing: 1
# online: 2
# gambling: 1
# operators: 1
# holding: 1
# would: 1
# continue: 1
# expire: 1
# wine: 1
# alcoholic: 1
# already: 1
# europe: 1
# 1524: 1
# antonio: 1
# pigafetta: 1
# cites: 1
# work: 1
# relazione: 1
# del: 1
# primo: 1
# viaggio: 1
# intorno: 1
# al: 1
# mondo: 1
# camogia: 1
# movements: 1
# worn: 1
# portraying: 1
# famous: 1
# far: 1
# communes: 1
# quarters: 1
# natural: 1
# gas: 1
# deposits: 1
# territorial: 2
# waters: 1
# yield: 1
# great: 1
# potential: 1
# untapped: 1
# distinction: 1
# branch: 1
# makes: 1
# deep: 1
# politicisation: 1
# judicial: 1
# sirik: 1
# matak: 1
# 2020.: 1
# minimising: 1
# disease: 1
# strain: 1
# outbreak: 1
# 2021: 1
# prompted: 1
# lockdowns: 1
# 20102015: 1
# 1.3: 1
# lemon: 2
# kdau: 1
# kroch: 1
# chhma: 1
# reddust: 1
# juice: 1
# refreshing: 1
# hot: 1
# iced: 1
# served: 1
# hefty: 1
# dose: 1
# defense: 1
# banh: 1
# mondol: 1
# kiri: 2
# rattanak: 1
# 4.5: 1
# lowest: 1
# 2.0: 1
# regular: 1
# restarted: 1
# offering: 1
# option: 1
# travellers: 1
# contains: 1
# soups: 1
# accounted: 1
# 90: 1
# 1985: 1
# dominant: 1
# textiles: 1
# leading: 1
# mahayana: 1
# function: 1
# debated: 1
# possibly: 1
# boasts: 1
# foods: 1
# heaviest: 1
# precipitation: 1
# driest: 1
# occurring: 1
# february: 1
# neolithic: 1
# earliest: 1
# dated: 1
# earthenware: 1
# ceramics: 1
# hydroelectric: 1
# pose: 1
# danger: 1
# products: 1
# kilograms: 1
# person: 2
# ounces: 1
# flooding: 2
# pacific: 1
# typhoon: 1
# shortages: 1
# clean: 1
# extreme: 1
# mudslides: 1
# potentially: 1
# storms: 1
# concern: 1
# alliance: 1

# %%
from collections import defaultdict

def build_ngram_model(data, n):
    model = defaultdict(lambda: defaultdict(int))
    for sentence in data:
        for i in range(len(sentence) - n + 1):
            ngram = tuple(sentence[i:i+n])
            prefix, token = ngram[:-1], ngram[-1]
            model[prefix][token] += 1
    return model

def backoff_prob(model, ngram):
    prefix, token = ngram[:-1], ngram[-1]
    if prefix in model and sum(model[prefix].values()) > 0:
        if token in model[prefix]:
            return model[prefix][token] / sum(model[prefix].values())
    elif len(prefix) > 1:
        return backoff_prob(model, prefix[1:] + (token,))
    return 0  # Default probability if no valid prefix or tokens

ngram_model = build_ngram_model(train_tokens, 4)

# %%
# Build the LM2 interpolated method
def interpolated_prob(model, ngram, lambdas, k):
    n = len(ngram)
    prob = 0
    for i in range(1, n+1):
        prefix, token = ngram[:i-1], ngram[i-1]
        count = model[prefix][token] + k
        total_count = sum(model[prefix].values()) + k * vocab_size
        prob += lambdas[i-1] * (count / total_count)
    return prob

lambdas = [0.1, 0.2, 0.3, 0.4]  # Example weights
k = 1  # Example smoothing parameter

# %%
import math
import numpy as np

def perplexity(model, tokens, prob_func):
    log_prob_sum = 0
    total_tokens = 0
    
    for sentence in tokens:
        # Skip very short sentences
        if len(sentence) < 4:
            continue
        
        for i in range(3, len(sentence)):
            # Create n-gram
            ngram = tuple(sentence[i-3:i+1])
            
            try:
                # Calculate probability
                prob = prob_func(model, ngram)
                
                # Handle zero or negative probabilities
                if prob <= 0:
                    prob = 1e-10  # Small positive value
                
                # Sum log probabilities
                log_prob = math.log2(prob)
                log_prob_sum += log_prob
                total_tokens += 1
            
            except Exception as e:
                print(f"Error processing n-gram {ngram}: {e}")
                continue
    
    # Avoid division by zero
    if total_tokens == 0:
        return float('inf')
    
    # Calculate perplexity
    perplexity_score = 2 ** (-log_prob_sum / total_tokens)
    
    return perplexity_score

pp_lm1 = perplexity(model=ngram_model, tokens=test_tokens, prob_func=backoff_prob)
pp_lm2 = perplexity(ngram_model, test_tokens, lambda m, n: interpolated_prob(m, n, lambdas, k))

print(f"pp_lm1: {pp_lm1}")
print(f"pp_lm2: {pp_lm2}")
# Out:
# pp_lm1: 5478938442.122225
# pp_lm2: 19745.429675291467

# %%
import random

def generate_text(model, start, length, prob_func):
    text = list(start)
    for _ in range(length - len(start)):
        prefix = tuple(text[-3:])
        if prefix not in model or not model[prefix] or sum(model[prefix].values()) == 0:
            next_words = random.choice(train_tokens)[:3]
            for next_word in next_words:
                text.append(next_word)
        else:
            next_word = max(model[prefix], key=lambda x: prob_func(model, prefix + (x,)))
            text.append(next_word)
    return ' '.join(text)

# Usage
start_tokens = list(random.choice(train_tokens)[:3])
backoff_text = generate_text(ngram_model, start_tokens, 100, backoff_prob)
start_tokens = list(random.choice(train_tokens)[:3])
interpolation_text = generate_text(ngram_model, start_tokens, 100, lambda m, n: interpolated_prob(m, n, lambdas, k))
print(f"Backoff Model: {backoff_text}")
print(f"Interpolation Model: {interpolation_text}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 20
#      18 backoff_text = generate_text(ngram_model, start_tokens, 100, backoff_prob)
#      19 start_tokens = list(random.choice(train_tokens)[:3])
# ---> 20 interpolation_text = generate_text(ngram_model, start_tokens.capitalize(), 100, lambda m, n: interpolated_prob(m, n, lambdas, k))
#      21 print(f"Backoff Model: {backoff_text}")
#      22 print(f"Interpolation Model: {interpolation_text}")
#
# AttributeError: 'list' object has no attribute 'capitalize'
