# %%
import wikipediaapi

# Set up the Wikipedia API with a valid user-agent
wiki = wikipediaapi.Wikipedia(
    language="en", 
    user_agent="YourAppName/1.0 (your-email@example.com)"
)

# Fetch the article
topic = "Cambodia"
article = wiki.page(topic)

if article.exists():
    with open(f"./data/wiki_dataset.txt", "w", encoding="utf-8") as file:
        file.write(article.text)
    
else:
    print(f"The article '{topic}' does not exist.")

# %% [markdown]
# 1. Clean data

# %%
import re

def clean_wikipedia_text(text):
    # Remove citations like [1], [2][3], [citation needed]
    text = re.sub(r'\[[^\]]+\]', '', text)
    
    # Remove URLs
    text = re.sub(r'http[s]?://\S+', '', text)
    
    # Remove parenthetical information
    text = re.sub(r'\([^)]*\)', '', text)
    
    # Remove special formatting (e.g., ''italic'' or '''bold''')
    text = re.sub(r"''+|\<.*?\>", '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove lines starting with special characters (-, *, digits)
    text = '\n'.join(line for line in text.split('\n') if not line.strip().startswith(('-', '*', '1.')))
    
    return text

# Load text and clean
with open('data/wiki_dataset.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

cleaned_text = clean_wikipedia_text(raw_text)

# Save cleaned text
with open('data/cleaned_wiki_text.txt', 'w', encoding='utf-8') as file:
    file.write(cleaned_text)

# %% [markdown]
# 2. Spit data into 3 subset for training, testing and validation

# %%
import random
import re
from nltk.tokenize import word_tokenize, sent_tokenize

# Load and preprocess corpus
with open('data/cleaned_wiki_text.txt', 'r', encoding='utf-8') as file:
    # Convert to lowercase
    corpus = file.read().lower()

# Clean up text: remove extra newlines and leading/trailing spaces
corpus = re.sub(r'\n+', ' ', corpus).strip()  # Replace multiple newlines with a space
corpus = re.sub(r'\s+', ' ', corpus) 
 # Replace multiple spaces with a single space

# Split into sentences
sentences = sent_tokenize(corpus)

# Remove empty sentences
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]

# Shuffle sentences
random.shuffle(sentences)

# Split into training, validation, and testing sets
train_split = int(0.7 * len(sentences))
val_split = int(0.8 * len(sentences))

train_set = sentences[:train_split]
val_set = sentences[train_split:val_split]
test_set = sentences[val_split:]

# Verify results
print(f"Total sentences: {len(sentences)}")
print(f"Training set: {len(train_set)} sentences")
print(f"Validation set: {len(val_set)} sentences")
print(f"Testing set: {len(test_set)} sentences")

# Optional: Save the sets to files for further use
with open('data/wiki_article/train_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(train_set) + '.')

with open('data/wiki_article/val_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(val_set) + '.')

with open('data/wiki_article/test_set.txt', 'w', encoding='utf-8') as file:
    file.write('. '.join(test_set) + '.')
# Out:
# Total sentences: 502
# Training set: 351 sentences
# Validation set: 50 sentences
# Testing set: 101 sentences

# %%
import re
from collections import Counter

# Tokenize
tokens = word_tokenize(' '.join(train_set))
vocab_size = 20000
token_counts = Counter(tokens)
vocab = {word for word, _ in token_counts.most_common(vocab_size)}

# Clean up unwanted characters
def clean_tokens(tokens):
    cleaned = []
    for sentence in tokens:
        cleaned_sentence = [re.sub(r'[^\w.]', '', word) for word in sentence]  # Keep only words and periods
        cleaned_sentence = [word for word in cleaned_sentence if word]  # Remove empty tokens
        cleaned.append(cleaned_sentence)
    return cleaned

# Replace words not in vocab with <UNK> and clean
def replace_with_unk(data):
    return [
        [word if word in vocab else '<UNK>' for word in word_tokenize(sentence)]
        for sentence in data
    ]

train_tokens = replace_with_unk(train_set)
val_tokens = replace_with_unk(val_set)
test_tokens = replace_with_unk(test_set)

# Clean the tokenized data
train_tokens = clean_tokens(train_tokens)
val_tokens = clean_tokens(val_tokens)
test_tokens = clean_tokens(test_tokens)

# Check results
print(train_tokens[:10])  # Show first 10 sentences from train_tokens
print(val_tokens[:10])    # Show first 10 sentences from val_tokens
print(test_tokens[:10])   # Show first 10 sentences from test_tokens
# Out:
# [['when', 'it', 'is', 'dark', 'enough', 'the', 'tea', 'is', 'decanted', 'into', 'another', 'cup', 'and', 'plenty', 'of', 'sugar', 'added', 'but', 'no', 'milk', '.'], ['more', 'rural', 'forms', 'of', 'music', 'include', 'chapei', 'and', 'ayai', '.'], ['in', 'the', '1980s', 'keo', 'surath', 'and', 'others', 'carried', 'on', 'the', 'legacy', 'of', 'the', 'classic', 'singers', 'often', 'remaking', 'their', 'popular', 'songs', '.'], ['this', 'era', 'gave', 'rise', 'to', 'the', 'term', 'killing', 'fields', 'and', 'the', 'prison', 'tuol', 'sleng', 'became', 'known', 'for', 'its', 'history', 'of', 'mass', 'killing', '.'], ['in', '2017', 'cambodia', 's', 'supreme', 'court', 'dissolved', 'the', 'main', 'opposition', 'party', 'cambodia', 'national', 'rescue', 'party', 'paving', 'the', 'way', 'for', 'a', 'return', 'to', 'a', 'yet', 'more', 'authoritarian', 'political', 'system', '.'], ['cambodia', 'was', 'ranked', '103rd', 'in', 'the', 'global', 'innovation', 'index', 'in', '2024.', 'energy', 'cambodia', 'has', 'high', 'potential', 'for', 'developing', 'renewable', 'energy', 'resources', '.'], ['volleyball', 'is', 'by', 'far', 'the', 'most', 'popular', 'sport', 'in', 'the', 'country', '.'], ['the', 'most', 'distinctive', 'geographical', 'feature', 'is', 'the', 'inundations', 'of', 'the', 'tonle', 'sap', 'measuring', 'about', '2590', 'square', 'kilometres', 'during', 'the', 'dry', 'season', 'and', 'expanding', 'to', 'about', '24605', 'square', 'kilometres', 'during', 'the', 'rainy', 'season', '.'], ['foreign', 'relations', 'the', 'foreign', 'relations', 'of', 'cambodia', 'are', 'handled', 'by', 'the', 'ministry', 'of', 'foreign', 'affairs', 'under', 'prak', 'sokhon', '.'], ['the', 'supply', 'of', 'fish', 'and', 'fish', 'products', 'for', 'food', 'and', 'trade', 'as', 'of', '2000', 'was', '20', 'kilograms', 'per', 'person', 'or', '2', 'ounces', 'per', 'day', 'per', 'person', '.']]
# [['in', 'december', 'UNK', 'washington', 'UNK', 'UNK', 'UNK', 'UNK', 'was', 'UNK', 'by', 'sihanouk', 'that', 'if', 'the', 'us', 'UNK', 'to', 'UNK', 'the', 'vietnamese', 'communist', 'sanctuaries', 'he', 'would', 'not', 'UNK', 'UNK', 'cambodians', 'were', 'killed', '.'], ['in', '2004', 'the', 'number', 'of', 'road', 'UNK', 'per', 'UNK', 'UNK', 'was', 'ten', 'UNK', 'UNK', 'in', 'cambodia', 'than', 'in', 'the', 'developed', 'world', 'and', 'the', 'number', 'of', 'road', 'deaths', 'had', 'UNK', 'in', 'the', 'UNK', 'three', 'years', '.'], ['sihamoni', 's', 'selection', 'was', 'UNK', 'by', 'prime', 'minister', 'hun', 'sen', 'and', 'national', 'assembly', 'UNK', 'prince', 'norodom', 'ranariddh', 'both', 'members', 'of', 'the', 'throne', 'council', '.'], ['the', 'former', 'is', 'popular', 'among', 'the', 'older', 'UNK', 'and', 'is', 'most', 'often', 'a', 'solo', 'performance', 'of', 'a', 'man', 'UNK', 'a', 'cambodian', 'UNK', 'in', 'between', 'a', 'UNK', 'verses', '.'], ['besides', 'UNK', 'penh', 'and', 'angkor', 'wat', 'other', 'tourist', 'UNK', 'include', 'sihanoukville', 'in', 'the', 'southwest', 'which', 'has', 'several', 'popular', 'beaches', 'and', 'battambang', 'in', 'the', 'northwest', 'both', 'of', 'which', 'are', 'popular', 'UNK', 'for', 'UNK', 'who', 'UNK', 'up', 'a', 'significant', 'UNK', 'of', 'UNK', 'to', 'cambodia', '.'], ['the', 'french', 'UNK', 'UNK', 'sihanouk', 'would', 'be', 'UNK', 'to', 'control', '.'], ['for', 'more', 'than', 'UNK', 'years', 'what', 'was', 'to', 'UNK', 'cambodia', 'UNK', 'UNK', 'from', 'india', 'UNK', 'them', 'on', 'to', 'other', 'southeast', 'asian', 'UNK', 'that', 'later', 'became', 'thailand', 'and', 'laos', '.'], ['after', '14', 'years', 'UNK', 'rail', 'services', 'between', 'the', 'two', 'cities', 'UNK', 'recently', 'UNK', 'a', 'safer', 'UNK', 'than', 'road', 'for', 'UNK', '.'], ['the', 'toasted', 'baguette', 'UNK', 'are', 'UNK', 'in', 'the', 'curry', 'and', 'UNK', '.'], ['for', 'most', 'cambodians', 'it', 'is', 'a', 'time', 'to', 'UNK', 'their', 'relatives', 'who', 'UNK', 'during', 'the', 'UNK', 'khmer', 'rouge', 'regime', '.']]
# [['forced', 'UNK', 'in', '1970', 'and', 'deaths', 'during', 'the', 'khmer', 'rouge', 'era', 'UNK', 'the', 'vietnamese', 'population', 'in', 'cambodia', 'from', 'between', 'UNK', 'and', 'UNK', 'in', '1969', 'to', 'a', 'reported', 'UNK', 'in', 'UNK', 'most', 'of', 'the', 'UNK', 'of', 'the', 'khmer', 'rouge', 'regime', 'were', 'not', 'ethnic', 'UNK', 'but', 'ethnic', 'khmer', '.'], ['the', 'UNK', 'is', 'a', 'traditional', 'cambodian', 'UNK', 'or', 'a', 'way', 'of', 'UNK', 'respect', 'to', 'others', '.'], ['it', 'has', 'a', 'UNK', 'UNK', 'along', 'the', 'gulf', 'of', 'thailand', '.'], ['this', 'cliff', 'UNK', 'the', 'southern', 'UNK', 'of', 'the', 'UNK', 'mountains', '.'], ['UNK', 'government', 'national', 'UNK', 'in', 'cambodia', 'take', 'place', 'within', 'the', 'framework', 'of', 'the', 'UNK', 's', 'UNK', 'of', 'UNK', 'the', 'government', 'is', 'a', 'UNK', 'UNK', 'operated', 'as', 'a', 'UNK', 'representative', 'democracy', '.'], ['examples', 'include', 'the', 'UNK', 'dances', 'UNK', 'and', 'UNK', 'as', 'well', 'as', 'UNK', 'and', 'UNK', 'UNK', '.'], ['it', 'was', 'fully', 'UNK', 'to', 'the', 'UNK', 'vietnamese', 'army', 'and', 'under', 'the', 'UNK', 'of', 'the', 'vietnamese', 'UNK', 'to', 'phnom', 'penh', '.'], ['it', 'is', 'UNK', 'by', 'thailand', 'to', 'the', 'northwest', 'laos', 'to', 'the', 'north', 'vietnam', 'to', 'the', 'east', 'and', 'has', 'a', 'UNK', 'along', 'the', 'gulf', 'of', 'thailand', 'in', 'the', 'southwest', '.'], ['the', 'un', 'was', 'UNK', 'a', 'UNK', 'to', 'UNK', 'a', 'UNK', 'and', 'deal', 'with', 'UNK', 'and', 'UNK', 'known', 'as', 'the', 'united', 'nations', 'transitional', 'UNK', 'in', 'cambodia', '.'], ['the', 'religion', 'spread', 'and', 'eventually', 'UNK', 'hinduism', 'and', 'mahayana', 'buddhism', 'as', 'the', 'popular', 'religion', 'of', 'angkor', 'it', 'was', 'not', 'the', 'official', 'state', 'religion', 'until', 'UNK', 'when', 'UNK', 'UNK', 'took', 'power', '.']]

# %%
import pandas as pd 
from collections import Counter 
from nltk.tokenize import word_tokenize
from itertools import chain

flattened_tokens = list(chain.from_iterable(train_tokens))
word_counts = Counter(flattened_tokens)
tokens = word_tokenize(corpus.lower()) 
df = pd.DataFrame(word_counts.items(),columns=['word','Frequency'])
df = df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)

# Display the DataFrame
print(df)
for word, count in word_counts.items():
    print(f'{word}: {count}')
# Out:
#            word  Frequency
# 0           the        622
# 1             .        351
# 2           and        315
# 3            of        308
# 4            in        229
# ...         ...        ...
# 2595     surath          1
# 2596  breakdown          1
# 2597     spread          1
# 2598  sculpture          1
# 2599  exchanged          1
#
# [2600 rows x 2 columns]
# when: 12
# it: 21
# is: 98
# dark: 1
# enough: 1
# the: 622
# tea: 7
# decanted: 1
# into: 13
# another: 4
# cup: 1
# and: 315
# plenty: 2
# of: 308
# sugar: 3
# added: 1
# but: 10
# no: 3
# milk: 2
# .: 351
# more: 12
# rural: 4
# forms: 2
# music: 10
# include: 8
# chapei: 1
# ayai: 1
# in: 229
# 1980s: 2
# keo: 2
# surath: 1
# others: 2
# carried: 2
# on: 36
# legacy: 2
# classic: 2
# singers: 1
# often: 9
# remaking: 1
# their: 15
# popular: 10
# songs: 1
# this: 11
# era: 2
# gave: 2
# rise: 3
# to: 167
# term: 5
# killing: 2
# fields: 1
# prison: 3
# tuol: 1
# sleng: 1
# became: 5
# known: 5
# for: 53
# its: 25
# history: 2
# mass: 3
# 2017: 3
# cambodia: 139
# s: 66
# supreme: 2
# court: 3
# dissolved: 4
# main: 11
# opposition: 6
# party: 16
# national: 22
# rescue: 2
# paving: 1
# way: 1
# a: 136
# return: 1
# yet: 2
# authoritarian: 1
# political: 8
# system: 8
# was: 59
# ranked: 2
# 103rd: 1
# global: 4
# innovation: 2
# index: 4
# 2024.: 1
# energy: 5
# has: 35
# high: 2
# potential: 2
# developing: 2
# renewable: 4
# resources: 2
# volleyball: 2
# by: 70
# far: 1
# most: 23
# sport: 1
# country: 36
# distinctive: 2
# geographical: 1
# feature: 1
# inundations: 1
# tonle: 11
# sap: 13
# measuring: 1
# about: 10
# 2590: 1
# square: 5
# kilometres: 9
# during: 19
# dry: 8
# season: 10
# expanding: 1
# 24605: 1
# rainy: 3
# foreign: 8
# relations: 4
# are: 58
# handled: 2
# ministry: 5
# affairs: 1
# under: 10
# prak: 1
# sokhon: 1
# supply: 6
# fish: 10
# products: 2
# food: 5
# trade: 6
# as: 64
# 2000: 2
# 20: 3
# kilograms: 1
# per: 12
# person: 3
# or: 19
# 2: 3
# ounces: 1
# day: 2
# he: 8
# enthroned: 2
# phnom: 23
# penh: 19
# 29: 1
# october: 5
# 2004.: 2
# officially: 2
# multiparty: 2
# democracy: 1
# reality: 1
# remain: 2
# oneparty: 3
# state: 11
# dominated: 3
# cambodian: 48
# people: 22
# prime: 10
# minister: 13
# hun: 18
# sen: 15
# recast: 1
# khmer: 45
# rouge: 13
# official: 8
# power: 9
# since: 9
# 1985.: 1
# open: 1
# doors: 1
# new: 10
# investment: 5
# his: 19
# reign: 1
# have: 22
# yielded: 1
# access: 3
# coterie: 1
# cronies: 1
# wife: 1
# bun: 2
# rany: 1
# according: 7
# megha: 1
# bahree: 1
# writer: 1
# forbes: 1
# 15day: 1
# festival: 2
# offer: 1
# prayers: 1
# spirits: 4
# dead: 1
# relatives: 1
# assumed: 1
# office: 2
# 39: 1
# years: 6
# ago: 1
# one: 12
# world: 15
# longestserving: 1
# leaders: 3
# among: 4
# worst: 2
# places: 3
# organised: 3
# labour: 7
# 2015: 1
# international: 26
# union: 4
# confederation: 1
# rights: 7
# landing: 1
# category: 1
# countries: 8
# with: 58
# guarantee: 1
# development: 10
# research: 5
# center: 1
# united: 6
# nations: 7
# considered: 4
# southeast: 14
# asia: 8
# vulnerable: 3
# effects: 2
# climate: 8
# change: 5
# alongside: 1
# philippines: 2
# royal: 6
# dances: 9
# like: 3
# apsara: 1
# dance: 11
# icons: 1
# culture: 8
# mahori: 2
# ensembles: 1
# that: 33
# accompany: 1
# them: 2
# year: 4
# 1975: 2
# communist: 1
# troops: 3
# launched: 4
# an: 20
# offensive: 1
# which: 23
# 117: 1
# days: 2
# led: 7
# collapse: 1
# republic: 4
# scholar: 1
# george: 1
# coedes: 2
# refers: 1
# 10thcentury: 1
# inscription: 1
# dynastic: 1
# legend: 2
# hermit: 1
# kambu: 3
# swayambhuva: 2
# celestial: 1
# nymph: 1
# mera: 1
# unite: 1
# establish: 1
# solar: 1
# dynasty: 2
# begins: 2
# chenla: 4
# ruler: 2
# srutavarman: 1
# son: 5
# sreshthavarman: 1
# companies: 2
# deal: 1
# extensive: 3
# red: 3
# tape: 1
# obtaining: 3
# licenses: 4
# permits: 4
# especially: 2
# constructionrelated: 2
# demand: 1
# bribes: 2
# commonplace: 3
# process: 3
# elements: 1
# other: 22
# religious: 2
# practices: 4
# such: 9
# veneration: 1
# folk: 6
# heroes: 1
# ancestors: 1
# confucianism: 1
# taoism: 1
# mix: 1
# chinese: 4
# buddhism: 7
# also: 15
# practised: 2
# some: 11
# iron: 2
# age: 3
# settlements: 1
# were: 22
# found: 4
# beneath: 1
# baksei: 1
# chamkrong: 1
# angkorian: 4
# temples: 4
# while: 9
# circular: 2
# earthworks: 2
# discovered: 3
# at: 20
# site: 5
# lovea: 1
# northwest: 2
# angkor: 6
# 20102015: 1
# annual: 4
# rate: 5
# deforestation: 4
# 1.3: 1
# yai: 1
# can: 9
# be: 15
# performed: 6
# solo: 1
# man: 2
# woman: 3
# comedic: 1
# nature: 1
# much: 5
# area: 8
# been: 19
# designated: 1
# biosphere: 4
# reserve: 4
# classical: 3
# form: 2
# stylised: 1
# performance: 2
# art: 1
# established: 6
# courts: 1
# exhibited: 1
# both: 5
# entertainment: 1
# ceremonial: 1
# purposes: 2
# arms: 2
# came: 2
# from: 66
# vietnam: 18
# soviet: 1
# april: 6
# 2016: 3
# assembly: 6
# adopted: 2
# law: 7
# unions: 1
# naturally: 2
# regenerating: 2
# forest: 9
# 4: 1
# reported: 5
# primary: 6
# attract: 1
# government: 19
# could: 4
# improve: 3
# governance: 1
# adopt: 1
# clear: 2
# targets: 1
# develop: 1
# effective: 1
# regulatory: 3
# framework: 2
# project: 3
# bankability: 1
# facilitate: 1
# market: 1
# entry: 1
# investors: 1
# result: 2
# various: 8
# charitable: 1
# organisations: 3
# assisted: 1
# social: 10
# economic: 5
# civil: 5
# infrastructure: 5
# needs: 2
# prostitution: 1
# illegal: 2
# appears: 1
# prevalent: 2
# upstream: 1
# dams: 2
# will: 3
# imperil: 1
# stocks: 1
# provide: 2
# vast: 2
# majority: 7
# protein: 2
# denude: 1
# mekong: 14
# river: 9
# silt: 1
# rice: 11
# basket: 1
# major: 6
# secondary: 1
# crops: 1
# maize: 1
# cassava: 1
# sweet: 1
# potatoes: 1
# groundnuts: 1
# soybeans: 1
# sesame: 1
# seeds: 1
# beans: 3
# rubber: 2
# visitor: 1
# arrivals: 2
# 2018: 4
# topped: 1
# six: 1
# million: 15
# tenfold: 1
# increase: 3
# beginning: 2
# 21st: 1
# century: 4
# formerly: 1
# part: 9
# empire: 9
# delta: 3
# had: 8
# controlled: 1
# vietnamese: 13
# 1698: 1
# king: 13
# chey: 1
# chettha: 1
# ii: 3
# granting: 1
# permission: 1
# settle: 1
# decades: 1
# before: 4
# geography: 1
# 181035: 2
# lies: 1
# entirely: 1
# within: 3
# tropics: 1
# between: 11
# latitudes: 1
# 10: 3
# 15n: 1
# longitudes: 1
# 102: 1
# 108e: 1
# 1993: 2
# there: 10
# growing: 3
# use: 5
# english: 2
# replacing: 1
# french: 10
# language: 5
# 2019: 2
# 12: 1
# brewpubs: 1
# microbreweries: 2
# wat: 2
# historical: 1
# park: 3
# siem: 4
# reap: 4
# province: 7
# beaches: 1
# sihanoukville: 4
# capital: 3
# city: 7
# 150: 1
# casinos: 1
# attractions: 1
# tourists: 4
# hosted: 1
# ganefo: 1
# games: 5
# 1966: 1
# recently: 1
# sea: 2
# 2023.: 2
# divided: 3
# three: 3
# categories: 1
# throne: 2
# vacant: 1
# 1941: 2
# death: 2
# monivong: 3
# sisowath: 3
# france: 3
# passed: 1
# over: 11
# monireth: 1
# feeling: 1
# too: 1
# independently: 1
# minded: 1
# economy: 3
# capita: 2
# income: 1
# 4022: 1
# ppp: 1
# 1309: 1
# nominal: 1
# involves: 1
# local: 2
# population: 16
# businesses: 1
# authorities: 1
# well: 3
# transnational: 1
# corporations: 1
# all: 4
# two: 10
# networks: 2
# separated: 1
# time: 4
# space: 1
# indicate: 1
# shift: 1
# network: 2
# 2nd4th: 1
# ad: 2
# probably: 2
# due: 2
# changes: 1
# sociopolitical: 1
# powers: 2
# slavery: 1
# estimated: 3
# 256800: 1
# enslaved: 1
# modernday: 1
# 1.65: 1
# boasts: 1
# distinct: 4
# street: 1
# foods: 1
# members: 4
# pac: 1
# concurred: 1
# findings: 1
# evaluation: 2
# related: 3
# impact: 2
# programme: 5
# garment: 6
# sector: 7
# workers: 6
# including: 9
# a.: 1
# contributing: 1
# sustained: 3
# overall: 2
# growth: 5
# industry: 6
# b.: 1
# improving: 1
# lives: 2
# least: 4
# half: 4
# factories: 5
# bfc: 2
# many: 7
# family: 1
# c.: 1
# ensuring: 1
# receive: 1
# correct: 1
# wages: 1
# protection: 3
# benefits: 1
# d.: 2
# virtually: 1
# eliminating: 1
# child: 1
# e.: 1
# making: 3
# safer: 1
# f.: 1
# creating: 1
# level: 2
# playing: 1
# field: 2
# across: 4
# g.: 1
# influencing: 1
# business: 2
# through: 5
# using: 4
# factory: 1
# data: 2
# highlight: 1
# areas: 5
# improvement: 2
# being: 7
# core: 1
# risk: 2
# management: 2
# strategies: 1
# brandsbuyers: 1
# water: 3
# levels: 3
# ecology: 1
# productivity: 1
# tonlé: 2
# recent: 1
# affecting: 1
# security: 3
# agriculture: 6
# large: 3
# proportion: 1
# demographics: 1
# protectorate: 3
# condudcted: 1
# first: 6
# census: 3
# 1921.: 1
# only: 7
# men: 3
# aged: 2
# 60: 1
# counted: 1
# purpose: 2
# collection: 1
# taxes: 1
# anglicisation: 1
# cambodge: 1
# turn: 2
# transliteration: 1
# កមពជ: 1
# after: 13
# japanese: 2
# occupation: 2
# second: 2
# war: 8
# gained: 3
# independence: 2
# 1953.: 1
# extended: 1
# 1965: 1
# via: 2
# ho: 2
# chi: 2
# minh: 2
# sihanouk: 16
# trails: 1
# 2012: 3
# exports: 3
# grew: 3
# 4.61: 1
# billion: 3
# up: 5
# 8: 1
# 2011.: 1
# 2013: 5
# worth: 1
# 1.56: 1
# 14: 1
# 2004: 4
# norodom: 10
# sihamoni: 3
# selected: 1
# special: 2
# ninemember: 1
# council: 1
# selection: 1
# quickly: 1
# put: 1
# place: 2
# abdication: 2
# week: 2
# prior: 1
# they: 7
# taken: 1
# care: 1
# wrapping: 1
# cloth: 1
# protect: 2
# moisture: 1
# landmines: 1
# exploded: 1
# ordnance: 1
# alone: 2
# caused: 1
# 44630: 1
# injuries: 2
# 1979: 1
# mineuxo: 1
# victim: 1
# information: 2
# environmental: 4
# degradation: 1
# includes: 4
# parks: 1
# wildlife: 6
# sanctuaries: 2
# scale: 2
# endangered: 1
# endemic: 1
# species: 6
# now: 6
# threatened: 2
# extinction: 1
# loss: 1
# habitats: 2
# 1997: 5
# fearing: 1
# coprime: 3
# prince: 3
# ranariddh: 5
# coup: 5
# army: 3
# purge: 1
# supporters: 1
# humble: 1
# farming: 1
# background: 1
# just: 2
# 33: 2
# took: 1
# 1985: 2
# longruling: 1
# dictator: 1
# supported: 2
# 1: 2
# flowing: 1
# south: 4
# eastern: 1
# regions: 1
# sung: 1
# duo: 1
# women: 5
# take: 1
# turns: 1
# answering: 1
# verse: 1
# posing: 1
# riddles: 1
# solve: 1
# short: 1
# instrumental: 1
# breaks: 1
# verses: 1
# 1990s: 2
# saw: 1
# popularity: 2
# kantrum: 1
# style: 2
# surin: 1
# set: 2
# modern: 5
# instrumentation: 1
# rich: 1
# fisheries: 2
# largest: 6
# freshwater: 2
# lake: 5
# largely: 4
# impoverished: 1
# territory: 3
# belongs: 2
# combination: 1
# thailand: 11
# disrespecting: 1
# thai: 1
# upbuild: 1
# lack: 2
# military: 4
# left: 2
# situation: 1
# unsettled: 1
# 1962.: 1
# china: 6
# cultivated: 1
# ties: 2
# 2010s: 3
# muslim: 1
# 80: 2
# ethnic: 7
# cham: 4
# expected: 2
# free: 1
# land: 9
# mines: 2
# 2025: 1
# orphans: 1
# 290: 1
# amputee: 1
# affect: 1
# come: 4
# duties: 1
# providing: 1
# public: 5
# peace: 5
# investigate: 2
# prevent: 1
# crime: 2
# terrorism: 1
# violent: 2
# groups: 8
# private: 1
# property: 1
# help: 1
# assist: 1
# civilians: 1
# emergency: 2
# forces: 10
# case: 2
# natural: 1
# disaster: 1
# unrest: 2
# armed: 6
# conflicts: 2
# indigenous: 1
# mountains: 5
# collectively: 1
# montagnards: 1
# loeu: 3
# meaning: 1
# highland: 2
# infant: 1
# mortality: 1
# decreased: 2
# 86: 1
# 1000: 1
# live: 1
# births: 1
# 1998: 1
# 24: 2
# 2018.: 2
# health: 1
# indicators: 1
# ratanakiri: 3
# 22.9: 1
# children: 9
# die: 1
# five: 4
# bestpreserved: 1
# example: 1
# architecture: 3
# along: 1
# hundreds: 3
# around: 10
# region: 5
# secondlargest: 1
# minority: 1
# 16000: 1
# living: 1
# provinces: 8
# concentrated: 1
# adjacent: 2
# tra: 2
# leaf: 1
# books: 2
# record: 2
# legends: 1
# ramayana: 2
# origin: 2
# prayer: 1
# lemon: 3
# te: 2
# kdau: 1
# kroch: 1
# chhma: 1
# made: 3
# reddust: 1
# juice: 1
# refreshing: 1
# hot: 1
# iced: 1
# generally: 4
# served: 1
# hefty: 1
# dose: 1
# diplomatic: 1
# numerous: 3
# reports: 1
# twenty: 1
# embassies: 1
# asian: 8
# neighbours: 2
# those: 5
# important: 5
# players: 1
# paris: 2
# negotiations: 1
# us: 7
# australia: 1
# canada: 1
# european: 1
# japan: 1
# russia: 1
# cuisine: 4
# relatively: 1
# unknown: 1
# compared: 2
# ports: 1
# minor: 2
# ones: 1
# vowed: 1
# rule: 3
# until: 5
# turned: 1
# 74.: 1
# regularly: 1
# accused: 1
# ignoring: 1
# human: 3
# suppressing: 1
# dissent: 1
# crooner: 1
# sinn: 1
# sisamouth: 1
# ros: 1
# sereysothea: 1
# pen: 1
# ran: 1
# 1960s: 2
# 1970s: 2
# pop: 1
# 18: 2
# may: 5
# advisory: 1
# committee: 2
# ilo: 1
# better: 2
# met: 1
# input: 1
# draft: 1
# conclusions: 1
# recommendations: 1
# independent: 1
# midterm: 1
# discuss: 1
# options: 1
# how: 3
# further: 2
# strengthen: 1
# transparent: 1
# reporting: 1
# initiative: 2
# borders: 1
# north: 7
# west: 2
# laos: 4
# northeast: 2
# east: 4
# 1.04: 1
# female: 4
# male: 2
# ratio: 3
# femalebiased: 1
# sex: 1
# greater: 2
# subregion: 2
# spans: 1
# 17: 3
# every: 2
# cambodians: 7
# visit: 1
# pagodas: 1
# mark: 1
# pchum: 1
# ben: 1
# demanded: 2
# operating: 2
# licences: 1
# member: 9
# bank: 9
# asean: 4
# joined: 1
# wto: 2
# 2005: 2
# attended: 2
# inaugural: 1
# summit: 2
# malaysia: 1
# burials: 1
# testify: 1
# availability: 1
# existence: 1
# structure: 2
# organization: 3
# vietnameseoccupied: 1
# kampuchea: 4
# de: 4
# facto: 4
# confiscated: 2
# thousands: 3
# than: 7
# decade: 1
# selfenrichment: 1
# maintaining: 1
# interests: 1
# prosoviet: 1
# kampuchean: 1
# revolutionary: 1
# created: 3
# 1951: 1
# group: 5
# who: 4
# fled: 2
# avoid: 1
# purged: 1
# pol: 2
# pot: 2
# ta: 1
# mok: 1
# bon: 1
# om: 1
# touk: 1
# boat: 3
# rowing: 1
# contest: 1
# lao: 1
# pdr: 1
# noted: 1
# several: 2
# key: 5
# concerns: 2
# gaps: 1
# 95: 2
# buddhist: 1
# destroyed: 2
# july: 3
# 2023: 5
# election: 10
# ruling: 2
# easily: 1
# won: 3
# landslide: 1
# flawed: 1
# disqualification: 1
# candlelight: 2
# australian: 1
# hip: 1
# hop: 1
# astronomy: 1
# class: 2
# recorded: 3
# kak: 1
# channthy: 1
# nativeborn: 1
# singer: 1
# so: 1
# livelihoods: 1
# economically: 1
# nutritionally: 1
# said: 2
# gordon: 1
# holtgrieve: 1
# professor: 1
# university: 2
# washington: 1
# points: 1
# out: 4
# none: 1
# either: 2
# built: 2
# pointing: 1
# good: 1
# outcomes: 1
# western: 5
# instruments: 2
# mixture: 1
# traditional: 6
# wine: 1
# alcoholic: 1
# drink: 2
# judges: 1
# lawyers: 3
# executed: 1
# deemed: 1
# enemies: 2
# 612: 2
# legal: 1
# professionals: 2
# actually: 1
# survived: 1
# remained: 1
# passengers: 1
# remnants: 1
# becoming: 1
# firmly: 1
# 802: 2
# jayavarman: 3
# declared: 2
# java: 1
# proclaimed: 1
# themselves: 1
# devaraja: 1
# marked: 2
# challenges: 2
# facing: 1
# still: 3
# fact: 1
# older: 1
# lacks: 1
# education: 9
# particularly: 3
# countryside: 1
# suffers: 1
# basic: 1
# factors: 1
# contribute: 1
# theravada: 4
# hinduism: 3
# colonialism: 1
# globalization: 1
# based: 2
# economist: 1
# imf: 1
# average: 5
# gdp: 4
# period: 6
# 20012010: 1
# 7.7: 1
# top: 2
# ten: 1
# highest: 4
# analogous: 1
# unusual: 1
# disappears: 1
# then: 1
# expands: 1
# massively: 1
# flow: 2
# backs: 1
# rains: 1
# 65: 1
# 1.61.: 1
# total: 4
# fertility: 3
# 2.5: 2
# 4.0: 1
# 2000.: 1
# urban: 3
# 2.2: 1
# 3.3: 1
# sole: 2
# dominantparty: 1
# despite: 1
# adopting: 1
# anticorruption: 2
# 2010: 6
# corruption: 4
# prevails: 1
# throughout: 3
# worked: 1
# 500: 1
# bc: 4
# supporting: 1
# evidence: 4
# coming: 1
# khorat: 1
# plateau: 1
# what: 2
# later: 2
# colonisation: 1
# 1863: 1
# signed: 3
# treaty: 2
# mainstay: 1
# results: 2
# disputed: 2
# leading: 1
# demonstrations: 1
# rebels: 1
# began: 2
# him: 2
# gain: 2
# support: 4
# grown: 1
# mondulkiri: 2
# kirirom: 1
# provided: 3
# whistleblowers: 2
# jailed: 1
# 6: 1
# months: 1
# if: 2
# report: 2
# not: 7
# proven: 1
# event: 2
# prehistory: 1
# penetration: 1
# farmers: 1
# third: 1
# millennium: 2
# rapidly: 1
# 2000s: 1
# received: 1
# considerable: 2
# belt: 1
# road: 4
# initiative.a: 1
# unbacked: 1
# crimes: 5
# tribunal: 3
# sought: 1
# committed: 2
# democratic: 1
# prosecute: 1
# attack: 1
# against: 4
# president: 3
# overseas: 1
# press: 2
# club: 1
# rick: 1
# valenzuela: 1
# captured: 1
# video: 1
# visiting: 2
# beijing: 1
# 1970: 2
# ousted: 2
# general: 6
# lon: 2
# nol: 2
# sirik: 1
# matak: 1
# plain: 5
# abuts: 1
# sandstone: 1
# escarpment: 1
# southwardfacing: 1
# cliff: 1
# stretching: 1
# 200: 1
# miles: 1
# rising: 2
# abruptly: 1
# above: 2
# heights: 1
# 600: 1
# 1800: 1
# feet: 3
# southwestern: 2
# upland: 1
# blocks: 1
# krâvanh: 1
# dâmrei: 1
# covers: 1
# gulf: 2
# contains: 2
# tropical: 3
# fruits: 2
# soups: 1
# noodles: 1
# monsoon: 1
# ushers: 1
# lasts: 2
# november: 3
# viet: 1
# cong: 1
# desperate: 1
# retain: 1
# lines: 2
# attacks: 3
# cpp: 6
# seat: 2
# without: 1
# effectively: 2
# solidifying: 1
# remnant: 1
# colonial: 1
# past: 2
# dialect: 1
# sometimes: 2
# used: 1
# rivers: 2
# diet: 1
# respect: 1
# academic: 1
# school: 1
# showed: 2
# parental: 1
# attitudes: 1
# beliefs: 2
# played: 1
# significant: 5
# role: 3
# 1962: 2
# conducted: 1
# instability: 2
# lead: 1
# 36yearlong: 1
# gap: 1
# 1998.: 1
# younger: 1
# 22: 4
# old: 1
# quantity: 1
# souvenirs: 1
# produced: 3
# sufficient: 1
# face: 2
# increasing: 4
# number: 5
# sold: 1
# markets: 1
# imported: 3
# plan: 2
# makes: 1
# provision: 1
# establishing: 2
# science: 4
# technology: 3
# foundation: 1
# promote: 1
# industrial: 2
# particular: 3
# focus: 1
# icts: 1
# participated: 1
# olympics: 1
# 1956: 1
# summer: 1
# olympic: 1
# sending: 1
# equestrian: 1
# riders: 1
# colloquially: 2
# refer: 1
# srok: 1
# slightly: 1
# formal: 1
# បរទសកមពជ: 1
# speakers: 3
# un: 5
# withdrew: 1
# decided: 1
# 90: 2
# registered: 1
# voters: 1
# forced: 1
# evictions: 1
# senior: 1
# officials: 3
# governmentconnected: 1
# representative: 1
# thiounn: 1
# prasith: 1
# retained: 1
# work: 2
# consultation: 1
# representatives: 1
# noncommunist: 1
# parties: 3
# nevertheless: 1
# pleas: 1
# ignored: 1
# bombing: 1
# continued: 2
# held: 2
# end: 1
# sink: 1
# back: 1
# normal: 1
# allowing: 1
# reverse: 1
# approximately: 3
# attends: 1
# each: 2
# play: 1
# give: 1
# thanks: 1
# moon: 1
# watch: 2
# fireworks: 1
# dine: 2
# attend: 1
# race: 1
# carnivaltype: 1
# atmosphere: 1
# currently: 6
# designates: 1
# developed: 2
# august: 3
# directive: 1
# banning: 1
# finance: 3
# issuing: 1
# online: 2
# gambling: 1
# operators: 1
# holding: 1
# would: 1
# allowed: 2
# continue: 1
# expire: 1
# classified: 1
# combines: 1
# westernstyle: 1
# rock: 1
# soccer: 2
# brought: 1
# locals: 1
# muslims: 1
# underwent: 1
# purges: 1
# exterminated: 1
# refusal: 1
# withdraw: 1
# sanctions: 1
# ingredients: 2
# kaffir: 1
# lime: 1
# grass: 1
# garlic: 2
# sauce: 3
# soy: 1
# tamarind: 1
# ginger: 1
# oyster: 1
# coconut: 1
# black: 1
# pepper: 1
# central: 5
# kingdom: 7
# provides: 1
# oversight: 2
# banking: 2
# responsible: 5
# direct: 2
# mahayana: 1
# religion: 4
# institutions: 5
# targeted: 2
# perceived: 1
# destructive: 1
# singular: 1
# issue: 1
# transition: 2
# 1978: 1
# invaded: 1
# response: 2
# border: 2
# raids: 1
# conquered: 1
# regime: 5
# suffered: 1
# setbacks: 1
# excavations: 1
# lower: 3
# layers: 2
# series: 2
# radiocarbon: 1
# dates: 1
# 6000: 1
# junction: 1
# bassac: 1
# port: 1
# capable: 1
# receiving: 1
# 8000ton: 1
# ships: 2
# wet: 3
# 5000ton: 1
# 25: 1
# autonomous: 2
# municipality: 2
# legislative: 1
# shared: 2
# executive: 2
# bicameral: 1
# parliament: 2
# consists: 1
# house: 2
# upper: 3
# senate: 3
# temperature: 1
# range: 3
# 21: 1
# 35: 1
# c: 3
# experiences: 1
# monsoons: 3
# affects: 1
# judiciary: 1
# police: 3
# 1987: 1
# passenger: 2
# train: 1
# operated: 1
# battambang: 3
# 141: 1
# funded: 1
# mostly: 1
# started: 1
# revitalise: 1
# languishing: 1
# rail: 2
# logistics: 1
# centers: 1
# bangkok: 1
# seasons: 1
# totalling: 1
# single: 1
# onemetre: 1
# gauge: 1
# track: 1
# estimates: 2
# unexploded: 1
# 60000: 1
# civilian: 1
# deaths: 1
# maimed: 1
# injured: 2
# 1970.: 1
# landmine: 1
# casualties: 1
# sharply: 1
# 800: 1
# 111: 1
# proposed: 1
# staging: 1
# protests: 2
# streets: 1
# demanding: 1
# wage: 1
# increases: 1
# improvements: 2
# working: 2
# conditions: 3
# once: 2
# landmined: 1
# southwest: 1
# blow: 1
# inland: 2
# bringing: 1
# moistureladen: 1
# winds: 1
# indian: 2
# ocean: 1
# function: 1
# debated: 1
# possibly: 1
# date: 1
# introduction: 2
# revised: 1
# command: 1
# early: 2
# prelude: 1
# reorganisation: 1
# guests: 1
# banquets: 1
# informal: 1
# gatherings: 1
# funcinpec: 2
# hung: 1
# hill: 2
# tribe: 1
# hunted: 1
# incessantly: 1
# off: 2
# slaves: 1
# siamese: 1
# annamites: 1
# reputation: 1
# safe: 1
# destination: 1
# tourism: 3
# hindered: 1
# highprofile: 1
# examples: 2
# serious: 1
# december: 2
# 2021: 1
# announced: 2
# manet: 3
# succeed: 1
# next: 1
# 2022: 2
# warned: 1
# newest: 1
# control: 1
# communists: 4
# imposed: 1
# eventually: 1
# referred: 1
# opposed: 1
# trials: 1
# investigations: 1
# former: 7
# determined: 1
# keep: 1
# disenfranchise: 1
# any: 3
# threats: 1
# thus: 1
# increased: 4
# aggressive: 1
# actions: 2
# coastal: 2
# populations: 1
# principal: 2
# commodity: 1
# 2014: 2
# sentenced: 2
# khieu: 1
# samphan: 1
# 83yearold: 1
# head: 4
# nuon: 1
# chea: 1
# 88yearold: 1
# chief: 1
# ideologue: 1
# life: 3
# charges: 1
# terror: 1
# ucb: 1
# libraries: 1
# govpubs: 1
# profile: 1
# bbc: 1
# news: 1
# encyclopædia: 1
# britannica: 1
# wikimedia: 1
# atlas: 1
# geographic: 1
# openstreetmap: 1
# forecasts: 1
# futures: 1
# website: 1
# cambodia.gov.kh: 1
# isolated: 1
# highlands: 1
# indianized: 1
# cousins: 1
# consequently: 1
# culturally: 2
# distant: 1
# khmers: 1
# observing: 1
# preindiancontact: 1
# customs: 1
# descended: 3
# austronesian: 2
# champa: 1
# coast: 1
# southern: 3
# presentday: 1
# rival: 1
# already: 1
# europe: 1
# 1524: 1
# antonio: 1
# pigafetta: 1
# cites: 1
# relazione: 1
# del: 1
# primo: 1
# viaggio: 1
# intorno: 1
# al: 1
# mondo: 1
# camogia: 1
# seven: 2
# reporters: 1
# protesters: 2
# hit: 1
# slingshot: 1
# projectiles: 1
# hospitalized: 1
# commands: 1
# 120: 1
# 125: 1
# seats: 3
# 55: 1
# 62: 1
# surrendered: 1
# 5: 1
# mission: 2
# evacuated: 1
# détat: 2
# consolidated: 2
# 123seat: 1
# elected: 2
# proportional: 1
# representation: 1
# serve: 1
# maximum: 1
# intricately: 1
# costumed: 1
# highly: 2
# trained: 1
# occasions: 1
# tribute: 1
# invocation: 1
# enact: 1
# stories: 1
# epic: 1
# poems: 1
# reamker: 1
# version: 2
# prahok: 1
# longer: 1
# storage: 1
# acclaimed: 1
# universities: 2
# simultaneous: 1
# perimeter: 1
# pinned: 1
# down: 3
# republican: 1
# cpk: 1
# units: 1
# overran: 1
# fire: 1
# bases: 1
# controlling: 1
# vital: 1
# resupply: 1
# route: 2
# 13th: 1
# missionaries: 2
# sri: 1
# lanka: 1
# reintroduced: 2
# having: 1
# sent: 1
# previously: 1
# 1190s: 1
# airport: 6
# accounted: 1
# cent: 3
# employed: 1
# workforce: 2
# sports: 7
# basketball: 1
# bodybuilding: 1
# hockey: 1
# rugby: 1
# golf: 1
# baseball: 1
# gaining: 1
# cover: 2
# 46: 1
# equivalent: 1
# 8068370: 1
# hectares: 5
# 2020: 3
# 11004790: 1
# 1990.: 1
# covered: 3
# 7464400: 1
# planted: 1
# 603970: 1
# comprised: 1
# 102000: 1
# active: 1
# personnel: 1
# neighbouring: 4
# populous: 1
# followed: 1
# cyclos: 1
# unique: 2
# cyclist: 1
# sits: 1
# behind: 1
# engages: 1
# employers: 1
# governments: 1
# boost: 1
# competitiveness: 1
# able: 2
# stabilize: 1
# accepted: 1
# association: 2
# 30: 1
# 1999.: 2
# crowned: 1
# father: 2
# youth: 2
# policies: 1
# guidelines: 1
# techo: 1
# intended: 1
# replace: 1
# existing: 2
# construction: 2
# staple: 1
# grain: 1
# 2001: 1
# partnership: 1
# corporation: 1
# progressed: 1
# policy: 2
# neutrality: 1
# cold: 1
# killed: 2
# 3: 2
# cited: 1
# figure: 1
# 61: 1
# appointed: 1
# rest: 2
# commune: 2
# councillors: 1
# extending: 1
# outward: 1
# transitional: 1
# plains: 1
# thinly: 1
# forested: 1
# elevations: 1
# 650: 1
# rcep: 1
# nonaligned: 1
# movement: 1
# la: 2
# francophonie: 2
# dialogue: 1
# partner: 1
# shanghai: 1
# cooperation: 3
# organisation: 1
# native: 3
# racing: 2
# buffalo: 1
# pradal: 1
# serey: 1
# wrestling: 1
# bokator: 1
# following: 2
# 1991: 1
# accords: 1
# formally: 2
# ended: 3
# governed: 1
# institute: 1
# 750: 1
# varieties: 2
# seed: 1
# football: 1
# although: 4
# professional: 1
# because: 5
# where: 4
# encounter: 1
# corrupt: 1
# everyday: 1
# medical: 1
# services: 1
# dealing: 1
# alleged: 1
# traffic: 2
# violations: 1
# pursuing: 1
# fair: 1
# verdicts: 1
# distinctly: 1
# seasonal: 1
# differences: 1
# doctors: 1
# teachers: 1
# journalists: 1
# covering: 2
# protest: 1
# september: 1
# say: 1
# deliberately: 1
# attacked: 2
# clothes: 1
# slingshots: 1
# stun: 1
# guns: 1
# fraud: 1
# vote: 1
# tampering: 1
# june: 1
# elections: 1
# assistance: 2
# upgrading: 1
# highways: 1
# standards: 1
# vastly: 1
# improved: 1
# 2006.: 1
# roads: 1
# paved: 1
# administrative: 2
# divisions: 2
# firstlevel: 1
# 2007: 2
# team: 1
# researchers: 1
# satellite: 1
# photographs: 1
# techniques: 1
# concluded: 1
# preindustrial: 1
# sprawl: 1
# 2980: 1
# trains: 1
# run: 1
# sisophon: 1
# regulated: 1
# banks: 1
# microfinance: 1
# 31: 1
# entities: 2
# 70: 2
# individual: 1
# underlining: 1
# himself: 1
# uniting: 1
# warring: 1
# princes: 1
# name: 2
# kambuja: 1
# mondol: 1
# kiri: 2
# rattanak: 1
# 4.5: 1
# lowest: 1
# 2.0: 1
# dwellers: 1
# engaged: 1
# primarily: 1
# commerce: 2
# powersharing: 1
# agreement: 1
# agreed: 1
# simultaneously: 2
# ministers: 1
# secede: 1
# fully: 1
# transferred: 1
# quality: 2
# varies: 1
# widely: 1
# infused: 1
# medicinal: 1
# herbs: 1
# remains: 1
# leadership: 1
# invasion: 1
# richard: 1
# nixon: 1
# ground: 1
# entered: 1
# campaign: 1
# aimed: 1
# destroying: 1
# nva: 1
# base: 1
# spending: 1
# stands: 1
# robert: 1
# kaplan: 1
# eyeglasses: 1
# deadly: 1
# yellow: 1
# star: 1
# seen: 2
# sign: 1
# intellectualism: 1
# amnesty: 1
# recognises: 1
# prisoner: 1
# conscience: 1
# 33yearold: 1
# activist: 1
# yorm: 1
# bopha: 1
# remote: 1
# uninhabited: 1
# aural: 2
# peak: 1
# rises: 1
# elevation: 1
# 5949: 1
# reasons: 1
# opportunistic: 1
# loggings: 1
# clearings: 1
# big: 1
# projects: 1
# agricultural: 1
# activities: 1
# original: 1
# master: 1
# tapes: 1
# lost: 1
# controversy: 1
# continues: 1
# terms: 1
# net: 1
# enrolment: 1
# gains: 1
# program: 1
# basedbudgeting: 1
# helps: 1
# disadvantaged: 1
# usfunded: 1
# airlift: 1
# ammunition: 1
# congress: 1
# refused: 1
# additional: 1
# aid: 4
# defense: 2
# banh: 1
# lasted: 1
# 1953: 1
# brief: 1
# interruption: 1
# occupied: 1
# 1945: 1
# puppet: 1
# 1945.: 1
# 1874: 1
# 946000: 1
# 5.7: 1
# credible: 1
# nongovernmental: 1
# estimate: 1
# 770000: 1
# adversely: 1
# affected: 2
# grabbing: 1
# four: 1
# says: 1
# parisbased: 1
# federation: 1
# delicacies: 1
# num: 1
# banhchok: 1
# amok: 1
# aping: 1
# sanctuary: 6
# fighting: 1
# demonstrators: 1
# 20000: 1
# gathered: 1
# clashing: 1
# riot: 1
# archaeological: 2
# shows: 1
# communities: 1
# huntergatherers: 1
# inhabited: 1
# holocene: 1
# ancient: 1
# discovery: 1
# cave: 1
# laang: 1
# spean: 1
# hoabinhian: 1
# secretaries: 1
# chay: 1
# saing: 1
# yun: 1
# por: 1
# sreu: 1
# employs: 3
# 335400: 1
# 91: 1
# these: 3
# collected: 1
# traditionally: 2
# leaves: 2
# cyclo: 1
# cycle: 1
# rickshaws: 2
# increasingly: 1
# replaced: 1
# remorques: 1
# india: 2
# fell: 1
# 1969: 1
# 3.1: 1
# 2007.: 2
# less: 1
# 3220: 1
# km2: 1
# future: 1
# sustainability: 1
# reserves: 1
# severe: 2
# threat: 1
# roasted: 1
# butter: 1
# plus: 1
# might: 1
# anything: 1
# rum: 1
# pork: 3
# fat: 1
# giving: 1
# beverage: 1
# strange: 1
# faintly: 1
# chocolatey: 1
# aroma: 1
# upon: 1
# 1960: 1
# again: 1
# taking: 1
# title: 1
# heavily: 1
# decentralised: 1
# provincial: 1
# district: 1
# rules: 1
# objections: 1
# thwart: 1
# diplomatically: 1
# useful: 1
# counterweight: 1
# closer: 1
# states: 3
# majesty: 1
# commander: 1
# holds: 1
# position: 1
# commanderinchief: 1
# influence: 1
# curry: 1
# toasted: 1
# baguette: 1
# bread: 1
# preangkorian: 1
# postangkor: 1
# 3rd: 1
# 4th: 1
# 5th: 1
# centuries: 1
# indianised: 1
# funan: 1
# successor: 1
# coalesced: 1
# typically: 1
# fasterpaced: 1
# display: 1
# themes: 1
# common: 1
# love: 1
# comedy: 1
# warding: 1
# evil: 1
# kicking: 1
# sey: 1
# similar: 1
# footbag: 1
# chess: 1
# lowland: 1
# tribes: 1
# coined: 1
# encourage: 1
# unity: 1
# highlanders: 1
# lowlanders: 1
# prohibition: 1
# nuclear: 1
# weapons: 1
# runs: 1
# see: 1
# temperatures: 2
# drop: 1
# accompanied: 2
# humidity: 1
# celebrates: 1
# cultural: 1
# tributaries: 1
# avenues: 1
# length: 1
# 3700: 1
# navigable: 2
# craft: 2
# drawing: 2
# 0.6: 1
# metres: 2
# 282: 1
# 1.8: 1
# krolap: 1
# strong: 1
# putting: 1
# small: 1
# glass: 2
# placing: 1
# saucer: 1
# turning: 1
# whole: 1
# thing: 1
# upside: 1
# brew: 1
# 4392: 1
# monastery: 1
# strategy: 1
# action: 1
# implemented: 1
# late: 1
# ideas: 1
# incite: 1
# green: 2
# environmentally: 1
# sustainable: 1
# representing: 1
# 11: 1
# ministries: 2
# umbrella: 1
# successfully: 1
# nominated: 1
# unesco: 1
# districts: 2
# municipalities: 2
# communes: 1
# quarters: 1
# neolithic: 2
# migrations: 1
# monkhmer: 2
# insular: 1
# 212: 1
# mammal: 1
# 536: 1
# bird: 1
# 240: 1
# reptile: 1
# 850: 2
# 435: 1
# marine: 1
# originated: 1
# villages: 2
# villagers: 2
# viii: 1
# mongol: 1
# kublai: 1
# khan: 1
# buy: 1
# little: 1
# trace: 1
# beyond: 1
# magical: 1
# tantricism: 1
# host: 1
# hindu: 1
# gods: 1
# assimilated: 1
# spirit: 1
# credit: 1
# bureau: 1
# robam: 1
# preah: 3
# reach: 1
# troap: 1
# pinpeat: 1
# ensemble: 1
# vocal: 1
# chorus: 1
# prehistoric: 1
# soils: 1
# near: 1
# memot: 1
# latter: 1
# 1950s: 1
# instead: 1
# maternal: 1
# grandson: 1
# 1972: 1
# conflict: 2
# same: 2
# message: 1
# conveyed: 1
# johnson: 1
# emissary: 1
# chester: 1
# bowles: 1
# january: 1
# 1968.: 1
# refuted: 1
# right: 1
# u.s.: 1
# air: 1
# strikes: 1
# 26: 3
# march: 2
# criminal: 1
# must: 1
# immediately: 1
# definitively: 1
# stop: 1
# stability: 1
# shaken: 1
# represented: 2
# 12th: 1
# fear: 1
# renewed: 1
# discourage: 1
# delay: 1
# bilateral: 1
# multilateral: 1
# donors: 2
# disagreements: 1
# offshore: 1
# islands: 1
# sections: 1
# boundary: 1
# undefined: 1
# maritime: 1
# boundaries: 1
# waterways: 1
# historically: 1
# favouritism: 1
# impunity: 1
# evergreen: 1
# dipterocarp: 1
# forests: 1
# mondolkiri: 1
# protected: 1
# seima: 1
# prich: 1
# srepok: 1
# cardamom: 1
# ecosystem: 1
# botumsakor: 1
# samkos: 1
# crackdown: 1
# script: 2
# derived: 1
# pallava: 2
# tourist: 1
# souvenir: 1
# lot: 1
# interest: 1
# did: 1
# reappear: 1
# 1995: 1
# bar: 1
# flooding: 1
# pacific: 1
# typhoon: 1
# plans: 2
# hydroelectric: 1
# pose: 1
# real: 1
# danger: 1
# 70th: 1
# peaceful: 1
# 2024: 1
# densely: 1
# populated: 1
# devoted: 1
# cultivation: 1
# heartland: 1
# deeply: 1
# influenced: 2
# animism: 1
# subdivided: 1
# 159: 1
# negative: 1
# advised: 1
# focuses: 1
# mitigation: 1
# measures: 1
# planning: 1
# culmination: 1
# twoyear: 1
# korea: 1
# agency: 1
# surrounding: 2
# fastestgrowing: 1
# 219000: 1
# inflation: 1
# 1.7: 1
# 1.6: 1
# healthcare: 1
# raising: 1
# awareness: 1
# hivaids: 1
# malaria: 1
# diseases: 1
# dish: 1
# kuyteav: 1
# broth: 1
# noodle: 1
# soup: 1
# fried: 1
# scallions: 1
# onions: 1
# contain: 1
# toppings: 1
# beef: 1
# balls: 1
# shrimp: 1
# liver: 1
# lettuce: 1
# translates: 1
# roughly: 1
# jobs: 1
# commercial: 2
# airports: 1
# biodiversity: 1
# contained: 1
# ministerial: 1
# appointees: 1
# exercise: 1
# composed: 1
# styles: 2
# 19th20thcentury: 1
# settlers: 1
# search: 1
# opportunities: 1
# ahead: 1
# enacted: 1
# tighter: 1
# curbs: 1
# media: 2
# completed: 1
# leave: 1
# landscape: 1
# characterised: 1
# lowlying: 1
# surrounded: 1
# uplands: 1
# low: 1
# reaches: 1
# containing: 1
# earliest: 1
# dated: 1
# earthenware: 1
# ceramics: 1
# kinds: 1
# beads: 1
# recovered: 1
# sites: 1
# phum: 1
# snay: 1
# prohear: 1
# suggest: 1
# trading: 1
# kang: 1
# kek: 1
# iew: 1
# guilty: 1
# humanity: 1
# commandant: 1
# s21: 1
# extermination: 1
# camp: 1
# constitutionally: 1
# dominates: 1
# chacha: 1
# bolero: 1
# madison: 1
# homogeneous: 1
# kâmpŭchéa: 1
# shortened: 1
# alternative: 1
# ពររជណចករកមពជ: 1
# कमबज: 1
# referring: 1
# descendants: 1
# busiest: 1
# maintain: 1
# separate: 1
# encompasses: 1
# nine: 1
# kampong: 2
# thom: 1
# pursat: 1
# chhnang: 1
# banteay: 1
# meanchey: 2
# pailin: 1
# oddar: 1
# vihear: 1
# pledged: 1
# 504: 1
# loans: 1
# grants: 1
# technical: 1
# 28: 1
# conference: 1
# appealed: 1
# i: 2
# appeal: 1
# you: 1
# publicise: 1
# abroad: 1
# very: 1
# stand: 1
# cambodiathat: 1
# oppose: 1
# bombings: 1
# whatever: 1
# pretext: 1
# monetary: 1
# fund: 1
# besides: 1
# interprovincial: 1
# artery: 1
# connecting: 1
# resurfacing: 1
# dirt: 1
# concreteasphalt: 1
# bridging: 1
# crossings: 1
# permanently: 1
# connected: 1
# koh: 1
# kong: 1
# hence: 1
# uninterrupted: 1
# suggests: 1
# origins: 1
# kanchi: 1
# creation: 1
# myth: 1
# factbook: 1
# 40: 1
# sworn: 1
# wars: 1
# kingdoms: 1
# sacked: 1
# ayutthaya: 1
# abandoned: 1
# 1432: 1
# ecological: 1
# failure: 1
# breakdown: 1
# spread: 1
# sculpture: 1
# exchanged: 1
# regarding: 1
# coffee: 2
# domestically: 1
# educational: 1
# involvement: 1
# close: 1
# interrelationship: 1
# community: 1
# efficacy: 1
# apotropaic: 1
# luckattracting: 1
# charms: 1
# possibility: 1
# manipulating: 1
# contact: 1
# spiritual: 1
# baromey: 1
# originates: 1
# activity: 1
# automobile: 1
# though: 1
# motorcycles: 1
# predominate: 1
# crop: 1
# move: 1
# step: 1
# towards: 1
# approach: 1
# application: 1
# households: 1
# depend: 1
# subsectors: 1
# cities: 1
# languages: 1
# subfamily: 1
# austroasiatic: 1

# %%
from collections import defaultdict

def build_ngram_model(data, n):
    model = defaultdict(lambda: defaultdict(int))
    for sentence in data:
        for i in range(len(sentence) - n + 1):
            ngram = tuple(sentence[i:i+n])
            prefix, token = ngram[:-1], ngram[-1]
            model[prefix][token] += 1
    return model

def backoff_prob(model, ngram):
    prefix, token = ngram[:-1], ngram[-1]
    if prefix in model and sum(model[prefix].values()) > 0:
        if token in model[prefix]:
            return model[prefix][token] / sum(model[prefix].values())
    elif len(prefix) > 1:
        return backoff_prob(model, prefix[1:] + (token,))
    return 0  # Default probability if no valid prefix or tokens

ngram_model = build_ngram_model(train_tokens, 4)

# %%
# Build the LM2 interpolated method
def interpolated_prob(model, ngram, lambdas, k):
    n = len(ngram)
    prob = 0
    for i in range(1, n+1):
        prefix, token = ngram[:i-1], ngram[i-1]
        count = model[prefix][token] + k
        total_count = sum(model[prefix].values()) + k * vocab_size
        prob += lambdas[i-1] * (count / total_count)
    return prob

lambdas = [0.1, 0.2, 0.3, 0.4]  # Example weights
k = 1  # Example smoothing parameter

# %%
import math
import numpy as np

def perplexity(model, tokens, prob_func):
    log_prob_sum = 0
    total_tokens = 0
    
    for sentence in tokens:
        if len(sentence) < 4:
            continue
        
        for i in range(3, len(sentence)):
            # Create n-gram
            ngram = tuple(sentence[i-3:i+1])
            
            try:
                # Calculate probability
                prob = prob_func(model, ngram)
                
                # Handle zero or negative probabilities
                if prob <= 0:
                    prob = 1e-10  # Small positive value
                
                # Sum log probabilities
                log_prob = math.log2(prob)
                log_prob_sum += log_prob
                total_tokens += 1
            
            except Exception as e:
                print(f"Error processing n-gram {ngram}: {e}")
                continue
    
    # Avoid division by zero
    if total_tokens == 0:
        return float('inf')
    
    # Calculate perplexity
    perplexity_score = 2 ** (-log_prob_sum / total_tokens)
    
    return perplexity_score

pp_lm1 = perplexity(model=ngram_model, tokens=test_tokens, prob_func=backoff_prob)
pp_lm2 = perplexity(ngram_model, test_tokens, lambda m, n: interpolated_prob(m, n, lambdas, k))

print(f"pp_lm1: {pp_lm1}")
print(f"pp_lm2: {pp_lm2}")
# Out:
# pp_lm1: 5839811413.019416
# pp_lm2: 19780.5554358151

# %%
import random

def generate_text(model, start, length, prob_func):
    text = list(start)
    for _ in range(length - len(start)):
        prefix = tuple(text[-3:])
        if prefix not in model or not model[prefix] or sum(model[prefix].values()) == 0:
            next_words = random.choice(train_tokens)[:3]
            for next_word in next_words:
                text.append(next_word)
        else:
            next_word = max(model[prefix], key=lambda x: prob_func(model, prefix + (x,)))
            text.append(next_word)
    return ' '.join(text)

start_tokens = list(random.choice(train_tokens)[:3])
backoff_text = generate_text(ngram_model, start_tokens, 50, backoff_prob)
start_tokens = list(random.choice(train_tokens)[:3])
interpolation_text = generate_text(ngram_model, start_tokens, 50, lambda m, n: interpolated_prob(m, n, lambdas, k))
print(f"Backoff Model: {backoff_text}")
print(f"Interpolation Model: {interpolation_text}")
# Out:
# Backoff Model: most are urban dwellers engaged primarily in commerce . pol pot was determined to keep his power and disenfranchise any enemies or potential threats and thus increased his violent and aggressive actions against his people . a powersharing agreement was agreed with ranariddh and hun sen of the cambodian people s party . this marked the beginning of the 21st century . cambodia has two major ports phnom penh and cambodia s 150 casinos are the main attractions for foreign tourists . flowing south through cambodia s eastern regions is the mekong river of the silt vietnam needs for its rice basket . in response to border raids by the khmer rouge
# Interpolation Model: bribes are often demanded from companies operating in cambodia when obtaining licences and permits such as constructionrelated permits . the election was won by funcinpec led by sihanouk s son ranariddh in a hung parliament . in 2018 they handled a record of 10 million passengers . according to the international development research center and the united nations cambodia is considered southeast asia s most vulnerable country to the effects of climate change alongside the philippines . the environmental degradation also includes national parks and wildlife sanctuaries on a large scale and many endangered and endemic species are now threatened with extinction due to loss of habitats .
